# %%
try:
    from jyquickhelper import add_notebook_menu 
except:
    # !pip install jyquickhelper
    from jyquickhelper import add_notebook_menu
    

add_notebook_menu()
#Table du contenu pour  naviger facilement le notebook.
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null) {
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;")
#          .replace(">", "&gt;").replace("&", "&amp;");
#         }
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += end_format + "</ul>\n";
#             format_open -= 1;
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2);
#         text_menu += begin_format + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#         format_open += 1;
#     }
#     while (1 < memo_level) {
#         text_menu += end_format + "</ul>\n";
#         memo_level -= 1;
#         format_open -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#
#     while (format_open > 0) {
#         text_menu += end_format;
#         format_open -= 1;
#     }
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<a href="#__HREF__">__TITLE__</a>';
#     var send = "";
#     var begin_format = '<li>';
#     var end_format = '</li>';
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item,
#        begin_format, end_format);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# ## Notebook presentation

# %% [markdown]
# This notebook is focused on presenting the benchmark results for the Rips complex, Rips edge collapse complex, and alpha complex. The evaluation is performed on the ORBIT15K dataset. The notebook includes two tests, each utilizing distinct machine learning pipelines, which will be described in subsequent steps.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import ast
import numpy as np
from memory_profiler import profile
from sklearn.preprocessing   import MinMaxScaler
from sklearn.pipeline        import Pipeline
from sklearn.svm             import SVC
from sklearn.ensemble        import RandomForestClassifier
from sklearn.neighbors       import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from gudhi.representations import PersistenceImage
from gudhi.representations import BottleneckDistance
from gudhi.representations import Landscape
import gudhi as gd

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# %% [markdown]
# ##  Second Test : Selection of the representation module

# %% [markdown]
# ### Pipeline

# %%
pipe = Pipeline([("Separator", gd.representations.DiagramSelector(limit=np.inf, point_type="finite")),
                    ("Scaler",    gd.representations.DiagramScaler(scalers=[([0,1], MinMaxScaler())])),
                    ("TDA",       gd.representations.PersistenceImage()),
                    ("Estimator", RandomForestClassifier())])

param =    [
                                
                {"Scaler__use":         [True],
                "TDA":                 [gd.representations.Landscape()], 
                "TDA__resolution":     [100],
                "Estimator":           [RandomForestClassifier()]},
            
                {"Scaler__use":         [True],
                "TDA":                 [gd.representations.PersistenceImage()], 
                "TDA__resolution":     [ [5,5], [6,6] ],
                "TDA__bandwidth":      [0.01, 0.1, 1.0, 10.0],
                "Estimator":           [RandomForestClassifier()]},
                {"Scaler__use":         [False],
                "TDA":                 [gd.representations.BottleneckDistance()], 
                "TDA__epsilon":        [0.1], 
                "Estimator":           [RandomForestClassifier()]}
            ]

model = GridSearchCV(pipe, param, cv=4, error_score='raise')

# %% [markdown]
# ### Alpha Complex :

# %%
df_alpha_test_1=pd.read_csv("results_alpha.csv")
df_alpha_test_2=pd.read_csv("resultsalpha_6245.csv")
df_alpha_test_3=pd.read_csv("resultsalpha_625.csv")
df_alpha_test_pipeline1=pd.concat([df_alpha_test_1,df_alpha_test_2,df_alpha_test_3])
df_alpha_test_pipeline1=df_alpha_test_pipeline1.sort_values(by="test_accuracy",ascending=False)
df_alpha_test_pipeline1 = df_alpha_test_pipeline1.reset_index(drop=True)
                
df_complex = pd.json_normalize(df_alpha_test_pipeline1["complex_parameters"].apply(ast.literal_eval))
df_complex=df_complex.reset_index(drop=True)

df_alpha_test_pipeline1 = pd.concat([df_complex, df_alpha_test_pipeline1], axis=1)
df_alpha_test_pipeline1['Estimator']=" RandomForestClassifier"
df_alpha_test_pipeline1
# Out:
#   complex_type precision                               complex_parameters
# 0        alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}  \
# 1        alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}
# 2        alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
# 3        alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}
# 4        alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}
# 5        alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
# 6        alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}
# 7        alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}
# 8        alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
#
#    elapsed_time  time for diagram computation  time for pipeline creation
# 0        71.804                         9.205                         0.0  \
# 1        29.435                         9.576                         0.0
# 2        51.927                         2.583                         0.0
# 3        53.611                         2.338                         0.0
# 4        39.283                        11.054                         0.0
# 5        24.089                         3.178                         0.0
# 6        30.043                         2.895                         0.0
# 7        25.323                         2.504                         0.0
# 8        22.292                         2.753                         0.0
#
#    time for pipeline fitting and testing  elapsed_memory
# 0                                     63           1.043  \
# 1                                     20           0.023
# 2                                     49           6.922
# 3                                     51           0.176
# 4                                     28           0.766
# 5                                     21           5.309
# 6                                     27           9.238
# 7                                     23           1.141
# 8                                     20          10.285
#
#    memory for diagram computation  memory for pipeline creation
# 0                           0.000                           0.0  \
# 1                           0.000                           0.0
# 2                           0.285                           0.0
# 3                           0.000                           0.0
# 4                           0.008                           0.0
# 5                           1.547                           0.0
# 6                           7.402                           0.0
# 7                           0.000                           0.0
# 8                           1.508                           0.0
#
#    memory for pipeline fitting and testing  test_accuracy
# 0                                        1       0.619048  \
# 1                                        0       0.619048
# 2                                        7       0.571429
# 3                                        0       0.523810
# 4                                        1       0.476190
# 5                                        4       0.380952
# 6                                        2       0.380952
# 7                                        1       0.333333
# 8                                        9       0.238095
#
#                      best parameters for the complex                Estimator
# 0  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 1  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 2  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 3  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 4  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 5  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 6  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 7  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 8  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier

# %%
columns_to_keep = ['complex_type', 'precision', 'elapsed_time', 'elapsed_memory', 'test_accuracy']

# Keep only the specified columns
df_alpha_test_pipeline1_filtered = df_alpha_test_pipeline1[columns_to_keep]
df_alpha_test_pipeline1_filtered
# Out:
#   complex_type precision  elapsed_time  elapsed_memory  test_accuracy
# 0        alpha     exact        71.804           1.043       0.619048
# 1        alpha     exact        29.435           0.023       0.619048
# 2        alpha      fast        51.927           6.922       0.571429
# 3        alpha      safe        53.611           0.176       0.523810
# 4        alpha     exact        39.283           0.766       0.476190
# 5        alpha      fast        24.089           5.309       0.380952
# 6        alpha      safe        30.043           9.238       0.380952
# 7        alpha      safe        25.323           1.141       0.333333
# 8        alpha      fast        22.292          10.285       0.238095

# %%
print(" MEAN MEMORY ",np.mean(df_alpha_test_pipeline1["elapsed_memory"]))
print(" MEAN TIME ",np.mean(df_alpha_test_pipeline1["elapsed_time"]))

for e in df_alpha_test_pipeline1['best parameters for the complex']:
    print(e)
# Out:
#  MEAN MEMORY  3.878111111111112
#  MEAN TIME  38.64522222222222
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}

# %% [markdown]
# ### results for alpha:
#
# * Best persistence representations: Persistence Image
# * Best precision: exact
# * Mean of elapsed_time: 38.645222
# * Mean of elapsed_memory: 3.878 MB
# * Best test accuracy: 0.619048
# * Best elapsed time for best acc: 29.435 seconds
# * Best elapsed memory for best acc: 0.023 MB

# %% [markdown]
# ### Edge Collapse Rips Complex :

# %%
df_edge_test_1=pd.read_csv("results_edge.csv")
df_edge_test_2=pd.read_csv("resultsedge_6245.csv")
df_edge_test_3=pd.read_csv("resultsedge_625.csv")
df_edge_test_4=pd.read_csv("resultsedge_6255558.csv")
df_edge_test_pipeline1=pd.concat([df_edge_test_1,df_edge_test_2,df_edge_test_3,df_edge_test_4])
df_edge_test_pipeline1=df_edge_test_pipeline1.sort_values(by="test_accuracy",ascending=False)
df_edge_test_pipeline1 = df_edge_test_pipeline1.reset_index(drop=True)
                
df_complex = pd.json_normalize(df_edge_test_pipeline1["complex_parameters"].apply(ast.literal_eval))
df_complex=df_complex.reset_index(drop=True)



df_edge_test_pipeline1 = pd.concat([df_complex, df_edge_test_pipeline1], axis=1)
df_edge_test_pipeline1['Estimator']=" RandomForestClassifier"
df_edge_test_pipeline1
# Out:
#    complex_type  max_dimension sparse  max_edge_length  nb_iterations
# 0          edge              2   None         0.516584              2  \
# 1          edge              2   None         0.575211              3
# 2          edge              2   None         0.649735              2
# 3          edge              2   None         0.425860              3
# 4          edge              2   None         0.439468              3
# 5          edge              2   None         0.746055              3
# 6          edge              2   None         0.590269              2
# 7          edge              2   None         0.358031              2
# 8          edge              2   None         0.284186              3
# 9          edge              2   None         0.512279              2
# 10         edge              2   None         0.190465              2
# 11         edge              2   None         0.443120              3
# 12         edge              2   None         0.516584              3
# 13         edge              2   None         0.585445              3
# 14         edge              2   None         0.857695              2
# 15         edge              2   None         0.585445              2
# 16         edge              2   None         0.851250              3
# 17         edge              2   None         0.278639              2
# 18         edge              2   None         0.353158              3
# 19         edge              2   None         0.836042              3
# 20         edge              2   None         0.726875              2
# 21         edge              2   None         0.661717              3
# 22         edge              2   None         0.746055              2
# 23         edge              2   None         0.503620              3
# 24         edge              2   None         0.661717              2
# 25         edge              2   None         0.353158              2
# 26         edge              2   None         0.191713              2
# 27         edge              2   None         0.666974              3
# 28         edge              2   None         0.431968              2
# 29         edge              2   None         0.590269              3
# 30         edge              2   None         0.666974              2
# 31         edge              2   None         0.751931              3
# 32         edge              2   None         0.364614              3
# 33         edge              2   None         0.642946              3
# 34         edge              2   None         0.642946              2
# 35         edge              2   None         0.367327              2
# 36         edge              2   None         0.275171              2
# 37         edge              2   None         0.851250              2
# 38         edge              2   None         0.751931              2
# 39         edge              2   None         0.857695              3
# 40         edge              2   None         0.439468              2
# 41         edge              2   None         0.503620              2
# 42         edge              2   None         0.364614              2
# 43         edge              2   None         0.184333              3
# 44         edge              2   None         0.286114              3
# 45         edge              2   None         0.512279              3
# 46         edge              2   None         0.278639              3
# 47         edge              2   None         0.284186              2
# 48         edge              2   None         0.425860              2
# 49         edge              2   None         0.191713              3
# 50         edge              2   None         0.358031              3
# 51         edge              2   None         0.367327              3
# 52         edge              2   None         0.732426              3
# 53         edge              2   None         0.732426              2
# 54         edge              2   None         0.567462              3
# 55         edge              2   None         0.836042              2
# 56         edge              2   None         0.649735              3
# 57         edge              2   None         0.431968              3
# 58         edge              2   None         0.496333              3
# 59         edge              2   None         0.190465              3
# 60         edge              2   None         0.832011              2
# 61         edge              2   None         0.567462              2
# 62         edge              2   None         0.286114              2
# 63         edge              2   None         0.275171              3
# 64         edge              2   None         0.186441              3
# 65         edge              2   None         0.184333              2
# 66         edge              2   None         0.443120              2
# 67         edge              2   None         0.575211              2
# 68         edge              2   None         0.186441              2
# 69         edge              2   None         0.832011              3
# 70         edge              2   None         0.726875              3
# 71         edge              2   None         0.496333              2
#
#                                    complex_parameters  elapsed_time
# 0   {'complex_type': 'edge', 'max_dimension': 2, '...       258.302  \
# 1   {'complex_type': 'edge', 'max_dimension': 2, '...       338.189
# 2   {'complex_type': 'edge', 'max_dimension': 2, '...       437.601
# 3   {'complex_type': 'edge', 'max_dimension': 2, '...       246.145
# 4   {'complex_type': 'edge', 'max_dimension': 2, '...       151.566
# 5   {'complex_type': 'edge', 'max_dimension': 2, '...       520.796
# 6   {'complex_type': 'edge', 'max_dimension': 2, '...       356.636
# 7   {'complex_type': 'edge', 'max_dimension': 2, '...       118.301
# 8   {'complex_type': 'edge', 'max_dimension': 2, '...        63.548
# 9   {'complex_type': 'edge', 'max_dimension': 2, '...       223.390
# 10  {'complex_type': 'edge', 'max_dimension': 2, '...        38.442
# 11  {'complex_type': 'edge', 'max_dimension': 2, '...       176.507
# 12  {'complex_type': 'edge', 'max_dimension': 2, '...       259.532
# 13  {'complex_type': 'edge', 'max_dimension': 2, '...       313.566
# 14  {'complex_type': 'edge', 'max_dimension': 2, '...       730.722
# 15  {'complex_type': 'edge', 'max_dimension': 2, '...       278.359
# 16  {'complex_type': 'edge', 'max_dimension': 2, '...       649.311
# 17  {'complex_type': 'edge', 'max_dimension': 2, '...        75.676
# 18  {'complex_type': 'edge', 'max_dimension': 2, '...       188.477
# 19  {'complex_type': 'edge', 'max_dimension': 2, '...       684.351
# 20  {'complex_type': 'edge', 'max_dimension': 2, '...       579.556
# 21  {'complex_type': 'edge', 'max_dimension': 2, '...       408.387
# 22  {'complex_type': 'edge', 'max_dimension': 2, '...       521.669
# 23  {'complex_type': 'edge', 'max_dimension': 2, '...       249.495
# 24  {'complex_type': 'edge', 'max_dimension': 2, '...       409.566
# 25  {'complex_type': 'edge', 'max_dimension': 2, '...       187.567
# 26  {'complex_type': 'edge', 'max_dimension': 2, '...        31.761
# 27  {'complex_type': 'edge', 'max_dimension': 2, '...       466.067
# 28  {'complex_type': 'edge', 'max_dimension': 2, '...       173.900
# 29  {'complex_type': 'edge', 'max_dimension': 2, '...       356.212
# 30  {'complex_type': 'edge', 'max_dimension': 2, '...       466.698
# 31  {'complex_type': 'edge', 'max_dimension': 2, '...       592.230
# 32  {'complex_type': 'edge', 'max_dimension': 2, '...       102.767
# 33  {'complex_type': 'edge', 'max_dimension': 2, '...       468.002
# 34  {'complex_type': 'edge', 'max_dimension': 2, '...       482.422
# 35  {'complex_type': 'edge', 'max_dimension': 2, '...       108.806
# 36  {'complex_type': 'edge', 'max_dimension': 2, '...       151.773
# 37  {'complex_type': 'edge', 'max_dimension': 2, '...       645.539
# 38  {'complex_type': 'edge', 'max_dimension': 2, '...       592.802
# 39  {'complex_type': 'edge', 'max_dimension': 2, '...       732.255
# 40  {'complex_type': 'edge', 'max_dimension': 2, '...       155.978
# 41  {'complex_type': 'edge', 'max_dimension': 2, '...       243.440
# 42  {'complex_type': 'edge', 'max_dimension': 2, '...       103.200
# 43  {'complex_type': 'edge', 'max_dimension': 2, '...       125.965
# 44  {'complex_type': 'edge', 'max_dimension': 2, '...        63.348
# 45  {'complex_type': 'edge', 'max_dimension': 2, '...       201.522
# 46  {'complex_type': 'edge', 'max_dimension': 2, '...        75.037
# 47  {'complex_type': 'edge', 'max_dimension': 2, '...        61.141
# 48  {'complex_type': 'edge', 'max_dimension': 2, '...       246.869
# 49  {'complex_type': 'edge', 'max_dimension': 2, '...        31.738
# 50  {'complex_type': 'edge', 'max_dimension': 2, '...       119.280
# 51  {'complex_type': 'edge', 'max_dimension': 2, '...       108.514
# 52  {'complex_type': 'edge', 'max_dimension': 2, '...       554.328
# 53  {'complex_type': 'edge', 'max_dimension': 2, '...       555.015
# 54  {'complex_type': 'edge', 'max_dimension': 2, '...       389.827
# 55  {'complex_type': 'edge', 'max_dimension': 2, '...       691.509
# 56  {'complex_type': 'edge', 'max_dimension': 2, '...       438.425
# 57  {'complex_type': 'edge', 'max_dimension': 2, '...       173.705
# 58  {'complex_type': 'edge', 'max_dimension': 2, '...       315.073
# 59  {'complex_type': 'edge', 'max_dimension': 2, '...        39.823
# 60  {'complex_type': 'edge', 'max_dimension': 2, '...       716.380
# 61  {'complex_type': 'edge', 'max_dimension': 2, '...       392.059
# 62  {'complex_type': 'edge', 'max_dimension': 2, '...        65.911
# 63  {'complex_type': 'edge', 'max_dimension': 2, '...       147.508
# 64  {'complex_type': 'edge', 'max_dimension': 2, '...        50.455
# 65  {'complex_type': 'edge', 'max_dimension': 2, '...       126.423
# 66  {'complex_type': 'edge', 'max_dimension': 2, '...       171.817
# 67  {'complex_type': 'edge', 'max_dimension': 2, '...       337.377
# 68  {'complex_type': 'edge', 'max_dimension': 2, '...        51.068
# 69  {'complex_type': 'edge', 'max_dimension': 2, '...       713.951
# 70  {'complex_type': 'edge', 'max_dimension': 2, '...       592.149
# 71  {'complex_type': 'edge', 'max_dimension': 2, '...       316.106
#
#     time for diagram computation  time for pipeline creation
# 0                        244.751                         0.0  \
# 1                        325.621                         0.0
# 2                        425.233                         0.0
# 3                        234.599                         0.0
# 4                        140.578                         0.0
# 5                        509.302                         0.0
# 6                        343.033                         0.0
# 7                        106.297                         0.0
# 8                         52.000                         0.0
# 9                        211.901                         0.0
# 10                        26.853                         0.0
# 11                       163.070                         0.0
# 12                       246.191                         0.0
# 13                       302.089                         0.0
# 14                       717.440                         0.0
# 15                       266.771                         0.0
# 16                       637.903                         0.0
# 17                        63.478                         0.0
# 18                       176.816                         0.0
# 19                       671.909                         0.0
# 20                       568.560                         0.0
# 21                       396.957                         0.0
# 22                       510.219                         0.0
# 23                       237.211                         0.0
# 24                       398.300                         0.0
# 25                       176.078                         0.0
# 26                        18.324                         0.0
# 27                       452.655                         0.0
# 28                       161.566                         0.0
# 29                       342.611                         0.0
# 30                       453.531                         0.0
# 31                       578.638                         0.0
# 32                        91.310                         0.0
# 33                       456.952                         0.0
# 34                       470.879                         0.0
# 35                        95.248                         0.0
# 36                       140.025                         0.0
# 37                       633.828                         0.0
# 38                       579.323                         0.0
# 39                       718.673                         0.0
# 40                       144.997                         0.0
# 41                       230.948                         0.0
# 42                        91.749                         0.0
# 43                       114.423                         0.0
# 44                        50.176                         0.0
# 45                       189.913                         0.0
# 46                        63.145                         0.0
# 47                        50.107                         0.0
# 48                       235.624                         0.0
# 49                        18.222                         0.0
# 50                       106.973                         0.0
# 51                        95.003                         0.0
# 52                       542.109                         0.0
# 53                       542.639                         0.0
# 54                       378.497                         0.0
# 55                       679.175                         0.0
# 56                       425.910                         0.0
# 57                       161.844                         0.0
# 58                       303.457                         0.0
# 59                        26.673                         0.0
# 60                       704.822                         0.0
# 61                       380.477                         0.0
# 62                        52.191                         0.0
# 63                       136.107                         0.0
# 64                        38.191                         0.0
# 65                       114.795                         0.0
# 66                       158.478                         0.0
# 67                       324.811                         0.0
# 68                        38.639                         0.0
# 69                       702.495                         0.0
# 70                       580.666                         0.0
# 71                       304.548                         0.0
#
#     time for pipeline fitting and testing  elapsed_memory
# 0                                      14       55270.480  \
# 1                                      13       80732.895
# 2                                      12      110552.590
# 3                                      12       43914.680
# 4                                      11       35265.723
# 5                                      11      151870.590
# 6                                      14       81101.656
# 7                                      12       24753.375
# 8                                      12       10466.676
# 9                                      11       55033.195
# 10                                     12        6416.324
# 11                                     13       34378.750
# 12                                     13       55125.395
# 13                                     11       80292.492
# 14                                     13      205978.922
# 15                                     12       28035.012
# 16                                     11      202589.574
# 17                                     12       11071.566
# 18                                     12       29995.109
# 19                                     12      197744.832
# 20                                     11      155097.789
# 21                                     11      112024.789
# 22                                     11      151853.230
# 23                                     12       57108.977
# 24                                     11      112031.012
# 25                                     11       30251.059
# 26                                     13        1443.543
# 27                                     13      113985.480
# 28                                     12       38570.141
# 29                                     14       81374.324
# 30                                     13      114129.715
# 31                                     14      154519.305
# 32                                     11       20614.359
# 33                                     11      116776.570
# 34                                     12      117122.395
# 35                                     14       14037.785
# 36                                     12       17137.828
# 37                                     12      202703.934
# 38                                     13      154626.586
# 39                                     14      205976.531
# 40                                     11       35271.914
# 41                                     12       57111.852
# 42                                     11       20570.977
# 43                                     12       14003.090
# 44                                     13        6958.984
# 45                                     12       13732.543
# 46                                     12       10561.332
# 47                                     11       10465.000
# 48                                     11       44298.148
# 49                                     14        1313.707
# 50                                     12       24750.383
# 51                                     14       14033.203
# 52                                     12      148398.852
# 53                                     12      148394.941
# 54                                     11       86548.602
# 55                                     12      197749.379
# 56                                     13      110550.395
# 57                                     12       38563.777
# 58                                     12       62814.922
# 59                                     13        5245.430
# 60                                     12      204647.547
# 61                                     12       86912.922
# 62                                     14        8896.562
# 63                                     11       16715.906
# 64                                     12        9095.523
# 65                                     12       14993.012
# 66                                     13       29325.008
# 67                                     13       80786.898
# 68                                     12       10013.805
# 69                                     11      204280.621
# 70                                     11      154672.785
# 71                                     12       63165.719
#
#     memory for diagram computation  memory for pipeline creation
# 0                        55270.480                         0.000  \
# 1                        80732.895                         0.000
# 2                       110552.590                         0.000
# 3                        43914.680                         0.000
# 4                        35265.723                         0.000
# 5                       151870.590                         0.000
# 6                        81101.656                         0.000
# 7                        24753.375                         0.000
# 8                        10466.676                         0.000
# 9                        55033.195                         0.000
# 10                        6415.348                         0.000
# 11                       34378.750                         0.000
# 12                       55125.395                         0.000
# 13                       80292.492                         0.000
# 14                      205978.922                         0.000
# 15                       27532.395                         0.000
# 16                      202589.574                         0.000
# 17                       11071.566                         0.000
# 18                       29995.109                         0.000
# 19                      197743.660                         0.000
# 20                      155097.543                         0.000
# 21                      112024.785                         0.000
# 22                      151853.230                         0.000
# 23                       57108.977                         0.000
# 24                      112031.012                         0.000
# 25                       30251.059                         0.000
# 26                        1442.961                         0.004
# 27                      113985.480                         0.000
# 28                       38570.141                         0.000
# 29                       81374.324                         0.000
# 30                      114129.715                         0.000
# 31                      154519.305                         0.000
# 32                       20614.359                         0.000
# 33                      116776.059                         0.000
# 34                      117122.395                         0.000
# 35                       14037.785                         0.000
# 36                       17137.828                         0.000
# 37                      202703.934                         0.000
# 38                      154626.586                         0.000
# 39                      205976.531                         0.000
# 40                       35271.910                         0.000
# 41                       57111.852                         0.000
# 42                       20570.977                         0.000
# 43                       14003.082                         0.000
# 44                        6957.762                         0.000
# 45                       13732.543                         0.000
# 46                       10561.332                         0.000
# 47                       10465.000                         0.000
# 48                       44298.148                         0.000
# 49                        1313.707                         0.000
# 50                       24750.383                         0.000
# 51                       14033.203                         0.000
# 52                      148398.852                         0.000
# 53                      148394.941                         0.000
# 54                       86548.602                         0.000
# 55                      197749.379                         0.000
# 56                      110550.395                         0.000
# 57                       38563.773                         0.000
# 58                       62814.922                         0.000
# 59                        5245.422                         0.000
# 60                      204647.547                         0.000
# 61                       86912.922                         0.000
# 62                        8895.352                         0.000
# 63                       16715.906                         0.000
# 64                        9095.523                         0.000
# 65                       14992.055                         0.004
# 66                       29325.008                         0.000
# 67                       80786.898                         0.000
# 68                       10012.844                         0.000
# 69                      204280.523                         0.031
# 70                      154672.785                         0.000
# 71                       63165.719                         0.000
#
#     memory for pipeline fitting and testing  test_accuracy
# 0                                         0       0.714286  \
# 1                                         0       0.666667
# 2                                         0       0.666667
# 3                                         0       0.666667
# 4                                         0       0.666667
# 5                                         0       0.666667
# 6                                         0       0.619048
# 7                                         0       0.619048
# 8                                         0       0.619048
# 9                                         0       0.619048
# 10                                        1       0.619048
# 11                                        0       0.619048
# 12                                        0       0.571429
# 13                                        0       0.571429
# 14                                        0       0.571429
# 15                                      503       0.571429
# 16                                        0       0.571429
# 17                                        0       0.571429
# 18                                        0       0.571429
# 19                                        1       0.571429
# 20                                        0       0.571429
# 21                                        0       0.571429
# 22                                        0       0.523810
# 23                                        0       0.523810
# 24                                        0       0.523810
# 25                                        0       0.523810
# 26                                        1       0.523810
# 27                                        0       0.523810
# 28                                        0       0.523810
# 29                                        0       0.523810
# 30                                        0       0.523810
# 31                                        0       0.523810
# 32                                        0       0.476190
# 33                                        1       0.476190
# 34                                        0       0.476190
# 35                                        0       0.476190
# 36                                        0       0.476190
# 37                                        0       0.476190
# 38                                        0       0.476190
# 39                                        0       0.476190
# 40                                        0       0.476190
# 41                                        0       0.476190
# 42                                        0       0.476190
# 43                                        0       0.428571
# 44                                        1       0.428571
# 45                                        0       0.428571
# 46                                        0       0.428571
# 47                                        0       0.428571
# 48                                        0       0.428571
# 49                                        0       0.428571
# 50                                        0       0.428571
# 51                                        0       0.428571
# 52                                        0       0.428571
# 53                                        0       0.380952
# 54                                        0       0.380952
# 55                                        0       0.380952
# 56                                        0       0.380952
# 57                                        0       0.380952
# 58                                        0       0.380952
# 59                                        0       0.380952
# 60                                        0       0.380952
# 61                                        0       0.380952
# 62                                        1       0.333333
# 63                                        0       0.333333
# 64                                        0       0.333333
# 65                                        1       0.333333
# 66                                        0       0.333333
# 67                                        0       0.333333
# 68                                        1       0.333333
# 69                                        0       0.333333
# 70                                        0       0.285714
# 71                                        0       0.238095
#
#                       best parameters for the complex                Estimator
# 0   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 1   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 2   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 3   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 4   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 5   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 6   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 7   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 8   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 9   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 10  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 11  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 12  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 13  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 14  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 15  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 16  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 17  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 18  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 19  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 20  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 21  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 22  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 23  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 24  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 25  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 26  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 27  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 28  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 29  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 30  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 31  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 32  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 33  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 34  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 35  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 36  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 37  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 38  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 39  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 40  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 41  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 42  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 43  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 44  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 45  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 46  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 47  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 48  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 49  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 50  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 51  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 52  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 53  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 54  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 55  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 56  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 57  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 58  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 59  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 60  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 61  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 62  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 63  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 64  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 65  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 66  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 67  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 68  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 69  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 70  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 71  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier

# %%
print(" MEAN MEMORY: ",np.mean(df_edge_test_pipeline1["elapsed_memory"]))
print(" MEAN TIME : ",np.mean(df_edge_test_pipeline1["elapsed_time"]))

for e in df_edge_test_pipeline1['best parameters for the complex']:
    print(e)
# Out:
#  MEAN MEMORY:  75094.70731944445
#  MEAN TIME :  308.4976666666667
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}

# %%
mask = df_edge_test_pipeline1['test_accuracy'] > 0.6
columns_to_keep = ['complex_type', 'max_edge_length','max_dimension','nb_iterations', 'elapsed_time', 'elapsed_memory', 'test_accuracy']

df_edge_test_pipeline1_filtered = df_edge_test_pipeline1[columns_to_keep]
filtered_df = df_edge_test_pipeline1_filtered[mask]
filtered_df
# Out:
#    complex_type  max_edge_length  max_dimension  nb_iterations  elapsed_time
# 0          edge         0.516584              2              2       258.302  \
# 1          edge         0.575211              2              3       338.189
# 2          edge         0.649735              2              2       437.601
# 3          edge         0.425860              2              3       246.145
# 4          edge         0.439468              2              3       151.566
# 5          edge         0.746055              2              3       520.796
# 6          edge         0.590269              2              2       356.636
# 7          edge         0.358031              2              2       118.301
# 8          edge         0.284186              2              3        63.548
# 9          edge         0.512279              2              2       223.390
# 10         edge         0.190465              2              2        38.442
# 11         edge         0.443120              2              3       176.507
#
#     elapsed_memory  test_accuracy
# 0        55270.480       0.714286
# 1        80732.895       0.666667
# 2       110552.590       0.666667
# 3        43914.680       0.666667
# 4        35265.723       0.666667
# 5       151870.590       0.666667
# 6        81101.656       0.619048
# 7        24753.375       0.619048
# 8        10466.676       0.619048
# 9        55033.195       0.619048
# 10        6416.324       0.619048
# 11       34378.750       0.619048

# %%
 
filtered_df['max_edge_length'].value_counts()
# Out:
# max_edge_length
# 0.516584    1
# 0.575211    1
# 0.649735    1
# 0.425860    1
# 0.439468    1
# 0.746055    1
# 0.590269    1
# 0.358031    1
# 0.284186    1
# 0.512279    1
# 0.190465    1
# 0.443120    1
# Name: count, dtype: int64

# %%
print(" MEAN MEMORY: ",np.mean(filtered_df["elapsed_memory"]))
print(" MEAN TIME : ",np.mean(filtered_df["elapsed_time"]))

for e in df_edge_test_pipeline1['best parameters for the complex']:
    print(e)
# Out:
#  MEAN MEMORY:  57479.7445
#  MEAN TIME :  244.1185833333333
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}

# %% [markdown]
# ### results for Edge Collapse Rips Complex :
# * Best accuracy: 0.714286
# * elapsed time for best acc: 258.302
# * Best persistence representations: Landscape
# * Best threshold: between 5th and 6th quantile
# * Mean of elapsed_time: 1173.497 S
# * Mean of elapsed_memory: 75028.74 MB
# * Best number of collapse: 2 and 3

# %% [markdown]
# ###  Rips Complex :

# %%
df_rips_test_1=pd.read_csv("results_rips.csv")
df_rips_test_2=pd.read_csv("resultsrips_6245.csv")
df_rips_test_3=pd.read_csv("resultsrips_625.csv")
df_rips_test_4=pd.read_csv("resultsrips_62588.csv")
df_rips_test_pipeline1=pd.concat([df_rips_test_1,df_rips_test_2,df_rips_test_3,df_rips_test_4])
df_rips_test_pipeline1=df_rips_test_pipeline1.sort_values(by="test_accuracy",ascending=False)
df_rips_test_pipeline1 = df_rips_test_pipeline1.reset_index(drop=True)
                
df_complex = pd.json_normalize(df_rips_test_pipeline1["complex_parameters"].apply(ast.literal_eval))
df_complex=df_complex.reset_index(drop=True)

df_rips_test_pipeline1 = pd.concat([df_complex, df_rips_test_pipeline1], axis=1)
df_rips_test_pipeline1['Estimator']=" RandomForestClassifier"

df_rips_test_pipeline1
# Out:
#    complex_type  max_dimension sparse  max_edge_length
# 0          rips              2   None         0.836201  \
# 1          rips              2   None         0.732426
# 2          rips              2   None         0.501485
# 3          rips              2   None         0.277081
# 4          rips              2   None         0.439468
# 5          rips              2   None         0.358031
# 6          rips              2   None         0.503620
# 7          rips              2   None         0.190465
# 8          rips              2   None         0.364614
# 9          rips              2   None         0.573518
# 10         rips              2   None         0.355923
# 11         rips              2   None         0.851250
# 12         rips              2   None         0.512279
# 13         rips              2   None         0.284186
# 14         rips              2   None         0.746055
# 15         rips              2   None         0.649735
# 16         rips              2   None         0.648507
# 17         rips              2   None         0.661717
# 18         rips              2   None         0.431968
# 19         rips              2   None         0.278639
# 20         rips              2   None         0.731654
# 21         rips              2   None         0.585445
# 22         rips              2   None         0.185702
# 23         rips              2   None         0.575211
# 24         rips              2   None         0.186441
# 25         rips              2   None         0.429650
# 26         rips              2   None         0.188577
# 27         rips              2   None         0.836042
#
#                                    complex_parameters  elapsed_time
# 0   {'complex_type': 'rips', 'max_dimension': 2, '...     15967.850  \
# 1   {'complex_type': 'rips', 'max_dimension': 2, '...     13377.622
# 2   {'complex_type': 'rips', 'max_dimension': 2, '...      5325.229
# 3   {'complex_type': 'rips', 'max_dimension': 2, '...      1431.260
# 4   {'complex_type': 'rips', 'max_dimension': 2, '...      2859.286
# 5   {'complex_type': 'rips', 'max_dimension': 2, '...      2419.382
# 6   {'complex_type': 'rips', 'max_dimension': 2, '...      5469.453
# 7   {'complex_type': 'rips', 'max_dimension': 2, '...       549.468
# 8   {'complex_type': 'rips', 'max_dimension': 2, '...      1638.864
# 9   {'complex_type': 'rips', 'max_dimension': 2, '...      7001.134
# 10  {'complex_type': 'rips', 'max_dimension': 2, '...      2382.761
# 11  {'complex_type': 'rips', 'max_dimension': 2, '...     20080.152
# 12  {'complex_type': 'rips', 'max_dimension': 2, '...      4639.547
# 13  {'complex_type': 'rips', 'max_dimension': 2, '...       862.682
# 14  {'complex_type': 'rips', 'max_dimension': 2, '...     14514.367
# 15  {'complex_type': 'rips', 'max_dimension': 2, '...      9997.927
# 16  {'complex_type': 'rips', 'max_dimension': 2, '...      9171.576
# 17  {'complex_type': 'rips', 'max_dimension': 2, '...     10141.458
# 18  {'complex_type': 'rips', 'max_dimension': 2, '...      3685.818
# 19  {'complex_type': 'rips', 'max_dimension': 2, '...      1542.938
# 20  {'complex_type': 'rips', 'max_dimension': 2, '...     12664.431
# 21  {'complex_type': 'rips', 'max_dimension': 2, '...      6536.873
# 22  {'complex_type': 'rips', 'max_dimension': 2, '...       889.486
# 23  {'complex_type': 'rips', 'max_dimension': 2, '...      7116.080
# 24  {'complex_type': 'rips', 'max_dimension': 2, '...      1005.171
# 25  {'complex_type': 'rips', 'max_dimension': 2, '...      3646.665
# 26  {'complex_type': 'rips', 'max_dimension': 2, '...         8.538
# 27  {'complex_type': 'rips', 'max_dimension': 2, '...     16962.920
#
#     time for diagram computation  time for pipeline creation
# 0                      15956.725                       0.001  \
# 1                      13365.973                       0.000
# 2                       5314.198                       0.000
# 3                       1419.355                       0.001
# 4                       2847.823                       0.001
# 5                       2407.623                       0.000
# 6                       5457.747                       0.000
# 7                        537.948                       0.000
# 8                       1627.371                       0.000
# 9                       6990.006                       0.001
# 10                      2371.131                       0.000
# 11                     20068.511                       0.001
# 12                      4628.217                       0.000
# 13                       851.281                       0.000
# 14                     14502.865                       0.000
# 15                      9986.256                       0.000
# 16                      9160.492                       0.000
# 17                     10130.096                       0.000
# 18                      3674.651                       0.000
# 19                      1531.734                       0.000
# 20                     12653.282                       0.000
# 21                      6525.325                       0.000
# 22                       877.688                       0.000
# 23                      7104.767                       0.000
# 24                       993.985                       0.000
# 25                      3634.743                       0.000
# 26                         0.027                       0.000
# 27                     16951.887                       0.000
#
#     time for pipeline fitting and testing  elapsed_memory
# 0                                      11             inf  \
# 1                                      12             inf
# 2                                      11             inf
# 3                                      12             inf
# 4                                      11             inf
# 5                                      12             inf
# 6                                      12             inf
# 7                                      12             inf
# 8                                      11             inf
# 9                                      11             inf
# 10                                     12             inf
# 11                                     12             inf
# 12                                     11             inf
# 13                                     11             inf
# 14                                     12             inf
# 15                                     12             inf
# 16                                     11             inf
# 17                                     11             inf
# 18                                     11             inf
# 19                                     11             inf
# 20                                     11             inf
# 21                                     12             inf
# 22                                     12             inf
# 23                                     11             inf
# 24                                     11             inf
# 25                                     12             inf
# 26                                      9           1.082
# 27                                     11             inf
#
#     memory for diagram computation  memory for pipeline creation
# 0                              inf                           0.0  \
# 1                              inf                           0.0
# 2                              inf                           0.0
# 3                              inf                           0.0
# 4                              inf                           0.0
# 5                              inf                           0.0
# 6                              inf                           0.0
# 7                              inf                           0.0
# 8                              inf                           0.0
# 9                              inf                           0.0
# 10                             inf                           0.0
# 11                             inf                           0.0
# 12                             inf                           0.0
# 13                             inf                           0.0
# 14                             inf                           0.0
# 15                             inf                           0.0
# 16                             inf                           0.0
# 17                             inf                           0.0
# 18                             inf                           0.0
# 19                             inf                           0.0
# 20                             inf                           0.0
# 21                             inf                           0.0
# 22                             inf                           0.0
# 23                             inf                           0.0
# 24                             inf                           0.0
# 25                             inf                           0.0
# 26                             0.0                           0.0
# 27                             inf                           0.0
#
#     memory for pipeline fitting and testing  test_accuracy
# 0                                         0       0.761905  \
# 1                                         0       0.714286
# 2                                         0       0.666667
# 3                                         0       0.666667
# 4                                         0       0.666667
# 5                                         0       0.619048
# 6                                         1       0.619048
# 7                                         1       0.619048
# 8                                         0       0.571429
# 9                                         0       0.571429
# 10                                        0       0.571429
# 11                                        0       0.571429
# 12                                        1       0.571429
# 13                                        0       0.571429
# 14                                        1       0.523810
# 15                                        0       0.523810
# 16                                        0       0.523810
# 17                                        0       0.476190
# 18                                        0       0.476190
# 19                                        0       0.476190
# 20                                        0       0.476190
# 21                                        0       0.428571
# 22                                        1       0.428571
# 23                                        0       0.428571
# 24                                        1       0.333333
# 25                                        1       0.333333
# 26                                        1       0.333333
# 27                                        0       0.285714
#
#                       best parameters for the complex                Estimator
# 0   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 1   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 2   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 3   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 4   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 5   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 6   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 7   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 8   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 9   {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 10  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 11  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 12  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 13  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 14  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 15  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 16  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 17  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 18  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 19  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 20  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 21  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 22  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 23  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 24  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 25  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 26  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier
# 27  {'Estimator': RandomForestClassifier(), 'Scale...   RandomForestClassifier

# %%
mask = df_rips_test_pipeline1['test_accuracy'] > 0.6

# Apply the mask to the DataFrame
filtered_df = df_rips_test_pipeline1[mask]
print(np.mean(filtered_df["elapsed_memory"]))
print(np.mean(filtered_df["elapsed_time"]))
print (filtered_df['max_edge_length'].value_counts())

for e in filtered_df['best parameters for the complex']:
    print(e)
# Out:
# inf
# 5924.94375
# max_edge_length
# 0.836201    1
# 0.732426    1
# 0.501485    1
# 0.277081    1
# 0.439468    1
# 0.358031    1
# 0.503620    1
# 0.190465    1
# Name: count, dtype: int64
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}

# %%
mask = df_rips_test_pipeline1['test_accuracy'] > 0.6
columns_to_keep = ['complex_type', 'max_edge_length', 'elapsed_time', 'elapsed_memory', 'test_accuracy']
df_edge_test_pipeline1_filtered = df_rips_test_pipeline1[columns_to_keep]

# Apply the mask to the DataFrame
filtered_df = df_edge_test_pipeline1_filtered[mask]
filtered_df
# Out:
#   complex_type  max_edge_length  elapsed_time  elapsed_memory  test_accuracy
# 0         rips         0.836201     15967.850             inf       0.761905
# 1         rips         0.732426     13377.622             inf       0.714286
# 2         rips         0.501485      5325.229             inf       0.666667
# 3         rips         0.277081      1431.260             inf       0.666667
# 4         rips         0.439468      2859.286             inf       0.666667
# 5         rips         0.358031      2419.382             inf       0.619048
# 6         rips         0.503620      5469.453             inf       0.619048
# 7         rips         0.190465       549.468             inf       0.619048

# %% [markdown]
# ###  results for  Rips Complex :
# * Best accuracy: 0.761905
# * elapsed time for best acc: 15967.850
# * Best persistence representations: Persistence Image
# * Best threshold: NA
# * Mean of elapsed_time: 5924.94375 S
# * Mean of elapsed_memory: inf MB

# %% [markdown]
# ## Third Test : RandomForestClassifier Hyperparameters Tuning

# %% [markdown]
# ### Pipeline:

# %%
pipe = Pipeline([("Separator", gd.representations.DiagramSelector(limit=np.inf, point_type="finite")),
                    ("Scaler",    gd.representations.DiagramScaler(scalers=[([0,1], MinMaxScaler())])),
                    ("TDA",       gd.representations.PersistenceImage()),
                    ("Estimator", RandomForestClassifier())])

param =    [
                                
                {"Scaler__use":         [True],
                "TDA":                 [gd.representations.Landscape()], 
                "TDA__resolution":     [100],
                "Estimator":           [RandomForestClassifier()],
                "Estimator": [RandomForestClassifier()],
               "Estimator__n_estimators": [50, 100, 200],
                "Estimator__max_depth": [None, 5, 10],
                "Estimator__min_samples_split": [2, 5, 10],
                "Estimator__min_samples_leaf": [1, 2, 4]},
            
                {"Scaler__use":         [True],
                "TDA":                 [gd.representations.PersistenceImage()], 
                "TDA__resolution":     [ [5,5], [6,6] ],
                "TDA__bandwidth":      [0.01, 0.1, 1.0, 10.0],
                "Estimator":           [RandomForestClassifier()],
                "Estimator__n_estimators": [50, 100, 200],
                "Estimator__max_depth": [None, 5, 10],
                "Estimator__min_samples_split": [2, 5, 10],
                "Estimator__min_samples_leaf": [1, 2, 4]},
            ]

model = GridSearchCV(pipe, param, cv=4, error_score='raise')

# %% [markdown]
# ### Alpha Complex :

# %%
df_alpha_test_1=pd.read_csv("results2alpha_6245.csv")
df_alpha_test_2=pd.read_csv("results2alpha_625.csv")
df_alpha_test_3=pd.read_csv("results2alpha_62588.csv")
df_alpha_test_4=pd.read_csv("results2alpha_6255558.csv")
df_alpha_test_5=pd.read_csv("results2alpha_621238.csv")
df_alpha_test_6=pd.read_csv("results2alpha_99846.csv")
df_alpha_test_7=pd.read_csv("results2alpha_9986.csv")

df_alpha_test_pipeline1=pd.concat([df_alpha_test_1,df_alpha_test_2,df_alpha_test_3,df_alpha_test_4,df_alpha_test_5,df_alpha_test_6,df_alpha_test_7])
df_alpha_test_pipeline1=df_alpha_test_pipeline1.sort_values(by="test_accuracy",ascending=False)
df_alpha_test_pipeline1 = df_alpha_test_pipeline1.reset_index(drop=True)
                
df_complex = pd.json_normalize(df_alpha_test_pipeline1["complex_parameters"].apply(ast.literal_eval))
df_complex=df_complex.reset_index(drop=True)

df_alpha_test_pipeline1 = pd.concat([df_complex, df_alpha_test_pipeline1], axis=1)
df_alpha_test_pipeline1['Estimator']=" RandomForestClassifier"
df_alpha_test_pipeline1
# Out:
#    complex_type precision                               complex_parameters
# 0         alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}  \
# 1         alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}
# 2         alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}
# 3         alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}
# 4         alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}
# 5         alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
# 6         alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
# 7         alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}
# 8         alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}
# 9         alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
# 10        alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}
# 11        alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}
# 12        alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}
# 13        alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
# 14        alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}
# 15        alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}
# 16        alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
# 17        alpha     exact  {'complex_type': 'alpha', 'precision': 'exact'}
# 18        alpha      safe   {'complex_type': 'alpha', 'precision': 'safe'}
# 19        alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
# 20        alpha      fast   {'complex_type': 'alpha', 'precision': 'fast'}
#
#     elapsed_time  time for diagram computation  time for pipeline creation
# 0       1390.002                         2.451                         0.0  \
# 1       1522.215                         2.294                         0.0
# 2       1537.387                         8.572                         0.0
# 3       1527.480                         2.409                         0.0
# 4       1478.673                         2.329                         0.0
# 5       1470.563                         2.644                         0.0
# 6       1530.352                         2.530                         0.0
# 7       1161.026                         8.810                         0.0
# 8       1986.921                         2.324                         0.0
# 9       1562.842                         2.480                         0.0
# 10      1523.878                         8.610                         0.0
# 11      1538.945                         2.316                         0.0
# 12      1504.587                         9.044                         0.0
# 13      1538.717                         2.849                         0.0
# 14      1473.822                         8.741                         0.0
# 15      1391.146                         8.786                         0.0
# 16      1834.864                         2.556                         0.0
# 17      1474.027                         8.916                         0.0
# 18      1525.255                         2.439                         0.0
# 19      1467.000                         2.574                         0.0
# 20      1131.558                         2.435                         0.0
#
#     time for pipeline fitting and testing  elapsed_memory
# 0                                    1388          24.684  \
# 1                                    1520           4.359
# 2                                    1529           2.895
# 3                                    1525           2.039
# 4                                    1476           2.527
# 5                                    1468          15.801
# 6                                    1528          13.410
# 7                                    1152           0.453
# 8                                    1985           2.504
# 9                                    1560          13.355
# 10                                   1515           0.070
# 11                                   1537           0.031
# 12                                   1496           0.512
# 13                                   1536           9.852
# 14                                   1465           2.082
# 15                                   1382           5.066
# 16                                   1832          11.184
# 17                                   1465          24.574
# 18                                   1523           0.035
# 19                                   1464          13.414
# 20                                   1129          11.402
#
#     memory for diagram computation  memory for pipeline creation
# 0                            0.000                           0.0  \
# 1                            0.000                           0.0
# 2                            0.000                           0.0
# 3                            0.000                           0.0
# 4                            0.000                           0.0
# 5                            1.508                           0.0
# 6                            1.520                           0.0
# 7                            0.000                           0.0
# 8                            0.000                           0.0
# 9                            1.488                           0.0
# 10                           0.000                           0.0
# 11                           0.000                           0.0
# 12                           0.000                           0.0
# 13                           1.535                           0.0
# 14                           0.000                           0.0
# 15                           0.441                           0.0
# 16                           1.516                           0.0
# 17                           0.000                           0.0
# 18                           0.000                           0.0
# 19                           1.531                           0.0
# 20                           1.473                           0.0
#
#     memory for pipeline fitting and testing  test_accuracy
# 0                                        25       0.619048  \
# 1                                         4       0.619048
# 2                                         3       0.619048
# 3                                         2       0.571429
# 4                                         3       0.571429
# 5                                        14       0.523810
# 6                                        12       0.523810
# 7                                         0       0.523810
# 8                                         3       0.523810
# 9                                        12       0.523810
# 10                                        0       0.523810
# 11                                        0       0.523810
# 12                                        1       0.428571
# 13                                        8       0.428571
# 14                                        2       0.428571
# 15                                        5       0.428571
# 16                                       10       0.380952
# 17                                       25       0.380952
# 18                                        0       0.380952
# 19                                       12       0.333333
# 20                                       10       0.047619
#
#                       best parameters for the complex                Estimator
# 0   {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 1   {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 2   {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 3   {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 4   {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 5   {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 6   {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 7   {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 8   {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 9   {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 10  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 11  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 12  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 13  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 14  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 15  {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 16  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 17  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 18  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 19  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 20  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier

# %%
print(" Mean memory :",np.mean(df_alpha_test_pipeline1["elapsed_memory"]))
print(" Mean time :",np.mean(df_alpha_test_pipeline1["elapsed_time"]))

for e in df_alpha_test_pipeline1['best parameters for the complex']:
    print(e)
    print("---------------------------------------------------------------------------------------------------------------")
    print("---------------------------------------------------------------------------------------------------------------")
# Out:
#  Mean memory : 7.630904761904761
#  Mean time : 1503.3933333333334
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=5), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# ---------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------

# %%
mask = df_alpha_test_pipeline1['test_accuracy'] > 0.6

# Apply the mask to the DataFrame
filtered_df = df_alpha_test_pipeline1[mask]
print(np.mean(filtered_df["elapsed_memory"]))
print(np.mean(filtered_df["elapsed_time"]))

for e in filtered_df['best parameters for the complex']:
    print(e)
# Out:
# 10.645999999999999
# 1483.2013333333332
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}

# %%
mask = df_alpha_test_pipeline1['test_accuracy'] > 0.6
columns_to_keep = ['complex_type', 'precision', 'elapsed_time', 'elapsed_memory', 'test_accuracy']
df_alpha_test_pipeline1_filtered = df_alpha_test_pipeline1[columns_to_keep]

# Apply the mask to the DataFrame
filtered_df = df_alpha_test_pipeline1_filtered[mask]
filtered_df
# Out:
#   complex_type precision  elapsed_time  elapsed_memory  test_accuracy
# 0        alpha      safe      1390.002          24.684       0.619048
# 1        alpha      safe      1522.215           4.359       0.619048
# 2        alpha     exact      1537.387           2.895       0.619048

# %% [markdown]
# ### results for Alpha Complex:
#
# * Best persistence representations: Persistence Image
# * Best precision: exact
# * Mean of elapsed_time: 38.645222
# * Mean of elapsed_memory: 3.878 MB
# * Best test accuracy: 0.619048
# * Best elapsed time for best acc: 29.435 seconds

# %% [markdown]
# ### Edge Collapse Rips Complex

# %%
df_edge_test_1=pd.read_csv("results2edge_6245.csv")
df_edge_test_2=pd.read_csv("results2edge_625.csv")
df_edge_test_3=pd.read_csv("results2edge_62588.csv")
df_edge_test_4=pd.read_csv("results2edge_6255558.csv")
df_edge_test_5=pd.read_csv("results2edge_76338.csv")
df_edge_test_6=pd.read_csv("results2edge_336238.csv")
df_edge_test_7=pd.read_csv("results2edge_621238.csv")
df_edge_test_8=pd.read_csv("results2edge_7644338.csv")
df_edge_test_9=pd.read_csv("results2edge_9986.csv")
df_edge_test_10=pd.read_csv("results2edge_89846.csv")
df_edge_test_11=pd.read_csv("results2edge_56238.csv")

df_edge_test_pipeline1=pd.concat([df_edge_test_1,df_edge_test_2,df_edge_test_3,df_edge_test_4,df_edge_test_5,df_edge_test_6,df_edge_test_7,df_edge_test_8,df_edge_test_9,df_edge_test_10,df_edge_test_11])
df_edge_test_pipeline1=df_edge_test_pipeline1.sort_values(by="test_accuracy",ascending=False)
df_edge_test_pipeline1 = df_edge_test_pipeline1.reset_index(drop=True)
                
df_complex = pd.json_normalize(df_edge_test_pipeline1["complex_parameters"].apply(ast.literal_eval))
df_complex=df_complex.reset_index(drop=True)



df_edge_test_pipeline1 = pd.concat([df_complex, df_edge_test_pipeline1], axis=1)
df_edge_test_pipeline1['Estimator']=" RandomForestClassifier"
df_edge_test_pipeline1
# Out:
#     complex_type  max_dimension sparse  max_edge_length  nb_iterations
# 0           edge              2   None         0.358031              3  \
# 1           edge              2   None         0.661717              2
# 2           edge              2   None         0.585445              3
# 3           edge              2   None         0.496333              3
# 4           edge              2   None         0.668441              2
# 5           edge              2   None         0.671234              3
# 6           edge              2   None         0.364614              3
# 7           edge              2   None         0.353158              3
# 8           edge              2   None         0.726875              2
# 9           edge              2   None         0.726875              3
# 10          edge              2   None         0.503620              3
# 11          edge              2   None         0.836201              2
# 12          edge              2   None         0.671234              2
# 13          edge              2   None         0.355923              3
# 14          edge              2   None         0.284186              2
# 15          edge              2   None         0.858712              2
# 16          edge              2   None         0.512279              3
# 17          edge              2   None         0.858712              3
# 18          edge              2   None         0.501485              2
# 19          edge              2   None         0.277081              3
# 20          edge              2   None         0.517931              3
# 21          edge              2   None         0.741360              3
# 22          edge              2   None         0.731654              2
# 23          edge              2   None         0.732426              3
# 24          edge              2   None         0.575211              3
# 25          edge              2   None         0.579512              3
# 26          edge              2   None         0.503620              2
# 27          edge              2   None         0.844886              2
# 28          edge              2   None         0.370012              3
# 29          edge              2   None         0.580863              2
# 30          edge              2   None         0.746055              2
# 31          edge              2   None         0.446094              3
# 32          edge              2   None         0.436307              3
# 33          edge              2   None         0.738313              3
# 34          edge              2   None         0.731654              3
# 35          edge              2   None         0.436307              2
# 36          edge              2   None         0.361818              3
# 37          edge              2   None         0.842572              2
# 38          edge              2   None         0.642946              2
# 39          edge              2   None         0.654961              2
# 40          edge              2   None         0.863527              2
# 41          edge              2   None         0.863527              3
# 42          edge              2   None         0.501485              3
# 43          edge              2   None         0.446094              2
# 44          edge              2   None         0.593858              2
# 45          edge              2   None         0.358031              2
# 46          edge              2   None         0.355923              2
# 47          edge              2   None         0.190465              2
# 48          edge              2   None         0.732426              2
# 49          edge              2   None         0.505314              3
# 50          edge              2   None         0.746055              3
# 51          edge              2   None         0.278639              3
# 52          edge              2   None         0.841716              3
# 53          edge              2   None         0.841716              2
# 54          edge              2   None         0.649735              2
# 55          edge              2   None         0.429650              3
# 56          edge              2   None         0.756757              3
# 57          edge              2   None         0.288394              3
# 58          edge              2   None         0.591743              2
# 59          edge              2   None         0.518516              3
# 60          edge              2   None         0.368927              2
# 61          edge              2   None         0.508464              2
# 62          edge              2   None         0.754678              2
# 63          edge              2   None         0.364614              2
# 64          edge              2   None         0.284186              3
# 65          edge              2   None         0.593858              3
# 66          edge              2   None         0.425860              2
# 67          edge              2   None         0.754678              3
# 68          edge              2   None         0.439468              3
# 69          edge              2   None         0.288394              2
# 70          edge              2   None         0.184333              3
# 71          edge              2   None         0.282771              2
# 72          edge              2   None         0.280349              3
# 73          edge              2   None         0.280349              2
# 74          edge              2   None         0.851250              3
# 75          edge              2   None         0.573518              3
# 76          edge              2   None         0.508464              3
# 77          edge              2   None         0.186441              3
# 78          edge              2   None         0.188862              2
# 79          edge              2   None         0.519768              3
# 80          edge              2   None         0.360889              2
# 81          edge              2   None         0.508263              3
# 82          edge              2   None         0.191933              2
# 83          edge              2   None         0.736641              2
# 84          edge              2   None         0.753060              2
# 85          edge              2   None         0.753060              3
# 86          edge              2   None         0.359638              2
# 87          edge              2   None         0.580828              2
# 88          edge              2   None         0.189922              3
# 89          edge              2   None         0.435037              2
# 90          edge              2   None         0.842572              3
# 91          edge              2   None         0.738313              2
# 92          edge              2   None         0.654961              3
# 93          edge              2   None         0.579512              2
# 94          edge              2   None         0.507096              3
# 95          edge              2   None         0.435037              3
# 96          edge              2   None         0.508263              2
# 97          edge              2   None         0.669769              3
# 98          edge              2   None         0.648507              2
# 99          edge              2   None         0.368927              3
# 100         edge              2   None         0.649735              3
# 101         edge              2   None         0.836042              3
# 102         edge              2   None         0.512279              2
# 103         edge              2   None         0.661717              3
# 104         edge              2   None         0.836201              3
# 105         edge              2   None         0.740374              3
# 106         edge              2   None         0.656545              3
# 107         edge              2   None         0.496333              2
# 108         edge              2   None         0.580863              3
# 109         edge              2   None         0.192428              2
# 110         edge              2   None         0.517931              2
# 111         edge              2   None         0.860265              2
# 112         edge              2   None         0.444915              3
# 113         edge              2   None         0.669769              2
# 114         edge              2   None         0.436187              2
# 115         edge              2   None         0.439468              2
# 116         edge              2   None         0.282037              2
# 117         edge              2   None         0.185702              2
# 118         edge              2   None         0.187770              3
# 119         edge              2   None         0.851250              2
# 120         edge              2   None         0.585445              2
# 121         edge              2   None         0.359638              3
# 122         edge              2   None         0.433558              3
# 123         edge              2   None         0.505314              2
# 124         edge              2   None         0.190465              3
# 125         edge              2   None         0.429650              2
# 126         edge              2   None         0.577401              3
# 127         edge              2   None         0.668441              3
# 128         edge              2   None         0.575211              2
# 129         edge              2   None         0.431968              2
# 130         edge              2   None         0.286635              2
# 131         edge              2   None         0.286635              3
# 132         edge              2   None         0.368151              3
# 133         edge              2   None         0.444201              2
# 134         edge              2   None         0.278639              2
# 135         edge              2   None         0.361818              2
# 136         edge              2   None         0.277081              2
# 137         edge              2   None         0.573518              2
# 138         edge              2   None         0.756757              2
# 139         edge              2   None         0.360889              3
# 140         edge              2   None         0.287411              3
# 141         edge              2   None         0.287411              2
# 142         edge              2   None         0.282771              3
# 143         edge              2   None         0.436187              3
# 144         edge              2   None         0.519768              2
# 145         edge              2   None         0.185702              3
# 146         edge              2   None         0.656895              3
# 147         edge              2   None         0.741360              2
# 148         edge              2   None         0.281477              2
# 149         edge              2   None         0.368151              2
# 150         edge              2   None         0.507096              2
# 151         edge              2   None         0.192428              3
# 152         edge              2   None         0.188862              3
# 153         edge              2   None         0.656545              2
# 154         edge              2   None         0.193332              3
# 155         edge              2   None         0.836042              2
# 156         edge              2   None         0.193332              2
# 157         edge              2   None         0.648507              3
# 158         edge              2   None         0.652825              2
# 159         edge              2   None         0.567462              2
# 160         edge              2   None         0.425860              3
# 161         edge              2   None         0.592534              3
# 162         edge              2   None         0.275171              3
# 163         edge              2   None         0.860265              3
# 164         edge              2   None         0.740374              2
# 165         edge              2   None         0.370012              2
# 166         edge              2   None         0.362385              2
# 167         edge              2   None         0.362385              3
# 168         edge              2   None         0.567462              3
# 169         edge              2   None         0.282037              3
# 170         edge              2   None         0.591743              3
# 171         edge              2   None         0.186441              2
# 172         edge              2   None         0.444201              3
# 173         edge              2   None         0.656895              2
# 174         edge              2   None         0.431968              3
# 175         edge              2   None         0.184333              2
# 176         edge              2   None         0.642946              3
# 177         edge              2   None         0.832011              2
# 178         edge              2   None         0.832011              3
# 179         edge              2   None         0.444915              2
# 180         edge              2   None         0.592534              2
# 181         edge              2   None         0.281477              3
# 182         edge              2   None         0.191933              3
# 183         edge              2   None         0.189922              2
# 184         edge              2   None         0.847134              3
# 185         edge              2   None         0.187770              2
# 186         edge              2   None         0.433558              2
# 187         edge              2   None         0.577401              2
# 188         edge              2   None         0.844886              3
# 189         edge              2   None         0.580828              3
# 190         edge              2   None         0.189108              3
# 191         edge              2   None         0.189108              2
# 192         edge              2   None         0.353158              2
# 193         edge              2   None         0.275171              2
# 194         edge              2   None         0.518516              2
# 195         edge              2   None         0.736641              3
# 196         edge              2   None         0.847134              2
# 197         edge              2   None         0.652825              3
#
#                                     complex_parameters  elapsed_time
# 0    {'complex_type': 'edge', 'max_dimension': 2, '...       924.289  \
# 1    {'complex_type': 'edge', 'max_dimension': 2, '...      1236.627
# 2    {'complex_type': 'edge', 'max_dimension': 2, '...      1172.248
# 3    {'complex_type': 'edge', 'max_dimension': 2, '...      1293.219
# 4    {'complex_type': 'edge', 'max_dimension': 2, '...      1596.168
# 5    {'complex_type': 'edge', 'max_dimension': 2, '...      1233.926
# 6    {'complex_type': 'edge', 'max_dimension': 2, '...       926.261
# 7    {'complex_type': 'edge', 'max_dimension': 2, '...      1182.370
# 8    {'complex_type': 'edge', 'max_dimension': 2, '...      1414.106
# 9    {'complex_type': 'edge', 'max_dimension': 2, '...      1555.586
# 10   {'complex_type': 'edge', 'max_dimension': 2, '...      1034.109
# 11   {'complex_type': 'edge', 'max_dimension': 2, '...      1457.967
# 12   {'complex_type': 'edge', 'max_dimension': 2, '...      1237.675
# 13   {'complex_type': 'edge', 'max_dimension': 2, '...       969.423
# 14   {'complex_type': 'edge', 'max_dimension': 2, '...       889.316
# 15   {'complex_type': 'edge', 'max_dimension': 2, '...      1885.815
# 16   {'complex_type': 'edge', 'max_dimension': 2, '...      1095.164
# 17   {'complex_type': 'edge', 'max_dimension': 2, '...      1880.667
# 18   {'complex_type': 'edge', 'max_dimension': 2, '...      1051.579
# 19   {'complex_type': 'edge', 'max_dimension': 2, '...       935.718
# 20   {'complex_type': 'edge', 'max_dimension': 2, '...      1354.568
# 21   {'complex_type': 'edge', 'max_dimension': 2, '...      1359.259
# 22   {'complex_type': 'edge', 'max_dimension': 2, '...      1341.635
# 23   {'complex_type': 'edge', 'max_dimension': 2, '...      1300.524
# 24   {'complex_type': 'edge', 'max_dimension': 2, '...      1107.605
# 25   {'complex_type': 'edge', 'max_dimension': 2, '...      1156.686
# 26   {'complex_type': 'edge', 'max_dimension': 2, '...      1035.554
# 27   {'complex_type': 'edge', 'max_dimension': 2, '...      1817.183
# 28   {'complex_type': 'edge', 'max_dimension': 2, '...       922.653
# 29   {'complex_type': 'edge', 'max_dimension': 2, '...      1425.537
# 30   {'complex_type': 'edge', 'max_dimension': 2, '...      1341.077
# 31   {'complex_type': 'edge', 'max_dimension': 2, '...       980.773
# 32   {'complex_type': 'edge', 'max_dimension': 2, '...      1044.829
# 33   {'complex_type': 'edge', 'max_dimension': 2, '...      1350.239
# 34   {'complex_type': 'edge', 'max_dimension': 2, '...      1324.688
# 35   {'complex_type': 'edge', 'max_dimension': 2, '...      1044.342
# 36   {'complex_type': 'edge', 'max_dimension': 2, '...      1179.327
# 37   {'complex_type': 'edge', 'max_dimension': 2, '...      1464.869
# 38   {'complex_type': 'edge', 'max_dimension': 2, '...      1454.146
# 39   {'complex_type': 'edge', 'max_dimension': 2, '...      1242.175
# 40   {'complex_type': 'edge', 'max_dimension': 2, '...      1466.258
# 41   {'complex_type': 'edge', 'max_dimension': 2, '...      1462.818
# 42   {'complex_type': 'edge', 'max_dimension': 2, '...      1064.566
# 43   {'complex_type': 'edge', 'max_dimension': 2, '...       979.184
# 44   {'complex_type': 'edge', 'max_dimension': 2, '...      1135.097
# 45   {'complex_type': 'edge', 'max_dimension': 2, '...       923.757
# 46   {'complex_type': 'edge', 'max_dimension': 2, '...       948.414
# 47   {'complex_type': 'edge', 'max_dimension': 2, '...       869.214
# 48   {'complex_type': 'edge', 'max_dimension': 2, '...      1303.444
# 49   {'complex_type': 'edge', 'max_dimension': 2, '...      1319.274
# 50   {'complex_type': 'edge', 'max_dimension': 2, '...      1380.904
# 51   {'complex_type': 'edge', 'max_dimension': 2, '...       890.725
# 52   {'complex_type': 'edge', 'max_dimension': 2, '...      1803.788
# 53   {'complex_type': 'edge', 'max_dimension': 2, '...      1805.595
# 54   {'complex_type': 'edge', 'max_dimension': 2, '...      1196.177
# 55   {'complex_type': 'edge', 'max_dimension': 2, '...       989.167
# 56   {'complex_type': 'edge', 'max_dimension': 2, '...      1344.885
# 57   {'complex_type': 'edge', 'max_dimension': 2, '...       878.971
# 58   {'complex_type': 'edge', 'max_dimension': 2, '...      1467.357
# 59   {'complex_type': 'edge', 'max_dimension': 2, '...       715.100
# 60   {'complex_type': 'edge', 'max_dimension': 2, '...       638.581
# 61   {'complex_type': 'edge', 'max_dimension': 2, '...      1329.824
# 62   {'complex_type': 'edge', 'max_dimension': 2, '...       886.082
# 63   {'complex_type': 'edge', 'max_dimension': 2, '...       925.813
# 64   {'complex_type': 'edge', 'max_dimension': 2, '...       937.624
# 65   {'complex_type': 'edge', 'max_dimension': 2, '...      1131.435
# 66   {'complex_type': 'edge', 'max_dimension': 2, '...      1229.475
# 67   {'complex_type': 'edge', 'max_dimension': 2, '...       884.151
# 68   {'complex_type': 'edge', 'max_dimension': 2, '...       979.881
# 69   {'complex_type': 'edge', 'max_dimension': 2, '...       881.710
# 70   {'complex_type': 'edge', 'max_dimension': 2, '...      1118.755
# 71   {'complex_type': 'edge', 'max_dimension': 2, '...       951.099
# 72   {'complex_type': 'edge', 'max_dimension': 2, '...      1124.842
# 73   {'complex_type': 'edge', 'max_dimension': 2, '...      1125.457
# 74   {'complex_type': 'edge', 'max_dimension': 2, '...      1463.707
# 75   {'complex_type': 'edge', 'max_dimension': 2, '...      1131.447
# 76   {'complex_type': 'edge', 'max_dimension': 2, '...      1323.132
# 77   {'complex_type': 'edge', 'max_dimension': 2, '...       874.668
# 78   {'complex_type': 'edge', 'max_dimension': 2, '...       904.990
# 79   {'complex_type': 'edge', 'max_dimension': 2, '...      1053.956
# 80   {'complex_type': 'edge', 'max_dimension': 2, '...       972.089
# 81   {'complex_type': 'edge', 'max_dimension': 2, '...      1134.797
# 82   {'complex_type': 'edge', 'max_dimension': 2, '...      1130.077
# 83   {'complex_type': 'edge', 'max_dimension': 2, '...      1654.165
# 84   {'complex_type': 'edge', 'max_dimension': 2, '...      1734.282
# 85   {'complex_type': 'edge', 'max_dimension': 2, '...      1735.655
# 86   {'complex_type': 'edge', 'max_dimension': 2, '...      1180.524
# 87   {'complex_type': 'edge', 'max_dimension': 2, '...      1181.691
# 88   {'complex_type': 'edge', 'max_dimension': 2, '...       940.668
# 89   {'complex_type': 'edge', 'max_dimension': 2, '...      1016.814
# 90   {'complex_type': 'edge', 'max_dimension': 2, '...      1471.542
# 91   {'complex_type': 'edge', 'max_dimension': 2, '...      1347.878
# 92   {'complex_type': 'edge', 'max_dimension': 2, '...      1247.722
# 93   {'complex_type': 'edge', 'max_dimension': 2, '...      1154.335
# 94   {'complex_type': 'edge', 'max_dimension': 2, '...      1076.424
# 95   {'complex_type': 'edge', 'max_dimension': 2, '...      1016.552
# 96   {'complex_type': 'edge', 'max_dimension': 2, '...      1114.807
# 97   {'complex_type': 'edge', 'max_dimension': 2, '...       819.922
# 98   {'complex_type': 'edge', 'max_dimension': 2, '...      1236.928
# 99   {'complex_type': 'edge', 'max_dimension': 2, '...       638.782
# 100  {'complex_type': 'edge', 'max_dimension': 2, '...      1196.465
# 101  {'complex_type': 'edge', 'max_dimension': 2, '...      1416.704
# 102  {'complex_type': 'edge', 'max_dimension': 2, '...      1044.245
# 103  {'complex_type': 'edge', 'max_dimension': 2, '...      1230.654
# 104  {'complex_type': 'edge', 'max_dimension': 2, '...      1457.290
# 105  {'complex_type': 'edge', 'max_dimension': 2, '...      1660.190
# 106  {'complex_type': 'edge', 'max_dimension': 2, '...      1526.017
# 107  {'complex_type': 'edge', 'max_dimension': 2, '...      1316.753
# 108  {'complex_type': 'edge', 'max_dimension': 2, '...      1420.509
# 109  {'complex_type': 'edge', 'max_dimension': 2, '...       600.223
# 110  {'complex_type': 'edge', 'max_dimension': 2, '...      1369.046
# 111  {'complex_type': 'edge', 'max_dimension': 2, '...       952.922
# 112  {'complex_type': 'edge', 'max_dimension': 2, '...       674.511
# 113  {'complex_type': 'edge', 'max_dimension': 2, '...       822.024
# 114  {'complex_type': 'edge', 'max_dimension': 2, '...      1256.789
# 115  {'complex_type': 'edge', 'max_dimension': 2, '...       983.523
# 116  {'complex_type': 'edge', 'max_dimension': 2, '...      1143.187
# 117  {'complex_type': 'edge', 'max_dimension': 2, '...       944.285
# 118  {'complex_type': 'edge', 'max_dimension': 2, '...      1106.997
# 119  {'complex_type': 'edge', 'max_dimension': 2, '...      1463.118
# 120  {'complex_type': 'edge', 'max_dimension': 2, '...      1132.503
# 121  {'complex_type': 'edge', 'max_dimension': 2, '...      1174.368
# 122  {'complex_type': 'edge', 'max_dimension': 2, '...      1238.627
# 123  {'complex_type': 'edge', 'max_dimension': 2, '...      1320.905
# 124  {'complex_type': 'edge', 'max_dimension': 2, '...       869.633
# 125  {'complex_type': 'edge', 'max_dimension': 2, '...      1024.066
# 126  {'complex_type': 'edge', 'max_dimension': 2, '...      1412.635
# 127  {'complex_type': 'edge', 'max_dimension': 2, '...      1579.844
# 128  {'complex_type': 'edge', 'max_dimension': 2, '...      1110.556
# 129  {'complex_type': 'edge', 'max_dimension': 2, '...       973.346
# 130  {'complex_type': 'edge', 'max_dimension': 2, '...      1171.765
# 131  {'complex_type': 'edge', 'max_dimension': 2, '...      1154.450
# 132  {'complex_type': 'edge', 'max_dimension': 2, '...      1213.700
# 133  {'complex_type': 'edge', 'max_dimension': 2, '...      1272.911
# 134  {'complex_type': 'edge', 'max_dimension': 2, '...       891.817
# 135  {'complex_type': 'edge', 'max_dimension': 2, '...      1188.033
# 136  {'complex_type': 'edge', 'max_dimension': 2, '...       960.314
# 137  {'complex_type': 'edge', 'max_dimension': 2, '...      1142.665
# 138  {'complex_type': 'edge', 'max_dimension': 2, '...      1340.045
# 139  {'complex_type': 'edge', 'max_dimension': 2, '...       969.580
# 140  {'complex_type': 'edge', 'max_dimension': 2, '...       614.943
# 141  {'complex_type': 'edge', 'max_dimension': 2, '...       616.055
# 142  {'complex_type': 'edge', 'max_dimension': 2, '...       955.784
# 143  {'complex_type': 'edge', 'max_dimension': 2, '...      1240.192
# 144  {'complex_type': 'edge', 'max_dimension': 2, '...      1052.714
# 145  {'complex_type': 'edge', 'max_dimension': 2, '...       898.959
# 146  {'complex_type': 'edge', 'max_dimension': 2, '...      1246.095
# 147  {'complex_type': 'edge', 'max_dimension': 2, '...      1354.640
# 148  {'complex_type': 'edge', 'max_dimension': 2, '...       934.762
# 149  {'complex_type': 'edge', 'max_dimension': 2, '...      1211.590
# 150  {'complex_type': 'edge', 'max_dimension': 2, '...      1078.630
# 151  {'complex_type': 'edge', 'max_dimension': 2, '...       601.984
# 152  {'complex_type': 'edge', 'max_dimension': 2, '...       917.531
# 153  {'complex_type': 'edge', 'max_dimension': 2, '...      1539.129
# 154  {'complex_type': 'edge', 'max_dimension': 2, '...       863.567
# 155  {'complex_type': 'edge', 'max_dimension': 2, '...      1415.835
# 156  {'complex_type': 'edge', 'max_dimension': 2, '...       860.253
# 157  {'complex_type': 'edge', 'max_dimension': 2, '...      1220.374
# 158  {'complex_type': 'edge', 'max_dimension': 2, '...      1530.364
# 159  {'complex_type': 'edge', 'max_dimension': 2, '...      1360.519
# 160  {'complex_type': 'edge', 'max_dimension': 2, '...      1217.601
# 161  {'complex_type': 'edge', 'max_dimension': 2, '...       762.616
# 162  {'complex_type': 'edge', 'max_dimension': 2, '...      1140.235
# 163  {'complex_type': 'edge', 'max_dimension': 2, '...       951.869
# 164  {'complex_type': 'edge', 'max_dimension': 2, '...      1667.418
# 165  {'complex_type': 'edge', 'max_dimension': 2, '...       918.737
# 166  {'complex_type': 'edge', 'max_dimension': 2, '...       992.671
# 167  {'complex_type': 'edge', 'max_dimension': 2, '...       988.271
# 168  {'complex_type': 'edge', 'max_dimension': 2, '...      1224.385
# 169  {'complex_type': 'edge', 'max_dimension': 2, '...      1142.643
# 170  {'complex_type': 'edge', 'max_dimension': 2, '...      1477.218
# 171  {'complex_type': 'edge', 'max_dimension': 2, '...       883.253
# 172  {'complex_type': 'edge', 'max_dimension': 2, '...      1282.626
# 173  {'complex_type': 'edge', 'max_dimension': 2, '...      1251.531
# 174  {'complex_type': 'edge', 'max_dimension': 2, '...       972.072
# 175  {'complex_type': 'edge', 'max_dimension': 2, '...      1116.401
# 176  {'complex_type': 'edge', 'max_dimension': 2, '...      1472.225
# 177  {'complex_type': 'edge', 'max_dimension': 2, '...      1681.771
# 178  {'complex_type': 'edge', 'max_dimension': 2, '...      1527.282
# 179  {'complex_type': 'edge', 'max_dimension': 2, '...       673.610
# 180  {'complex_type': 'edge', 'max_dimension': 2, '...       763.759
# 181  {'complex_type': 'edge', 'max_dimension': 2, '...       933.899
# 182  {'complex_type': 'edge', 'max_dimension': 2, '...      1133.199
# 183  {'complex_type': 'edge', 'max_dimension': 2, '...       943.433
# 184  {'complex_type': 'edge', 'max_dimension': 2, '...      1475.361
# 185  {'complex_type': 'edge', 'max_dimension': 2, '...      1102.362
# 186  {'complex_type': 'edge', 'max_dimension': 2, '...      1239.676
# 187  {'complex_type': 'edge', 'max_dimension': 2, '...      1421.994
# 188  {'complex_type': 'edge', 'max_dimension': 2, '...      1810.890
# 189  {'complex_type': 'edge', 'max_dimension': 2, '...      1167.523
# 190  {'complex_type': 'edge', 'max_dimension': 2, '...      1121.102
# 191  {'complex_type': 'edge', 'max_dimension': 2, '...      1127.776
# 192  {'complex_type': 'edge', 'max_dimension': 2, '...      1182.282
# 193  {'complex_type': 'edge', 'max_dimension': 2, '...      1138.673
# 194  {'complex_type': 'edge', 'max_dimension': 2, '...       714.756
# 195  {'complex_type': 'edge', 'max_dimension': 2, '...      1653.935
# 196  {'complex_type': 'edge', 'max_dimension': 2, '...      1478.284
# 197  {'complex_type': 'edge', 'max_dimension': 2, '...      1520.464
#
#      time for diagram computation  time for pipeline creation
# 0                          95.649                         0.0  \
# 1                         393.697                         0.0
# 2                         296.413                         0.0
# 3                         306.695                         0.0
# 4                         484.891                         0.0
# 5                         393.445                         0.0
# 6                          87.496                         0.0
# 7                         196.478                         0.0
# 8                         571.659                         0.0
# 9                         567.028                         0.0
# 10                        207.007                         0.0
# 11                        617.259                         0.0
# 12                        392.785                         0.0
# 13                        109.010                         0.0
# 14                         48.072                         0.0
# 15                        781.571                         0.0
# 16                        211.688                         0.0
# 17                        774.372                         0.0
# 18                        221.742                         0.0
# 19                         69.420                         0.0
# 20                        258.059                         0.0
# 21                        514.049                         0.0
# 22                        498.413                         0.0
# 23                        471.123                         0.0
# 24                        281.357                         0.0
# 25                        314.918                         0.0
# 26                        206.759                         0.0
# 27                        776.427                         0.0
# 28                         78.809                         0.0
# 29                        388.220                         0.0
# 30                        502.853                         0.0
# 31                        137.349                         0.0
# 32                        174.291                         0.0
# 33                        508.383                         0.0
# 34                        495.786                         0.0
# 35                        174.686                         0.0
# 36                        142.602                         0.0
# 37                        625.718                         0.0
# 38                        468.967                         0.0
# 39                        403.655                         0.0
# 40                        625.994                         0.0
# 41                        623.407                         0.0
# 42                        224.581                         0.0
# 43                        135.038                         0.0
# 44                        293.966                         0.0
# 45                         95.500                         0.0
# 46                        110.214                         0.0
# 47                         25.562                         0.0
# 48                        471.079                         0.0
# 49                        273.297                         0.0
# 50                        498.296                         0.0
# 51                         60.522                         0.0
# 52                        755.917                         0.0
# 53                        753.188                         0.0
# 54                        368.821                         0.0
# 55                        158.336                         0.0
# 56                        501.136                         0.0
# 57                         34.750                         0.0
# 58                        360.616                         0.0
# 59                        127.062                         0.0
# 60                         51.619                         0.0
# 61                        292.237                         0.0
# 62                        296.748                         0.0
# 63                         86.778                         0.0
# 64                         51.003                         0.0
# 65                        292.858                         0.0
# 66                        239.429                         0.0
# 67                        296.745                         0.0
# 68                        139.945                         0.0
# 69                         38.080                         0.0
# 70                        125.282                         0.0
# 71                         76.189                         0.0
# 72                         79.177                         0.0
# 73                         78.621                         0.0
# 74                        627.156                         0.0
# 75                        300.536                         0.0
# 76                        284.365                         0.0
# 77                         34.927                         0.0
# 78                         62.710                         0.0
# 79                        209.463                         0.0
# 80                        124.693                         0.0
# 81                        243.527                         0.0
# 82                         27.168                         0.0
# 83                        607.369                         0.0
# 84                        622.747                         0.0
# 85                        622.926                         0.0
# 86                        128.667                         0.0
# 87                        330.051                         0.0
# 88                         55.025                         0.0
# 89                        174.889                         0.0
# 90                        629.769                         0.0
# 91                        508.125                         0.0
# 92                        406.802                         0.0
# 93                        314.055                         0.0
# 94                        238.293                         0.0
# 95                        175.624                         0.0
# 96                        241.485                         0.0
# 97                        233.361                         0.0
# 98                        392.952                         0.0
# 99                         51.680                         0.0
# 100                       368.023                         0.0
# 101                       589.245                         0.0
# 102                       205.604                         0.0
# 103                       393.805                         0.0
# 104                       615.772                         0.0
# 105                       620.059                         0.0
# 106                       491.961                         0.0
# 107                       326.538                         0.0
# 108                       381.043                         0.0
# 109                         9.435                         0.0
# 110                       262.132                         0.0
# 111                       365.851                         0.0
# 112                        85.524                         0.0
# 113                       233.465                         0.0
# 114                       212.003                         0.0
# 115                       144.752                         0.0
# 116                       106.637                         0.0
# 117                        45.080                         0.0
# 118                        47.909                         0.0
# 119                       625.060                         0.0
# 120                       293.609                         0.0
# 121                       129.096                         0.0
# 122                       192.233                         0.0
# 123                       272.770                         0.0
# 124                        25.022                         0.0
# 125                       156.514                         0.0
# 126                       369.477                         0.0
# 127                       471.775                         0.0
# 128                       281.411                         0.0
# 129                       144.232                         0.0
# 130                        57.096                         0.0
# 131                        56.118                         0.0
# 132                       105.785                         0.0
# 133                       173.988                         0.0
# 134                        59.847                         0.0
# 135                       149.707                         0.0
# 136                        66.634                         0.0
# 137                       301.896                         0.0
# 138                       500.727                         0.0
# 139                       126.705                         0.0
# 140                        27.170                         0.0
# 141                        27.071                         0.0
# 142                        77.383                         0.0
# 143                       202.572                         0.0
# 144                       207.722                         0.0
# 145                        48.565                         0.0
# 146                       406.567                         0.0
# 147                       513.175                         0.0
# 148                        85.933                         0.0
# 149                       100.244                         0.0
# 150                       238.369                         0.0
# 151                         9.436                         0.0
# 152                        62.476                         0.0
# 153                       500.327                         0.0
# 154                        12.055                         0.0
# 155                       588.583                         0.0
# 156                        12.857                         0.0
# 157                       390.756                         0.0
# 158                       480.936                         0.0
# 159                       378.343                         0.0
# 160                       231.594                         0.0
# 161                       176.130                         0.0
# 162                       151.363                         0.0
# 163                       366.348                         0.0
# 164                       630.959                         0.0
# 165                        75.443                         0.0
# 166                       119.767                         0.0
# 167                       120.311                         0.0
# 168                       382.723                         0.0
# 169                       104.573                         0.0
# 170                       365.952                         0.0
# 171                        37.414                         0.0
# 172                       173.644                         0.0
# 173                       410.048                         0.0
# 174                       144.357                         0.0
# 175                       120.555                         0.0
# 176                       483.679                         0.0
# 177                       696.129                         0.0
# 178                       686.382                         0.0
# 179                        85.126                         0.0
# 180                       176.286                         0.0
# 181                        86.251                         0.0
# 182                        26.465                         0.0
# 183                        55.855                         0.0
# 184                       634.339                         0.0
# 185                        47.947                         0.0
# 186                       192.325                         0.0
# 187                       368.940                         0.0
# 188                       767.717                         0.0
# 189                       317.131                         0.0
# 190                        79.167                         0.0
# 191                        82.238                         0.0
# 192                       197.094                         0.0
# 193                       151.227                         0.0
# 194                       127.327                         0.0
# 195                       607.391                         0.0
# 196                       634.286                         0.0
# 197                       479.503                         0.0
#
#      time for pipeline fitting and testing  elapsed_memory
# 0                                      829       24812.172  \
# 1                                      843      112081.469
# 2                                      876       80295.172
# 3                                      987       62795.770
# 4                                     1111      113415.434
# 5                                      840      116561.141
# 6                                      839       20598.227
# 7                                      986       29931.305
# 8                                      842      155012.613
# 9                                      989      154611.320
# 10                                     827       57096.082
# 11                                     841      198953.895
# 12                                     845      116556.375
# 13                                     860       24104.117
# 14                                     841       10451.992
# 15                                    1104      205436.926
# 16                                     883       55036.301
# 17                                    1106      205246.816
# 18                                     830       57208.250
# 19                                     866        9664.074
# 20                                    1097       54687.297
# 21                                     845      153521.730
# 22                                     843      149649.023
# 23                                     829      148420.855
# 24                                     826       80750.793
# 25                                     842       83584.953
# 26                                     829       57096.766
# 27                                    1041      192692.906
# 28                                     844       17419.137
# 29                                    1037       72631.516
# 30                                     838      151835.676
# 31                                     843       35054.512
# 32                                     871       37129.496
# 33                                     842      153226.094
# 34                                     829      149573.043
# 35                                     870       37320.516
# 36                                    1037        9184.172
# 37                                     839      203449.195
# 38                                     985      117023.844
# 39                                     839      114475.246
# 40                                     840      210138.504
# 41                                     839      210132.516
# 42                                     840       57143.152
# 43                                     844       33237.219
# 44                                     841       83077.016
# 45                                     828       24737.168
# 46                                     838       24282.863
# 47                                     844        6739.863
# 48                                     832      148390.031
# 49                                    1046       57997.188
# 50                                     883      151836.000
# 51                                     830       15269.039
# 52                                    1048      201746.480
# 53                                    1052      201806.984
# 54                                     827      110554.168
# 55                                     831       38172.445
# 56                                     844      158211.180
# 57                                     844        1081.973
# 58                                    1107       80883.328
# 59                                     588       55164.934
# 60                                     587       19373.996
# 61                                    1038       46113.055
# 62                                     589      154812.129
# 63                                     839       20563.234
# 64                                     887       10438.812
# 65                                     839       83057.492
# 66                                     990       23165.777
# 67                                     587      154791.887
# 68                                     840       35241.930
# 69                                     844        6608.902
# 70                                     993       14011.230
# 71                                     875        8095.117
# 72                                    1046       10813.609
# 73                                    1047       10933.590
# 74                                     837      202612.184
# 75                                     831       81317.309
# 76                                    1039       38448.348
# 77                                     840        9070.219
# 78                                     842       10332.430
# 79                                     844       56150.047
# 80                                     847       26085.027
# 81                                     891       56992.590
# 82                                    1103        2808.344
# 83                                    1047      152045.648
# 84                                    1112      154038.434
# 85                                    1113      153971.562
# 86                                    1052       24117.215
# 87                                     852       82314.281
# 88                                     886        7124.402
# 89                                     842       40235.102
# 90                                     842      203248.742
# 91                                     840      153408.516
# 92                                     841      114582.113
# 93                                     840       83800.230
# 94                                     838       59299.125
# ...
# 29   {'Estimator': RandomForestClassifier(n_estimat...
# 30   {'Estimator': RandomForestClassifier(min_sampl...
# 31   {'Estimator': RandomForestClassifier(max_depth...
# 32   {'Estimator': RandomForestClassifier(max_depth...
# 33   {'Estimator': RandomForestClassifier(min_sampl...
# 34   {'Estimator': RandomForestClassifier(n_estimat...
# 35   {'Estimator': RandomForestClassifier(max_depth...
# 36   {'Estimator': RandomForestClassifier(), 'Estim...
# 37   {'Estimator': RandomForestClassifier(min_sampl...
# 38   {'Estimator': RandomForestClassifier(max_depth...
# 39   {'Estimator': RandomForestClassifier(max_depth...
# 40   {'Estimator': RandomForestClassifier(max_depth...
# 41   {'Estimator': RandomForestClassifier(max_depth...
# 42   {'Estimator': RandomForestClassifier(n_estimat...
# 43   {'Estimator': RandomForestClassifier(max_depth...
# 44   {'Estimator': RandomForestClassifier(max_depth...
# 45   {'Estimator': RandomForestClassifier(min_sampl...
# 46   {'Estimator': RandomForestClassifier(min_sampl...
# 47   {'Estimator': RandomForestClassifier(max_depth...
# 48   {'Estimator': RandomForestClassifier(max_depth...
# 49   {'Estimator': RandomForestClassifier(min_sampl...
# 50   {'Estimator': RandomForestClassifier(max_depth...
# 51   {'Estimator': RandomForestClassifier(max_depth...
# 52   {'Estimator': RandomForestClassifier(max_depth...
# 53   {'Estimator': RandomForestClassifier(min_sampl...
# 54   {'Estimator': RandomForestClassifier(min_sampl...
# 55   {'Estimator': RandomForestClassifier(max_depth...
# 56   {'Estimator': RandomForestClassifier(min_sampl...
# 57   {'Estimator': RandomForestClassifier(max_depth...
# 58   {'Estimator': RandomForestClassifier(max_depth...
# 59   {'Estimator': RandomForestClassifier(min_sampl...
# 60   {'Estimator': RandomForestClassifier(max_depth...
# 61   {'Estimator': RandomForestClassifier(max_depth...
# 62   {'Estimator': RandomForestClassifier(n_estimat...
# 63   {'Estimator': RandomForestClassifier(min_sampl...
# 64   {'Estimator': RandomForestClassifier(max_depth...
# 65   {'Estimator': RandomForestClassifier(min_sampl...
# 66   {'Estimator': RandomForestClassifier(max_depth...
# 67   {'Estimator': RandomForestClassifier(min_sampl...
# 68   {'Estimator': RandomForestClassifier(n_estimat...
# 69   {'Estimator': RandomForestClassifier(n_estimat...
# 70   {'Estimator': RandomForestClassifier(min_sampl...
# 71   {'Estimator': RandomForestClassifier(max_depth...
# 72   {'Estimator': RandomForestClassifier(max_depth...
# 73   {'Estimator': RandomForestClassifier(max_depth...
# 74   {'Estimator': RandomForestClassifier(min_sampl...
# 75   {'Estimator': RandomForestClassifier(min_sampl...
# 76   {'Estimator': RandomForestClassifier(min_sampl...
# 77   {'Estimator': RandomForestClassifier(min_sampl...
# 78   {'Estimator': RandomForestClassifier(max_depth...
# 79   {'Estimator': RandomForestClassifier(max_depth...
# 80   {'Estimator': RandomForestClassifier(max_depth...
# 81   {'Estimator': RandomForestClassifier(min_sampl...
# 82   {'Estimator': RandomForestClassifier(max_depth...
# 83   {'Estimator': RandomForestClassifier(min_sampl...
# 84   {'Estimator': RandomForestClassifier(min_sampl...
# 85   {'Estimator': RandomForestClassifier(max_depth...
# 86   {'Estimator': RandomForestClassifier(max_depth...
# 87   {'Estimator': RandomForestClassifier(min_sampl...
# 88   {'Estimator': RandomForestClassifier(min_sampl...
# 89   {'Estimator': RandomForestClassifier(max_depth...
# 90   {'Estimator': RandomForestClassifier(min_sampl...
# 91   {'Estimator': RandomForestClassifier(max_depth...
# 92   {'Estimator': RandomForestClassifier(max_depth...
# 93   {'Estimator': RandomForestClassifier(max_depth...
# 94   {'Estimator': RandomForestClassifier(), 'Estim...
# 95   {'Estimator': RandomForestClassifier(max_depth...
# 96   {'Estimator': RandomForestClassifier(n_estimat...
# 97   {'Estimator': RandomForestClassifier(max_depth...
# 98   {'Estimator': RandomForestClassifier(min_sampl...
# 99   {'Estimator': RandomForestClassifier(min_sampl...
# 100  {'Estimator': RandomForestClassifier(n_estimat...
# 101  {'Estimator': RandomForestClassifier(max_depth...
# 102  {'Estimator': RandomForestClassifier(min_sampl...
# 103  {'Estimator': RandomForestClassifier(n_estimat...
# 104  {'Estimator': RandomForestClassifier(min_sampl...
# 105  {'Estimator': RandomForestClassifier(max_depth...
# 106  {'Estimator': RandomForestClassifier(max_depth...
# 107  {'Estimator': RandomForestClassifier(n_estimat...
# 108  {'Estimator': RandomForestClassifier(n_estimat...
# 109  {'Estimator': RandomForestClassifier(max_depth...
# 110  {'Estimator': RandomForestClassifier(min_sampl...
# 111  {'Estimator': RandomForestClassifier(max_depth...
# 112  {'Estimator': RandomForestClassifier(max_depth...
# 113  {'Estimator': RandomForestClassifier(max_depth...
# 114  {'Estimator': RandomForestClassifier(n_estimat...
# 115  {'Estimator': RandomForestClassifier(max_depth...
# 116  {'Estimator': RandomForestClassifier(max_depth...
# 117  {'Estimator': RandomForestClassifier(max_depth...
# 118  {'Estimator': RandomForestClassifier(n_estimat...
# 119  {'Estimator': RandomForestClassifier(min_sampl...
# 120  {'Estimator': RandomForestClassifier(max_depth...
# 121  {'Estimator': RandomForestClassifier(min_sampl...
# 122  {'Estimator': RandomForestClassifier(max_depth...
# 123  {'Estimator': RandomForestClassifier(max_depth...
# 124  {'Estimator': RandomForestClassifier(min_sampl...
# 125  {'Estimator': RandomForestClassifier(min_sampl...
# 126  {'Estimator': RandomForestClassifier(max_depth...
# 127  {'Estimator': RandomForestClassifier(max_depth...
# 128  {'Estimator': RandomForestClassifier(n_estimat...
# 129  {'Estimator': RandomForestClassifier(n_estimat...
# 130  {'Estimator': RandomForestClassifier(min_sampl...
# 131  {'Estimator': RandomForestClassifier(max_depth...
# 132  {'Estimator': RandomForestClassifier(), 'Estim...
# 133  {'Estimator': RandomForestClassifier(min_sampl...
# 134  {'Estimator': RandomForestClassifier(min_sampl...
# 135  {'Estimator': RandomForestClassifier(), 'Estim...
# 136  {'Estimator': RandomForestClassifier(min_sampl...
# 137  {'Estimator': RandomForestClassifier(max_depth...
# 138  {'Estimator': RandomForestClassifier(max_depth...
# 139  {'Estimator': RandomForestClassifier(min_sampl...
# 140  {'Estimator': RandomForestClassifier(max_depth...
# 141  {'Estimator': RandomForestClassifier(min_sampl...
# 142  {'Estimator': RandomForestClassifier(min_sampl...
# 143  {'Estimator': RandomForestClassifier(max_depth...
# 144  {'Estimator': RandomForestClassifier(min_sampl...
# 145  {'Estimator': RandomForestClassifier(max_depth...
# 146  {'Estimator': RandomForestClassifier(max_depth...
# 147  {'Estimator': RandomForestClassifier(min_sampl...
# 148  {'Estimator': RandomForestClassifier(n_estimat...
# 149  {'Estimator': RandomForestClassifier(min_sampl...
# 150  {'Estimator': RandomForestClassifier(min_sampl...
# 151  {'Estimator': RandomForestClassifier(max_depth...
# 152  {'Estimator': RandomForestClassifier(min_sampl...
# 153  {'Estimator': RandomForestClassifier(max_depth...
# 154  {'Estimator': RandomForestClassifier(min_sampl...
# 155  {'Estimator': RandomForestClassifier(max_depth...
# 156  {'Estimator': RandomForestClassifier(n_estimat...
# 157  {'Estimator': RandomForestClassifier(max_depth...
# 158  {'Estimator': RandomForestClassifier(max_depth...
# 159  {'Estimator': RandomForestClassifier(max_depth...
# 160  {'Estimator': RandomForestClassifier(min_sampl...
# 161  {'Estimator': RandomForestClassifier(max_depth...
# 162  {'Estimator': RandomForestClassifier(min_sampl...
# 163  {'Estimator': RandomForestClassifier(max_depth...
# 164  {'Estimator': RandomForestClassifier(max_depth...
# 165  {'Estimator': RandomForestClassifier(max_depth...
# 166  {'Estimator': RandomForestClassifier(max_depth...
# 167  {'Estimator': RandomForestClassifier(max_depth...
# 168  {'Estimator': RandomForestClassifier(max_depth...
# 169  {'Estimator': RandomForestClassifier(max_depth...
# 170  {'Estimator': RandomForestClassifier(min_sampl...
# 171  {'Estimator': RandomForestClassifier(min_sampl...
# 172  {'Estimator': RandomForestClassifier(min_sampl...
# 173  {'Estimator': RandomForestClassifier(max_depth...
# 174  {'Estimator': RandomForestClassifier(max_depth...
# 175  {'Estimator': RandomForestClassifier(max_depth...
# 176  {'Estimator': RandomForestClassifier(min_sampl...
# 177  {'Estimator': RandomForestClassifier(n_estimat...
# 178  {'Estimator': RandomForestClassifier(max_depth...
# 179  {'Estimator': RandomForestClassifier(min_sampl...
# 180  {'Estimator': RandomForestClassifier(max_depth...
# 181  {'Estimator': RandomForestClassifier(n_estimat...
# 182  {'Estimator': RandomForestClassifier(max_depth...
# 183  {'Estimator': RandomForestClassifier(max_depth...
# 184  {'Estimator': RandomForestClassifier(max_depth...
# 185  {'Estimator': RandomForestClassifier(max_depth...
# 186  {'Estimator': RandomForestClassifier(max_depth...
# 187  {'Estimator': RandomForestClassifier(max_depth...
# 188  {'Estimator': RandomForestClassifier(max_depth...
# 189  {'Estimator': RandomForestClassifier(min_sampl...
# 190  {'Estimator': RandomForestClassifier(max_depth...
# 191  {'Estimator': RandomForestClassifier(n_estimat...
# 192  {'Estimator': RandomForestClassifier(max_depth...
# 193  {'Estimator': RandomForestClassifier(max_depth...
# 194  {'Estimator': RandomForestClassifier(max_depth...
# 195  {'Estimator': RandomForestClassifier(n_estimat...
# 196  {'Estimator': RandomForestClassifier(min_sampl...
# 197  {'Estimator': RandomForestClassifier(min_sampl...
#
#                    Estimator
# 0     RandomForestClassifier
# 1     RandomForestClassifier
# 2     RandomForestClassifier
# 3     RandomForestClassifier
# 4     RandomForestClassifier
# 5     RandomForestClassifier
# 6     RandomForestClassifier
# 7     RandomForestClassifier
# 8     RandomForestClassifier
# 9     RandomForestClassifier
# 10    RandomForestClassifier
# 11    RandomForestClassifier
# 12    RandomForestClassifier
# 13    RandomForestClassifier
# 14    RandomForestClassifier
# 15    RandomForestClassifier
# 16    RandomForestClassifier
# 17    RandomForestClassifier
# 18    RandomForestClassifier
# 19    RandomForestClassifier
# 20    RandomForestClassifier
# 21    RandomForestClassifier
# 22    RandomForestClassifier
# 23    RandomForestClassifier
# 24    RandomForestClassifier
# 25    RandomForestClassifier
# 26    RandomForestClassifier
# 27    RandomForestClassifier
# 28    RandomForestClassifier
# 29    RandomForestClassifier
# 30    RandomForestClassifier
# 31    RandomForestClassifier
# 32    RandomForestClassifier
# 33    RandomForestClassifier
# 34    RandomForestClassifier
# 35    RandomForestClassifier
# 36    RandomForestClassifier
# 37    RandomForestClassifier
# 38    RandomForestClassifier
# 39    RandomForestClassifier
# 40    RandomForestClassifier
# 41    RandomForestClassifier
# 42    RandomForestClassifier
# 43    RandomForestClassifier
# 44    RandomForestClassifier
# 45    RandomForestClassifier
# 46    RandomForestClassifier
# 47    RandomForestClassifier
# 48    RandomForestClassifier
# 49    RandomForestClassifier
# 50    RandomForestClassifier
# 51    RandomForestClassifier
# 52    RandomForestClassifier
# 53    RandomForestClassifier
# 54    RandomForestClassifier
# 55    RandomForestClassifier
# 56    RandomForestClassifier
# 57    RandomForestClassifier
# 58    RandomForestClassifier
# 59    RandomForestClassifier
# 60    RandomForestClassifier
# 61    RandomForestClassifier
# 62    RandomForestClassifier
# 63    RandomForestClassifier
# 64    RandomForestClassifier
# 65    RandomForestClassifier
# 66    RandomForestClassifier
# 67    RandomForestClassifier
# 68    RandomForestClassifier
# 69    RandomForestClassifier
# 70    RandomForestClassifier
# 71    RandomForestClassifier
# 72    RandomForestClassifier
# 73    RandomForestClassifier
# 74    RandomForestClassifier
# 75    RandomForestClassifier
# 76    RandomForestClassifier
# 77    RandomForestClassifier
# 78    RandomForestClassifier
# 79    RandomForestClassifier
# 80    RandomForestClassifier
# 81    RandomForestClassifier
# 82    RandomForestClassifier
# 83    RandomForestClassifier
# 84    RandomForestClassifier
# 85    RandomForestClassifier
# 86    RandomForestClassifier
# 87    RandomForestClassifier
# 88    RandomForestClassifier
# 89    RandomForestClassifier
# 90    RandomForestClassifier
# 91    RandomForestClassifier
# 92    RandomForestClassifier
# 93    RandomForestClassifier
# 94    RandomForestClassifier
# 95    RandomForestClassifier
# 96    RandomForestClassifier
# 97    RandomForestClassifier
# 98    RandomForestClassifier
# 99    RandomForestClassifier
# 100   RandomForestClassifier
# 101   RandomForestClassifier
# 102   RandomForestClassifier
# 103   RandomForestClassifier
# 104   RandomForestClassifier
# 105   RandomForestClassifier
# 106   RandomForestClassifier
# 107   RandomForestClassifier
# 108   RandomForestClassifier
# 109   RandomForestClassifier
# 110   RandomForestClassifier
# 111   RandomForestClassifier
# 112   RandomForestClassifier
# 113   RandomForestClassifier
# 114   RandomForestClassifier
# 115   RandomForestClassifier
# 116   RandomForestClassifier
# 117   RandomForestClassifier
# 118   RandomForestClassifier
# 119   RandomForestClassifier
# 120   RandomForestClassifier
# 121   RandomForestClassifier
# 122   RandomForestClassifier
# 123   RandomForestClassifier
# 124   RandomForestClassifier
# 125   RandomForestClassifier
# 126   RandomForestClassifier
# 127   RandomForestClassifier
# 128   RandomForestClassifier
# 129   RandomForestClassifier
# 130   RandomForestClassifier
# 131   RandomForestClassifier
# 132   RandomForestClassifier
# 133   RandomForestClassifier
# 134   RandomForestClassifier
# 135   RandomForestClassifier
# 136   RandomForestClassifier
# 137   RandomForestClassifier
# 138   RandomForestClassifier
# 139   RandomForestClassifier
# 140   RandomForestClassifier
# 141   RandomForestClassifier
# 142   RandomForestClassifier
# 143   RandomForestClassifier
# 144   RandomForestClassifier
# 145   RandomForestClassifier
# 146   RandomForestClassifier
# 147   RandomForestClassifier
# 148   RandomForestClassifier
# 149   RandomForestClassifier
# 150   RandomForestClassifier
# 151   RandomForestClassifier
# 152   RandomForestClassifier
# 153   RandomForestClassifier
# 154   RandomForestClassifier
# 155   RandomForestClassifier
# 156   RandomForestClassifier
# 157   RandomForestClassifier
# 158   RandomForestClassifier
# 159   RandomForestClassifier
# 160   RandomForestClassifier
# 161   RandomForestClassifier
# 162   RandomForestClassifier
# 163   RandomForestClassifier
# 164   RandomForestClassifier
# 165   RandomForestClassifier
# 166   RandomForestClassifier
# 167   RandomForestClassifier
# 168   RandomForestClassifier
# 169   RandomForestClassifier
# 170   RandomForestClassifier
# 171   RandomForestClassifier
# 172   RandomForestClassifier
# 173   RandomForestClassifier
# 174   RandomForestClassifier
# 175   RandomForestClassifier
# 176   RandomForestClassifier
# 177   RandomForestClassifier
# 178   RandomForestClassifier
# 179   RandomForestClassifier
# 180   RandomForestClassifier
# 181   RandomForestClassifier
# 182   RandomForestClassifier
# 183   RandomForestClassifier
# 184   RandomForestClassifier
# 185   RandomForestClassifier
# 186   RandomForestClassifier
# 187   RandomForestClassifier
# 188   RandomForestClassifier
# 189   RandomForestClassifier
# 190   RandomForestClassifier
# 191   RandomForestClassifier
# 192   RandomForestClassifier
# 193   RandomForestClassifier
# 194   RandomForestClassifier
# 195   RandomForestClassifier
# 196   RandomForestClassifier
# 197   RandomForestClassifier

# %%
print(np.mean(df_edge_test_pipeline1["elapsed_memory"]))
print(np.mean(df_edge_test_pipeline1["elapsed_time"]))

for e in df_edge_test_pipeline1['best parameters for the complex']:
    print(e)
# Out:
# 75028.74947474748
# 1173.6455454545455
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=10), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10, n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=10), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10, n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=10, n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}

# %%
mask = df_edge_test_pipeline1['test_accuracy'] > 0.6

# Apply the mask to the DataFrame
filtered_df = df_edge_test_pipeline1[mask]
print("Mean Memory: ",np.mean(filtered_df["elapsed_memory"]))
print("Mean Time: ", np.mean(filtered_df["elapsed_time"]))

for e in filtered_df['best parameters for the complex']:
    print(e)
# Out:
# Mean Memory:  95876.1323548387
# Mean Time:  1262.4036774193544
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=10, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}

# %%
mask = df_edge_test_pipeline1['test_accuracy'] > 0.6
columns_to_keep = ['complex_type', 'max_edge_length','nb_iterations', 'elapsed_time', 'elapsed_memory', 'test_accuracy']

# Keep only the specified columns
df_edge_test_pipeline1_filtered = df_edge_test_pipeline1[columns_to_keep]
# Apply the mask to the DataFrame
filtered_df = df_edge_test_pipeline1_filtered[mask]
filtered_df
# Out:
#    complex_type  max_edge_length  nb_iterations  elapsed_time  elapsed_memory
# 0          edge         0.358031              3       924.289       24812.172  \
# 1          edge         0.661717              2      1236.627      112081.469
# 2          edge         0.585445              3      1172.248       80295.172
# 3          edge         0.496333              3      1293.219       62795.770
# 4          edge         0.668441              2      1596.168      113415.434
# 5          edge         0.671234              3      1233.926      116561.141
# 6          edge         0.364614              3       926.261       20598.227
# 7          edge         0.353158              3      1182.370       29931.305
# 8          edge         0.726875              2      1414.106      155012.613
# 9          edge         0.726875              3      1555.586      154611.320
# 10         edge         0.503620              3      1034.109       57096.082
# 11         edge         0.836201              2      1457.967      198953.895
# 12         edge         0.671234              2      1237.675      116556.375
# 13         edge         0.355923              3       969.423       24104.117
# 14         edge         0.284186              2       889.316       10451.992
# 15         edge         0.858712              2      1885.815      205436.926
# 16         edge         0.512279              3      1095.164       55036.301
# 17         edge         0.858712              3      1880.667      205246.816
# 18         edge         0.501485              2      1051.579       57208.250
# 19         edge         0.277081              3       935.718        9664.074
# 20         edge         0.517931              3      1354.568       54687.297
# 21         edge         0.741360              3      1359.259      153521.730
# 22         edge         0.731654              2      1341.635      149649.023
# 23         edge         0.732426              3      1300.524      148420.855
# 24         edge         0.575211              3      1107.605       80750.793
# 25         edge         0.579512              3      1156.686       83584.953
# 26         edge         0.503620              2      1035.554       57096.766
# 27         edge         0.844886              2      1817.183      192692.906
# 28         edge         0.370012              3       922.653       17419.137
# 29         edge         0.580863              2      1425.537       72631.516
# 30         edge         0.746055              2      1341.077      151835.676
#
#     test_accuracy
# 0        0.761905
# 1        0.761905
# 2        0.761905
# 3        0.761905
# 4        0.666667
# 5        0.666667
# 6        0.666667
# 7        0.666667
# 8        0.666667
# 9        0.666667
# 10       0.666667
# 11       0.666667
# 12       0.666667
# 13       0.666667
# 14       0.666667
# 15       0.619048
# 16       0.619048
# 17       0.619048
# 18       0.619048
# 19       0.619048
# 20       0.619048
# 21       0.619048
# 22       0.619048
# 23       0.619048
# 24       0.619048
# 25       0.619048
# 26       0.619048
# 27       0.619048
# 28       0.619048
# 29       0.619048
# 30       0.619048

# %% [markdown]
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}

# %%
filtered_df['max_edge_length'].value_counts(), filtered_df['nb_iterations'].value_counts()
# Out:
# (max_edge_length
#  0.858712    2
#  0.671234    2
#  0.726875    2
#  0.503620    2
#  0.501485    1
#  0.580863    1
#  0.370012    1
#  0.844886    1
#  0.579512    1
#  0.575211    1
#  0.732426    1
#  0.731654    1
#  0.741360    1
#  0.517931    1
#  0.277081    1
#  0.358031    1
#  0.512279    1
#  0.661717    1
#  0.284186    1
#  0.355923    1
#  0.836201    1
#  0.353158    1
#  0.364614    1
#  0.668441    1
#  0.496333    1
#  0.585445    1
#  0.746055    1
#  Name: count, dtype: int64,
#  nb_iterations
#  3    18
#  2    13
#  Name: count, dtype: int64)

# %% [markdown]
# ### results for Edge Collapse Rips Complex:
# * Best persistence representations: Persistence Image // Landscape
# * Best precision: exact
# * Mean of elapsed_time: 1156.59575
# * Mean of elapsed_memory: 69996.14 MB
# * Best test accuracy: 0.762
# * Best elapsed time for best acc:924.289 seconds
# * Best number of iterations: 3

# %% [markdown]
# ### Rips Complex :

# %%
df_rips_test_1=pd.read_csv("results2rips_6245.csv")
df_rips_test_2=pd.read_csv("results2rips_625.csv")
df_rips_test_3=pd.read_csv("results2rips_62588.csv")
df_rips_test_4=pd.read_csv("results2rips_6255558.csv")
df_rips_test_5=pd.read_csv("results2rips_89846.csv")
df_rips_test_6=pd.read_csv("results2rips_336238.csv")
df_rips_test_7=pd.read_csv("results2rips_621238.csv")
df_rips_test_8=pd.read_csv("results2rips_7644338.csv")
df_rips_test_9=pd.read_csv("results2rips_99846.csv")
df_rips_test_10=pd.read_csv("results2rips_89846.csv")
df_rips_test_10=pd.read_csv("results2rips_336238.csv")


df_rips_test_pipeline1=pd.concat([df_rips_test_1,df_rips_test_2,df_rips_test_3,df_rips_test_4,df_rips_test_5,df_rips_test_6,df_rips_test_7,df_rips_test_8,df_rips_test_9,df_rips_test_10])
df_rips_test_pipeline1=df_rips_test_pipeline1.sort_values(by="test_accuracy",ascending=False)
df_rips_test_pipeline1 = df_rips_test_pipeline1.reset_index(drop=True)
                
df_complex = pd.json_normalize(df_rips_test_pipeline1["complex_parameters"].apply(ast.literal_eval))
df_complex=df_complex.reset_index(drop=True)



df_rips_test_pipeline1 = pd.concat([df_complex, df_rips_test_pipeline1], axis=1)
df_rips_test_pipeline1['Estimator']=" RandomForestClassifier"
df_rips_test_pipeline1
# Out:
#    complex_type  max_dimension sparse  max_edge_length
# 0          rips              2   None         0.431968  \
# 1          rips              2   None         0.282771
# 2          rips              2   None         0.591743
# 3          rips              2   None         0.364614
# 4          rips              2   None         0.661717
# 5          rips              2   None         0.836042
# 6          rips              2   None         0.275171
# 7          rips              2   None         0.362385
# 8          rips              2   None         0.756757
# 9          rips              2   None         0.288394
# 10         rips              2   None         0.288394
# 11         rips              2   None         0.429650
# 12         rips              2   None         0.503620
# 13         rips              2   None         0.756757
# 14         rips              2   None         0.746055
# 15         rips              2   None         0.567462
# 16         rips              2   None         0.863527
# 17         rips              2   None         0.863527
# 18         rips              2   None         0.585445
# 19         rips              2   None         0.512279
# 20         rips              2   None         0.439468
# 21         rips              2   None         0.508263
# 22         rips              2   None         0.190465
# 23         rips              2   None         0.446094
# 24         rips              2   None         0.446094
# 25         rips              2   None         0.753060
# 26         rips              2   None         0.278639
# 27         rips              2   None         0.439020
# 28         rips              2   None         0.847134
# 29         rips              2   None         0.370012
# 30         rips              2   None         0.741360
# 31         rips              2   None         0.519768
# 32         rips              2   None         0.519768
# 33         rips              2   None         0.671234
# 34         rips              2   None         0.370012
# 35         rips              2   None         0.435037
# 36         rips              2   None         0.738313
# 37         rips              2   None         0.852741
# 38         rips              2   None         0.284282
# 39         rips              2   None         0.284186
# 40         rips              2   None         0.355923
# 41         rips              2   None         0.832011
# 42         rips              2   None         0.726875
# 43         rips              2   None         0.648507
# 44         rips              2   None         0.671234
# 45         rips              2   None         0.360889
# 46         rips              2   None         0.654961
# 47         rips              2   None         0.851250
# 48         rips              2   None         0.501485
# 49         rips              2   None         0.573518
# 50         rips              2   None         0.188862
# 51         rips              2   None         0.731654
# 52         rips              2   None         0.277081
# 53         rips              2   None         0.353158
# 54         rips              2   None         0.425860
# 55         rips              2   None         0.649735
# 56         rips              2   None         0.642946
# 57         rips              2   None         0.858712
# 58         rips              2   None         0.191933
# 59         rips              2   None         0.575211
# 60         rips              2   None         0.185702
# 61         rips              2   None         0.661309
# 62         rips              2   None         0.584920
# 63         rips              2   None         0.444201
# 64         rips              2   None         0.746140
# 65         rips              2   None         0.368151
# 66         rips              2   None         0.836201
# 67         rips              2   None         0.593858
# 68         rips              2   None         0.593858
# 69         rips              2   None         0.496333
# 70         rips              2   None         0.364314
# 71         rips              2   None         0.286635
# 72         rips              2   None         0.193332
# 73         rips              2   None         0.511730
# 74         rips              2   None         0.193332
# 75         rips              2   None         0.656895
# 76         rips              2   None         0.281477
# 77         rips              2   None         0.668441
# 78         rips              2   None         0.517931
# 79         rips              2   None         0.732426
# 80         rips              2   None         0.580828
# 81         rips              2   None         0.436307
# 82         rips              2   None         0.189922
# 83         rips              2   None         0.842572
# 84         rips              2   None         0.507096
# 85         rips              2   None         0.184333
# 86         rips              2   None         0.358031
# 87         rips              2   None         0.186441
# 88         rips              2   None         0.579512
# 89         rips              2   None         0.190604
#
#                                    complex_parameters  elapsed_time
# 0   {'complex_type': 'rips', 'max_dimension': 2, '...      4051.952  \
# 1   {'complex_type': 'rips', 'max_dimension': 2, '...      1793.627
# 2   {'complex_type': 'rips', 'max_dimension': 2, '...      8796.108
# 3   {'complex_type': 'rips', 'max_dimension': 2, '...      2523.064
# 4   {'complex_type': 'rips', 'max_dimension': 2, '...     11925.929
# 5   {'complex_type': 'rips', 'max_dimension': 2, '...     16397.743
# 6   {'complex_type': 'rips', 'max_dimension': 2, '...      2089.808
# 7   {'complex_type': 'rips', 'max_dimension': 2, '...      2592.378
# 8   {'complex_type': 'rips', 'max_dimension': 2, '...     12063.922
# 9   {'complex_type': 'rips', 'max_dimension': 2, '...      1321.127
# 10  {'complex_type': 'rips', 'max_dimension': 2, '...      1321.127
# 11  {'complex_type': 'rips', 'max_dimension': 2, '...      4477.655
# 12  {'complex_type': 'rips', 'max_dimension': 2, '...      5673.698
# 13  {'complex_type': 'rips', 'max_dimension': 2, '...     12063.922
# 14  {'complex_type': 'rips', 'max_dimension': 2, '...     16660.473
# 15  {'complex_type': 'rips', 'max_dimension': 2, '...      9166.072
# 16  {'complex_type': 'rips', 'max_dimension': 2, '...     17421.178
# 17  {'complex_type': 'rips', 'max_dimension': 2, '...     17421.178
# 18  {'complex_type': 'rips', 'max_dimension': 2, '...      7548.634
# 19  {'complex_type': 'rips', 'max_dimension': 2, '...      5125.736
# 20  {'complex_type': 'rips', 'max_dimension': 2, '...      3638.154
# 21  {'complex_type': 'rips', 'max_dimension': 2, '...      5455.381
# 22  {'complex_type': 'rips', 'max_dimension': 2, '...      1427.312
# 23  {'complex_type': 'rips', 'max_dimension': 2, '...      3027.101
# 24  {'complex_type': 'rips', 'max_dimension': 2, '...      3027.101
# 25  {'complex_type': 'rips', 'max_dimension': 2, '...     16641.602
# 26  {'complex_type': 'rips', 'max_dimension': 2, '...      2541.173
# 27  {'complex_type': 'rips', 'max_dimension': 2, '...      2160.666
# 28  {'complex_type': 'rips', 'max_dimension': 2, '...     16988.055
# 29  {'complex_type': 'rips', 'max_dimension': 2, '...      1995.277
# 30  {'complex_type': 'rips', 'max_dimension': 2, '...     13078.006
# 31  {'complex_type': 'rips', 'max_dimension': 2, '...      4572.085
# 32  {'complex_type': 'rips', 'max_dimension': 2, '...      4572.085
# 33  {'complex_type': 'rips', 'max_dimension': 2, '...      9077.914
# 34  {'complex_type': 'rips', 'max_dimension': 2, '...      1995.277
# 35  {'complex_type': 'rips', 'max_dimension': 2, '...      3979.767
# 36  {'complex_type': 'rips', 'max_dimension': 2, '...     12756.287
# 37  {'complex_type': 'rips', 'max_dimension': 2, '...     11195.007
# 38  {'complex_type': 'rips', 'max_dimension': 2, '...      1003.727
# 39  {'complex_type': 'rips', 'max_dimension': 2, '...      1781.989
# 40  {'complex_type': 'rips', 'max_dimension': 2, '...      3206.084
# 41  {'complex_type': 'rips', 'max_dimension': 2, '...     24636.766
# 42  {'complex_type': 'rips', 'max_dimension': 2, '...     16943.494
# 43  {'complex_type': 'rips', 'max_dimension': 2, '...     11646.228
# 44  {'complex_type': 'rips', 'max_dimension': 2, '...      9077.914
# 45  {'complex_type': 'rips', 'max_dimension': 2, '...      3032.289
# 46  {'complex_type': 'rips', 'max_dimension': 2, '...      9938.472
# 47  {'complex_type': 'rips', 'max_dimension': 2, '...     19816.396
# 48  {'complex_type': 'rips', 'max_dimension': 2, '...      6107.065
# 49  {'complex_type': 'rips', 'max_dimension': 2, '...      8223.067
# 50  {'complex_type': 'rips', 'max_dimension': 2, '...      1773.281
# 51  {'complex_type': 'rips', 'max_dimension': 2, '...     15794.165
# 52  {'complex_type': 'rips', 'max_dimension': 2, '...      2216.549
# 53  {'complex_type': 'rips', 'max_dimension': 2, '...      2914.020
# 54  {'complex_type': 'rips', 'max_dimension': 2, '...      4046.006
# 55  {'complex_type': 'rips', 'max_dimension': 2, '...      9719.034
# 56  {'complex_type': 'rips', 'max_dimension': 2, '...     12166.129
# 57  {'complex_type': 'rips', 'max_dimension': 2, '...     21874.915
# 58  {'complex_type': 'rips', 'max_dimension': 2, '...      1473.155
# 59  {'complex_type': 'rips', 'max_dimension': 2, '...      7384.840
# 60  {'complex_type': 'rips', 'max_dimension': 2, '...      1700.767
# 61  {'complex_type': 'rips', 'max_dimension': 2, '...      6010.080
# 62  {'complex_type': 'rips', 'max_dimension': 2, '...      4449.586
# 63  {'complex_type': 'rips', 'max_dimension': 2, '...      4483.982
# 64  {'complex_type': 'rips', 'max_dimension': 2, '...      8043.883
# 65  {'complex_type': 'rips', 'max_dimension': 2, '...      2872.832
# 66  {'complex_type': 'rips', 'max_dimension': 2, '...     17993.646
# 67  {'complex_type': 'rips', 'max_dimension': 2, '...      6465.836
# 68  {'complex_type': 'rips', 'max_dimension': 2, '...      6465.836
# 69  {'complex_type': 'rips', 'max_dimension': 2, '...      5928.494
# 70  {'complex_type': 'rips', 'max_dimension': 2, '...      1463.312
# 71  {'complex_type': 'rips', 'max_dimension': 2, '...      2048.320
# 72  {'complex_type': 'rips', 'max_dimension': 2, '...       955.155
# 73  {'complex_type': 'rips', 'max_dimension': 2, '...      3153.261
# 74  {'complex_type': 'rips', 'max_dimension': 2, '...       955.155
# 75  {'complex_type': 'rips', 'max_dimension': 2, '...     10286.573
# 76  {'complex_type': 'rips', 'max_dimension': 2, '...      2293.329
# 77  {'complex_type': 'rips', 'max_dimension': 2, '...     12164.555
# 78  {'complex_type': 'rips', 'max_dimension': 2, '...      6566.259
# 79  {'complex_type': 'rips', 'max_dimension': 2, '...     12541.017
# 80  {'complex_type': 'rips', 'max_dimension': 2, '...      7179.970
# 81  {'complex_type': 'rips', 'max_dimension': 2, '...      3753.498
# 82  {'complex_type': 'rips', 'max_dimension': 2, '...      1354.073
# 83  {'complex_type': 'rips', 'max_dimension': 2, '...     17199.399
# 84  {'complex_type': 'rips', 'max_dimension': 2, '...      5643.181
# 85  {'complex_type': 'rips', 'max_dimension': 2, '...      1725.006
# 86  {'complex_type': 'rips', 'max_dimension': 2, '...      3112.715
# 87  {'complex_type': 'rips', 'max_dimension': 2, '...      1984.033
# 88  {'complex_type': 'rips', 'max_dimension': 2, '...      7715.018
# 89  {'complex_type': 'rips', 'max_dimension': 2, '...       760.475
#
#     time for diagram computation  time for pipeline creation
# 0                       3203.224                       0.000  \
# 1                        955.274                       0.000
# 2                       7687.874                       0.000
# 3                       1634.997                       0.000
# 4                      11036.550                       0.000
# 5                      15570.073                       0.001
# 6                       1242.662                       0.000
# 7                       1758.003                       0.000
# 8                      11213.172                       0.000
# 9                        461.825                       0.000
# 10                       461.825                       0.000
# 11                      3634.068                       0.000
# 12                      4836.218                       0.000
# 13                     11213.172                       0.000
# 14                     15773.462                       0.000
# 15                      8312.038                       0.000
# 16                     16564.252                       0.000
# 17                     16564.252                       0.000
# 18                      6665.669                       0.000
# 19                      4240.977                       0.000
# 20                      2753.162                       0.000
# 21                      4621.202                       0.000
# 22                       537.414                       0.000
# 23                      2168.124                       0.000
# 24                      2168.124                       0.000
# 25                     15537.435                       0.001
# 26                      1601.076                       0.000
# 27                      1565.715                       0.000
# 28                     16160.408                       0.000
# 29                      1138.300                       0.000
# 30                     12252.209                       0.000
# 31                      3712.719                       0.000
# 32                      3712.719                       0.000
# 33                      8218.980                       0.000
# 34                      1138.300                       0.000
# 35                      3088.396                       0.000
# 36                     11860.511                       0.000
# 37                     10577.613                       0.000
# 38                       411.499                       0.000
# 39                       899.623                       0.000
# 40                      2314.892                       0.000
# 41                     23579.449                       0.000
# 42                     15873.332                       0.001
# 43                     10806.183                       0.000
# 44                      8218.980                       0.000
# 45                      2138.119                       0.000
# 46                      9040.696                       0.001
# 47                     18965.231                       0.000
# 48                      5215.944                       0.000
# 49                      7333.390                       0.000
# 50                       773.998                       0.000
# 51                     14954.651                       0.000
# 52                      1327.975                       0.000
# 53                      2063.633                       0.000
# 54                      3199.697                       0.000
# 55                      8886.360                       0.000
# 56                     11320.146                       0.000
# 57                     20767.816                       0.001
# 58                       357.347                       0.000
# 59                      6547.318                       0.000
# 60                       809.689                       0.000
# 61                      5416.182                       0.000
# 62                      3856.154                       0.000
# 63                      3373.861                       0.000
# 64                      7428.039                       0.000
# 65                      1760.844                       0.000
# 66                     17151.378                       0.000
# 67                      5605.682                       0.000
# 68                      5605.682                       0.000
# 69                      5083.820                       0.000
# 70                       869.410                       0.000
# 71                       943.959                       0.000
# 72                        95.727                       0.000
# 73                      2560.567                       0.000
# 74                        95.727                       0.000
# 75                      9459.702                       0.000
# 76                      1305.431                       0.000
# 77                     11057.429                       0.000
# 78                      5455.177                       0.000
# 79                     11715.484                       0.000
# 80                      6352.938                       0.000
# 81                      2923.597                       0.000
# 82                       515.454                       0.000
# 83                     16301.753                       0.000
# 84                      4764.589                       0.000
# 85                       833.432                       0.000
# 86                      2271.038                       0.001
# 87                      1032.990                       0.000
# 88                      6820.864                       0.000
# 89                       163.312                       0.000
#
#     time for pipeline fitting and testing  elapsed_memory
# 0                                     849             inf  \
# 1                                     838             inf
# 2                                    1108             inf
# 3                                     888             inf
# 4                                     889             inf
# 5                                     828             inf
# 6                                     847             inf
# 7                                     834             inf
# 8                                     851             inf
# 9                                     859             inf
# 10                                    859             inf
# 11                                    844             inf
# 12                                    837             inf
# 13                                    851             inf
# 14                                    887             inf
# 15                                    854             inf
# 16                                    857             inf
# 17                                    857             inf
# 18                                    883             inf
# 19                                    885             inf
# 20                                    885             inf
# 21                                    834             inf
# 22                                    890             inf
# 23                                    859             inf
# 24                                    859             inf
# 25                                   1104             inf
# 26                                    940             inf
# 27                                    595             inf
# 28                                    828             inf
# 29                                    857             inf
# 30                                    826             inf
# 31                                    859             inf
# 32                                    859             inf
# 33                                    859             inf
# 34                                    857             inf
# 35                                    891             inf
# 36                                    896             inf
# 37                                    617             inf
# 38                                    592             inf
# 39                                    882             inf
# 40                                    891             inf
# 41                                   1057             inf
# 42                                   1070             inf
# 43                                    840             inf
# 44                                    859             inf
# 45                                    894             inf
# 46                                    898             inf
# 47                                    851             inf
# 48                                    891             inf
# 49                                    890             inf
# 50                                    999             inf
# 51                                    840             inf
# 52                                    889             inf
# 53                                    850             inf
# 54                                    846             inf
# 55                                    833             inf
# 56                                    846             inf
# 57                                   1107             inf
# 58                                   1116             inf
# 59                                    838             inf
# 60                                    891             inf
# 61                                    594             inf
# 62                                    593             inf
# 63                                   1110             inf
# 64                                    616             inf
# 65                                   1112             inf
# 66                                    842             inf
# 67                                    860             inf
# 68                                    860             inf
# 69                                    845             inf
# 70                                    594             inf
# 71                                   1104             inf
# 72                                    859             inf
# 73                                    593             inf
# 74                                    859             inf
# 75                                    827             inf
# 76                                    988             inf
# 77                                   1107             inf
# 78                                   1111             inf
# 79                                    826             inf
# 80                                    827             inf
# 81                                    830             inf
# 82                                    839             inf
# 83                                    898             inf
# 84                                    879             inf
# 85                                    892             inf
# 86                                    842             inf
# 87                                    951             inf
# 88                                    894             inf
# 89                                    597             inf
#
#     memory for diagram computation  memory for pipeline creation
# 0                              inf                           0.0  \
# 1                              inf                           0.0
# 2                              inf                           0.0
# 3                              inf                           0.0
# 4                              inf                           0.0
# 5                              inf                           0.0
# 6                              inf                           0.0
# 7                              inf                           0.0
# 8                              inf                           0.0
# 9                              inf                           0.0
# 10                             inf                           0.0
# 11                             inf                           0.0
# 12                             inf                           0.0
# 13                             inf                           0.0
# 14                             inf                           0.0
# 15                             inf                           0.0
# 16                             inf                           0.0
# 17                             inf                           0.0
# 18                             inf                           0.0
# 19                             inf                           0.0
# 20                             inf                           0.0
# 21                             inf                           0.0
# 22                             inf                           0.0
# 23                             inf                           0.0
# 24                             inf                           0.0
# 25                             inf                           0.0
# 26                             inf                           0.0
# 27                             inf                           0.0
# 28                             inf                           0.0
# 29                             inf                           0.0
# 30                             inf                           0.0
# 31                             inf                           0.0
# 32                             inf                           0.0
# 33                             inf                           0.0
# 34                             inf                           0.0
# 35                             inf                           0.0
# 36                             inf                           0.0
# 37                             inf                           0.0
# 38                             inf                           0.0
# 39                             inf                           0.0
# 40                             inf                           0.0
# 41                             inf                           0.0
# 42                             inf                           0.0
# 43                             inf                           0.0
# 44                             inf                           0.0
# 45                             inf                           0.0
# 46                             inf                           0.0
# 47                             inf                           0.0
# 48                             inf                           0.0
# 49                             inf                           0.0
# 50                             inf                           0.0
# 51                             inf                           0.0
# 52                             inf                           0.0
# 53                             inf                           0.0
# 54                             inf                           0.0
# 55                             inf                           0.0
# 56                             inf                           0.0
# 57                             inf                           0.0
# 58                             inf                           0.0
# 59                             inf                           0.0
# 60                             inf                           0.0
# 61                             inf                           0.0
# 62                             inf                           0.0
# 63                             inf                           0.0
# 64                             inf                           0.0
# 65                             inf                           0.0
# 66                             inf                           0.0
# 67                             inf                           0.0
# 68                             inf                           0.0
# 69                             inf                           0.0
# 70                             inf                           0.0
# 71                             inf                           0.0
# 72                             inf                           0.0
# 73                             inf                           0.0
# 74                             inf                           0.0
# 75                             inf                           0.0
# 76                             inf                           0.0
# 77                             inf                           0.0
# 78                             inf                           0.0
# 79                             inf                           0.0
# 80                             inf                           0.0
# 81                             inf                           0.0
# 82                             inf                           0.0
# 83                             inf                           0.0
# 84                             inf                           0.0
# 85                             inf                           0.0
# 86                             inf                           0.0
# 87                             inf                           0.0
# 88                             inf                           0.0
# 89                             inf                           0.0
#
#     memory for pipeline fitting and testing  test_accuracy
# 0                                         0       0.714286  \
# 1                                         0       0.714286
# 2                                         0       0.666667
# 3                                         0       0.666667
# 4                                       268       0.666667
# 5                                         0       0.666667
# 6                                         0       0.619048
# 7                                         0       0.619048
# 8                                         1       0.619048
# 9                                         0       0.619048
# 10                                        0       0.619048
# 11                                        0       0.619048
# 12                                        0       0.619048
# 13                                        1       0.619048
# 14                                        0       0.619048
# 15                                        0       0.571429
# 16                                        0       0.571429
# 17                                        0       0.571429
# 18                                        0       0.571429
# 19                                        0       0.571429
# 20                                        0       0.571429
# 21                                        0       0.571429
# 22                                        2       0.571429
# 23                                        0       0.523810
# 24                                        0       0.523810
# 25                                        0       0.523810
# 26                                     4803       0.523810
# 27                                        0       0.523810
# 28                                        0       0.523810
# 29                                        0       0.523810
# 30                                        1       0.523810
# 31                                        0       0.523810
# 32                                        0       0.523810
# 33                                        0       0.523810
# 34                                        0       0.523810
# 35                                        0       0.523810
# 36                                        0       0.523810
# 37                                        0       0.523810
# 38                                        0       0.523810
# 39                                        0       0.523810
# 40                                      329       0.523810
# 41                                        0       0.523810
# 42                                        0       0.523810
# 43                                        1       0.523810
# 44                                        0       0.523810
# 45                                        0       0.476190
# 46                                        0       0.476190
# 47                                        0       0.476190
# 48                                        0       0.476190
# 49                                        0       0.476190
# 50                                        2       0.476190
# 51                                        0       0.476190
# 52                                        0       0.476190
# 53                                        0       0.476190
# 54                                        0       0.476190
# 55                                        0       0.476190
# 56                                        0       0.476190
# 57                                        0       0.476190
# 58                                        2       0.476190
# 59                                        0       0.476190
# 60                                        2       0.428571
# 61                                        0       0.428571
# 62                                        0       0.428571
# 63                                        0       0.428571
# 64                                        0       0.428571
# 65                                        0       0.428571
# 66                                        3       0.428571
# 67                                        0       0.428571
# 68                                        0       0.428571
# 69                                        0       0.428571
# 70                                        0       0.428571
# 71                                        0       0.428571
# 72                                        2       0.380952
# 73                                        0       0.380952
# 74                                        2       0.380952
# 75                                        0       0.380952
# 76                                        0       0.380952
# 77                                        0       0.380952
# 78                                        0       0.380952
# 79                                        0       0.380952
# 80                                        1       0.333333
# 81                                        0       0.333333
# 82                                        2       0.333333
# 83                                        0       0.333333
# 84                                        0       0.333333
# 85                                        2       0.333333
# 86                                        0       0.333333
# 87                                        2       0.333333
# 88                                        0       0.238095
# 89                                        2       0.190476
#
#                       best parameters for the complex                Estimator
# 0   {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 1   {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 2   {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 3   {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 4   {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 5   {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 6   {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 7   {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 8   {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 9   {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 10  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 11  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 12  {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 13  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 14  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 15  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 16  {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 17  {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 18  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 19  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 20  {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 21  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 22  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 23  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 24  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 25  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 26  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 27  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 28  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 29  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 30  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 31  {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 32  {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 33  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 34  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 35  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 36  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 37  {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 38  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 39  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 40  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 41  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 42  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 43  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 44  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 45  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 46  {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 47  {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 48  {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 49  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 50  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 51  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 52  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 53  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 54  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 55  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 56  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 57  {'Estimator': RandomForestClassifier(), 'Estim...   RandomForestClassifier
# 58  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 59  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 60  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 61  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 62  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 63  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 64  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 65  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 66  {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 67  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 68  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 69  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 70  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 71  {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 72  {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 73  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 74  {'Estimator': RandomForestClassifier(n_estimat...   RandomForestClassifier
# 75  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 76  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 77  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 78  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 79  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 80  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 81  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 82  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 83  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 84  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 85  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 86  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier
# 87  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 88  {'Estimator': RandomForestClassifier(min_sampl...   RandomForestClassifier
# 89  {'Estimator': RandomForestClassifier(max_depth...   RandomForestClassifier

# %%
print("Mean Memory:",np.mean(df_rips_test_pipeline1["elapsed_memory"]))
print("Mean Time :",np.mean(df_rips_test_pipeline1["elapsed_time"]))

for e in df_rips_test_pipeline1['best parameters for the complex']:
    print(e)
# Out:
# Mean Memory: inf
# Mean Time : 7117.8712444444445
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=10, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=200), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=5, n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_split=10), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4, min_samples_split=10), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=200), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}

# %%
mask = df_rips_test_pipeline1['test_accuracy'] > 0.6

# Apply the mask to the DataFrame
filtered_df = df_rips_test_pipeline1[mask]
print("Mean Memory: ",np.mean(filtered_df["elapsed_memory"]))
print("Mean Time: ", np.mean(filtered_df["elapsed_time"]))
print(filtered_df["max_edge_length"].value_counts())
for e in filtered_df['best parameters for the complex']:
    print(e)
# Out:
# Mean Memory:  inf
# Mean Time:  6916.835533333334
# max_edge_length
# 0.756757    2
# 0.288394    2
# 0.431968    1
# 0.282771    1
# 0.591743    1
# 0.364614    1
# 0.661717    1
# 0.836042    1
# 0.275171    1
# 0.362385    1
# 0.429650    1
# 0.503620    1
# 0.746055    1
# Name: count, dtype: int64
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_split=5), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_split=5, n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=4, n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(min_samples_leaf=4), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 4, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 100, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# {'Estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=50), 'Estimator__max_depth': 10, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 5, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(n_estimators=200), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 1, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 200, 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# {'Estimator': RandomForestClassifier(min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=50), 'Estimator__max_depth': None, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 10, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# {'Estimator': RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=50), 'Estimator__max_depth': 5, 'Estimator__min_samples_leaf': 2, 'Estimator__min_samples_split': 2, 'Estimator__n_estimators': 50, 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}

# %%
mask = df_rips_test_pipeline1['test_accuracy'] > 0.6
columns_to_keep = ['complex_type', 'max_edge_length', 'elapsed_time', 'elapsed_memory', 'test_accuracy']
df_rips_test_pipeline1_filtered = df_rips_test_pipeline1[columns_to_keep]

# Apply the mask to the DataFrame
filtered_df = df_rips_test_pipeline1_filtered[mask]
filtered_df
# Out:
#    complex_type  max_edge_length  elapsed_time  elapsed_memory  test_accuracy
# 0          rips         0.431968      4051.952             inf       0.714286
# 1          rips         0.282771      1793.627             inf       0.714286
# 2          rips         0.591743      8796.108             inf       0.666667
# 3          rips         0.364614      2523.064             inf       0.666667
# 4          rips         0.661717     11925.929             inf       0.666667
# 5          rips         0.836042     16397.743             inf       0.666667
# 6          rips         0.275171      2089.808             inf       0.619048
# 7          rips         0.362385      2592.378             inf       0.619048
# 8          rips         0.756757     12063.922             inf       0.619048
# 9          rips         0.288394      1321.127             inf       0.619048
# 10         rips         0.288394      1321.127             inf       0.619048
# 11         rips         0.429650      4477.655             inf       0.619048
# 12         rips         0.503620      5673.698             inf       0.619048
# 13         rips         0.756757     12063.922             inf       0.619048
# 14         rips         0.746055     16660.473             inf       0.619048

# %% [markdown]
# ### results for Edge Collapse Rips Complex:
# * Best persistence representations: Persistence Image // Landscape
# * Best precision: exact
# * Mean of elapsed_time: 1156.59575
# * Mean of elapsed_memory: 69996.14 MB
# * Best test accuracy: 0.762
# * Best elapsed time for best acc:924.289 seconds
# * Best number of iterations: 3
