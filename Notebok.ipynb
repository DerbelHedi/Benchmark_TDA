# %% [markdown]
# ### This notebook is to explain how to use this
#  script_final is the function to run in the cluster, and get all the results from it , depending on the parameter of the complex

# %%
from ClusterFile import script_final
complex_params = {
    'complex_type': ['alpha'],
    'precision': ['safe','exact']}

# %%
script_final(complex_params)
# Out:
# TEST STARTED FOR :complex_alpha_parameters:  {'complex_type': 'alpha', 'precision': 'safe'}
# ST 1 computation time: 1.90 seconds
# ST 1 Memory used: 0.00 MB
# persistence computation time: :1.84 seconds
#
#
#
# ST 2 computation time: 2.35 seconds
# ST 2 Memory used: 0.05 MB
# persistence computation time: :2.22 seconds
#
#
#
# ST 3 computation time: 1.47 seconds
# ST 3 Memory used: 0.00 MB
# persistence computation time: :1.81 seconds
#
#
#
# ST 4 computation time: 1.45 seconds
# ST 4 Memory used: 0.00 MB
# persistence computation time: :2.38 seconds
#
#
#
# ST 5 computation time: 1.46 seconds
# ST 5 Memory used: 0.00 MB
# persistence computation time: :1.94 seconds
#
#
#
# ST 6 computation time: 1.46 seconds
# ST 6 Memory used: 0.00 MB
# persistence computation time: :1.46 seconds
#
#
#
# ST 7 computation time: 1.45 seconds
# ST 7 Memory used: 0.00 MB
# persistence computation time: :2.37 seconds
#
#
#
# ST 8 computation time: 1.49 seconds
# ST 8 Memory used: 0.00 MB
# persistence computation time: :1.50 seconds
#
#
#
# ST 9 computation time: 1.50 seconds
# ST 9 Memory used: 0.00 MB
# persistence computation time: :1.47 seconds
#
#
#
# ST 10 computation time: 1.47 seconds
# ST 10 Memory used: 0.00 MB
# persistence computation time: :1.48 seconds
#
#
#
# ST 11 computation time: 1.46 seconds
# ST 11 Memory used: 0.00 MB
# persistence computation time: :1.45 seconds
#
#
#
# ST 12 computation time: 1.94 seconds
# ST 12 Memory used: 0.00 MB
# persistence computation time: :1.46 seconds
#
#
#
# ST 13 computation time: 1.46 seconds
# ST 13 Memory used: 0.00 MB
# persistence computation time: :1.48 seconds
#
#
#
# ST 14 computation time: 1.44 seconds
# ST 14 Memory used: 0.00 MB
# persistence computation time: :1.90 seconds
#
#
#
# ST 15 computation time: 1.53 seconds
# ST 15 Memory used: 0.00 MB
# persistence computation time: :1.50 seconds
#
#
#
# ST 16 computation time: 3.12 seconds
# ST 16 Memory used: 0.00 MB
# persistence computation time: :2.84 seconds
#
#
#
# ST 17 computation time: 2.32 seconds
# ST 17 Memory used: 0.00 MB
# persistence computation time: :1.49 seconds
#
#
#
# ST 18 computation time: 1.48 seconds
# ST 18 Memory used: 0.00 MB
# persistence computation time: :2.35 seconds
#
#
#
# ST 19 computation time: 1.46 seconds
# ST 19 Memory used: 0.00 MB
# persistence computation time: :1.54 seconds
#
#
#
# ST 20 computation time: 1.46 seconds
# ST 20 Memory used: 0.00 MB
# persistence computation time: :1.92 seconds
#
#
#
# ST 21 computation time: 1.49 seconds
# ST 21 Memory used: 0.00 MB
# persistence computation time: :1.46 seconds
#
#
#
# ST 22 computation time: 1.49 seconds
# ST 22 Memory used: 0.00 MB
# persistence computation time: :1.48 seconds
#
#
#
# ST 23 computation time: 1.45 seconds
# ST 23 Memory used: 0.00 MB
# persistence computation time: :1.47 seconds
#
#
#
# ST 24 computation time: 1.48 seconds
# ST 24 Memory used: 0.00 MB
# persistence computation time: :1.47 seconds
#
#
#
# ST 25 computation time: 1.46 seconds
# ST 25 Memory used: 0.00 MB
# persistence computation time: :1.48 seconds
#
#
#
# ST 26 computation time: 1.46 seconds
# ST 26 Memory used: 0.00 MB
# persistence computation time: :1.46 seconds
#
#
#
# ST 27 computation time: 1.57 seconds
# ST 27 Memory used: 0.01 MB
# persistence computation time: :1.47 seconds
#
#
#
# ST 28 computation time: 1.46 seconds
# ST 28 Memory used: 0.00 MB
# persistence computation time: :1.44 seconds
#
#
#
# ST 29 computation time: 1.48 seconds
# ST 29 Memory used: 0.00 MB
# persistence computation time: :1.91 seconds
#
#
#
# ST 30 computation time: 1.45 seconds
# ST 30 Memory used: 0.00 MB
# persistence computation time: :1.44 seconds
#
#
#
# Time used for diagrams computation and persistence:  99.96107602119446 seconds
# Memory used for diagrams computation and persistence: 0.09 MB
# Time used for pipeline creation:  1.4475767612457275 seconds
# Memory used for diagrams computation and persistence: 0.00 MB
# GridSearchCV(cv=4, error_score='raise',
#              estimator=Pipeline(steps=[('Separator', DiagramSelector()),
#                                        ('Scaler',
#                                         DiagramScaler(scalers=[([0, 1],
#                                                                 MinMaxScaler())])),
#                                        ('TDA', PersistenceImage()),
#                                        ('Estimator',
#                                         RandomForestClassifier())]),
#              param_grid=[{'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [Landscape()],
#                           'TDA__resolution': [100]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [PersistenceImage()],
#                           'TDA__bandwidth': [0.01, 0.1, 1.0, 10.0],
#                           'TDA__resolution': [[5, 5], [6, 6]]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [False], 'TDA': [BottleneckDistance()],
#                           'TDA__epsilon': [0.1]}])
# /Users/hediderbel/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=4.
#   warnings.warn(
# model best parameters {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.01, resolution=[6, 6]), 'TDA__bandwidth': 0.01, 'TDA__resolution': [6, 6]}
# Train accuracy = 1.0
# Test accuracy  = 0.0
# /Users/hediderbel/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=4.
#   warnings.warn(
# model best parameters {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.01, resolution=[6, 6]), 'TDA__bandwidth': 0.01, 'TDA__resolution': [6, 6]}
# Train accuracy = 1.0
# Test accuracy  = 0.0
# Launch_benchmark computation time: :8.52 seconds
#
#
#
# TEST RESULT FOR PARAMETERS :  {'complex_type': 'alpha', 'precision': 'safe'}
# Test for the parameters: {'complex_type': 'alpha', 'precision': 'safe'} took 118.04 seconds
# ============================================================================================================================================
# ============================================================================================================================================
# ============================================================================================================================================
# TEST STARTED FOR :complex_alpha_parameters:  {'complex_type': 'alpha', 'precision': 'exact'}
# ST 1 computation time: 1.69 seconds
# ST 1 Memory used: 0.00 MB
# persistence computation time: :1.59 seconds
#
#
#
# ST 2 computation time: 1.67 seconds
# ST 2 Memory used: 0.00 MB
# persistence computation time: :1.59 seconds
#
#
#
# ST 3 computation time: 1.65 seconds
# ST 3 Memory used: 0.00 MB
# persistence computation time: :1.74 seconds
#
#
#
# ST 4 computation time: 1.66 seconds
# ST 4 Memory used: 0.02 MB
# persistence computation time: :1.60 seconds
#
#
#
# ST 5 computation time: 1.66 seconds
# ST 5 Memory used: 0.00 MB
# persistence computation time: :1.62 seconds
#
#
#
# ST 6 computation time: 1.60 seconds
# ST 6 Memory used: 0.00 MB
# persistence computation time: :1.59 seconds
#
#
#
# ST 7 computation time: 1.60 seconds
# ST 7 Memory used: 0.02 MB
# persistence computation time: :1.60 seconds
#
#
#
# ST 8 computation time: 1.60 seconds
# ST 8 Memory used: 0.00 MB
# persistence computation time: :1.72 seconds
#
#
#
# ST 9 computation time: 1.62 seconds
# ST 9 Memory used: 0.02 MB
# persistence computation time: :1.59 seconds
#
#
#
# ST 10 computation time: 1.63 seconds
# ST 10 Memory used: 0.00 MB
# persistence computation time: :1.59 seconds
#
#
#
# ST 11 computation time: 1.62 seconds
# ST 11 Memory used: 0.04 MB
# persistence computation time: :1.60 seconds
#
#
#
# ST 12 computation time: 1.62 seconds
# ST 12 Memory used: 0.00 MB
# persistence computation time: :1.58 seconds
#
#
#
# ST 13 computation time: 1.58 seconds
# ST 13 Memory used: 0.00 MB
# persistence computation time: :1.68 seconds
#
#
#
# ST 14 computation time: 1.61 seconds
# ST 14 Memory used: 0.00 MB
# persistence computation time: :1.60 seconds
#
#
#
# ST 15 computation time: 1.59 seconds
# ST 15 Memory used: 0.00 MB
# persistence computation time: :1.63 seconds
#
#
#
# ST 16 computation time: 1.58 seconds
# ST 16 Memory used: 0.00 MB
# persistence computation time: :1.58 seconds
#
#
#
# ST 17 computation time: 1.63 seconds
# ST 17 Memory used: 0.00 MB
# persistence computation time: :1.58 seconds
#
#
#
# ST 18 computation time: 1.61 seconds
# ST 18 Memory used: 0.00 MB
# persistence computation time: :1.69 seconds
#
#
#
# ST 19 computation time: 1.63 seconds
# ST 19 Memory used: 0.00 MB
# persistence computation time: :1.57 seconds
#
#
#
# ST 20 computation time: 1.58 seconds
# ST 20 Memory used: 0.00 MB
# persistence computation time: :2.08 seconds
#
#
#
# ST 21 computation time: 1.63 seconds
# ST 21 Memory used: 0.00 MB
# persistence computation time: :1.58 seconds
#
#
#
# ST 22 computation time: 1.66 seconds
# ST 22 Memory used: 0.00 MB
# persistence computation time: :1.59 seconds
#
#
#
# ST 23 computation time: 1.63 seconds
# ST 23 Memory used: 0.00 MB
# persistence computation time: :1.62 seconds
#
#
#
# ST 24 computation time: 1.74 seconds
# ST 24 Memory used: 0.00 MB
# persistence computation time: :1.58 seconds
#
#
#
# ST 25 computation time: 1.63 seconds
# ST 25 Memory used: 0.00 MB
# persistence computation time: :1.58 seconds
#
#
#
# ST 26 computation time: 1.62 seconds
# ST 26 Memory used: 0.00 MB
# persistence computation time: :1.61 seconds
#
#
#
# ST 27 computation time: 1.64 seconds
# ST 27 Memory used: 0.00 MB
# persistence computation time: :1.60 seconds
#
#
#
# ST 28 computation time: 1.62 seconds
# ST 28 Memory used: 0.00 MB
# persistence computation time: :2.08 seconds
#
#
#
# ST 29 computation time: 1.73 seconds
# ST 29 Memory used: 0.00 MB
# persistence computation time: :1.59 seconds
#
#
#
# ST 30 computation time: 1.62 seconds
# ST 30 Memory used: 0.00 MB
# persistence computation time: :1.59 seconds
#
#
#
# Time used for diagrams computation and persistence:  98.21132564544678 seconds
# Memory used for diagrams computation and persistence: 0.11 MB
# Time used for pipeline creation:  1.6187880039215088 seconds
# Memory used for diagrams computation and persistence: 0.00 MB
# GridSearchCV(cv=4, error_score='raise',
#              estimator=Pipeline(steps=[('Separator', DiagramSelector()),
#                                        ('Scaler',
#                                         DiagramScaler(scalers=[([0, 1],
#                                                                 MinMaxScaler())])),
#                                        ('TDA', PersistenceImage()),
#                                        ('Estimator',
#                                         RandomForestClassifier())]),
#              param_grid=[{'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [Landscape()],
#                           'TDA__resolution': [100]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [PersistenceImage()],
#                           'TDA__bandwidth': [0.01, 0.1, 1.0, 10.0],
#                           'TDA__resolution': [[5, 5], [6, 6]]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [False], 'TDA': [BottleneckDistance()],
#                           'TDA__epsilon': [0.1]}])
# model best parameters {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.01, resolution=[5, 5]), 'TDA__bandwidth': 0.01, 'TDA__resolution': [5, 5]}
# Train accuracy = 1.0
# Test accuracy  = 0.3333333333333333
# model best parameters {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.01, resolution=[5, 5]), 'TDA__bandwidth': 0.01, 'TDA__resolution': [5, 5]}
# Train accuracy = 1.0
# Test accuracy  = 0.3333333333333333
# Launch_benchmark computation time: :8.39 seconds
#
#
#
# TEST RESULT FOR PARAMETERS :  {'complex_type': 'alpha', 'precision': 'exact'}
# Test for the parameters: {'complex_type': 'alpha', 'precision': 'exact'} took 116.41 seconds
# ============================================================================================================================================
# ============================================================================================================================================
# ============================================================================================================================================
# Time consumed after the whole script 234.444 seconds
# Memory consumed for the whole script 2.078 MB
# Best Complex  Parameters: {'complex_type': 'alpha', 'precision': 'exact'}
# Best Grid Search Parameters: {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.01, resolution=[5, 5]), 'TDA__bandwidth': 0.01, 'TDA__resolution': [5, 5]}
# Best Test Accuracy: 0.3333333333333333
#                           complex_alpha_parameters  elapsed_time
# 0   {'complex_type': 'alpha', 'precision': 'safe'}    118.038533  \
# 1  {'complex_type': 'alpha', 'precision': 'exact'}    116.405416
#
#    test_accuracy                                           best_par
# 0       0.000000  {'Estimator': RandomForestClassifier(), 'Scale...  \
# 1       0.333333  {'Estimator': RandomForestClassifier(), 'Scale...
#
#    elapsed_memory
# 0        1.937500
# 1        0.140625
