# %% [markdown]
# ### This notebook is to explain how to use this
#  script_final is the function to run in the cluster, and get all the results from it , depending on the parameter of the complex

# %%
from ClusterFile import script_final
complex_params = {
    'complex_type': ['alpha'],
    'precision': ['safe','fast']}

# %%
script_final(complex_params)
# Out:
# TEST STARTED FOR :complex_alpha_parameters:  {'complex_type': 'alpha', 'precision': 'safe'}
# ST 1 computation time: 2.57 seconds
# ST 1 Memory used: 0.03 MB
# persistence computation time: :2.75 seconds
#
#
#
# ST 2 computation time: 1.65 seconds
# ST 2 Memory used: 0.00 MB
# persistence computation time: :1.69 seconds
#
#
#
# ST 3 computation time: 1.70 seconds
# ST 3 Memory used: 0.00 MB
# persistence computation time: :3.67 seconds
#
#
#
# ST 4 computation time: 1.60 seconds
# ST 4 Memory used: 0.00 MB
# persistence computation time: :1.64 seconds
#
#
#
# ST 5 computation time: 1.65 seconds
# ST 5 Memory used: 0.00 MB
# persistence computation time: :2.15 seconds
#
#
#
# ST 6 computation time: 1.66 seconds
# ST 6 Memory used: 0.03 MB
# persistence computation time: :1.59 seconds
#
#
#
# ST 7 computation time: 1.62 seconds
# ST 7 Memory used: 0.00 MB
# persistence computation time: :2.64 seconds
#
#
#
# ST 8 computation time: 1.65 seconds
# ST 8 Memory used: 0.00 MB
# persistence computation time: :3.63 seconds
#
#
#
# ST 9 computation time: 1.60 seconds
# ST 9 Memory used: 0.00 MB
# persistence computation time: :3.64 seconds
#
#
#
# ST 10 computation time: 1.64 seconds
# ST 10 Memory used: 0.00 MB
# persistence computation time: :3.17 seconds
#
#
#
# ST 11 computation time: 1.63 seconds
# ST 11 Memory used: 0.00 MB
# persistence computation time: :2.60 seconds
#
#
#
# ST 12 computation time: 1.70 seconds
# ST 12 Memory used: 0.00 MB
# persistence computation time: :2.67 seconds
#
#
#
# ST 13 computation time: 1.68 seconds
# ST 13 Memory used: 0.00 MB
# persistence computation time: :3.83 seconds
#
#
#
# ST 14 computation time: 1.68 seconds
# ST 14 Memory used: 0.00 MB
# persistence computation time: :3.19 seconds
#
#
#
# ST 15 computation time: 1.84 seconds
# ST 15 Memory used: 0.00 MB
# persistence computation time: :2.62 seconds
#
#
#
# ST 16 computation time: 1.63 seconds
# ST 16 Memory used: 0.00 MB
# persistence computation time: :1.64 seconds
#
#
#
# ST 17 computation time: 1.64 seconds
# ST 17 Memory used: 0.00 MB
# persistence computation time: :3.19 seconds
#
#
#
# ST 18 computation time: 1.66 seconds
# ST 18 Memory used: 0.00 MB
# persistence computation time: :2.69 seconds
#
#
#
# ST 19 computation time: 1.65 seconds
# ST 19 Memory used: 0.00 MB
# persistence computation time: :2.16 seconds
#
#
#
# ST 20 computation time: 1.68 seconds
# ST 20 Memory used: 0.00 MB
# persistence computation time: :3.65 seconds
#
#
#
# ST 21 computation time: 1.64 seconds
# ST 21 Memory used: 0.00 MB
# persistence computation time: :2.14 seconds
#
#
#
# ST 22 computation time: 1.64 seconds
# ST 22 Memory used: 0.00 MB
# persistence computation time: :3.58 seconds
#
#
#
# ST 23 computation time: 3.35 seconds
# ST 23 Memory used: 0.00 MB
# persistence computation time: :2.78 seconds
#
#
#
# ST 24 computation time: 3.86 seconds
# ST 24 Memory used: 0.09 MB
# persistence computation time: :3.94 seconds
#
#
#
# ST 25 computation time: 1.72 seconds
# ST 25 Memory used: 0.00 MB
# persistence computation time: :2.85 seconds
#
#
#
# ST 26 computation time: 1.71 seconds
# ST 26 Memory used: 0.00 MB
# persistence computation time: :4.02 seconds
#
#
#
# ST 27 computation time: 2.21 seconds
# ST 27 Memory used: 0.00 MB
# persistence computation time: :1.79 seconds
#
#
#
# ST 28 computation time: 2.17 seconds
# ST 28 Memory used: 0.00 MB
# persistence computation time: :4.33 seconds
#
#
#
# ST 29 computation time: 1.87 seconds
# ST 29 Memory used: 0.00 MB
# persistence computation time: :4.44 seconds
#
#
#
# ST 30 computation time: 2.00 seconds
# ST 30 Memory used: 0.00 MB
# persistence computation time: :4.54 seconds
#
#
#
# Time used for diagrams computation and persistence:  145.520174741745 seconds
# Memory used for diagrams computation and persistence: 0.16 MB
# Time used for pipeline creation:  3.691930055618286 seconds
# Memory used for diagrams computation and persistence: 0.00 MB
# GridSearchCV(cv=4, error_score='raise',
#              estimator=Pipeline(steps=[('Separator', DiagramSelector()),
#                                        ('Scaler',
#                                         DiagramScaler(scalers=[([0, 1],
#                                                                 MinMaxScaler())])),
#                                        ('TDA', PersistenceImage()),
#                                        ('Estimator',
#                                         RandomForestClassifier())]),
#              param_grid=[{'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [Landscape()],
#                           'TDA__resolution': [100]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [PersistenceImage()],
#                           'TDA__bandwidth': [0.01, 0.1, 1.0, 10.0],
#                           'TDA__resolution': [[5, 5], [6, 6]]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [False], 'TDA': [BottleneckDistance()],
#                           'TDA__epsilon': [0.1]}])
# model best parameters {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# Train accuracy = 1.0
# Test accuracy  = 0.3333333333333333
# model best parameters {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# Train accuracy = 1.0
# Test accuracy  = 0.16666666666666666
# Launch_benchmark computation time: :9.90 seconds
#
#
#
# TEST RESULT FOR PARAMETERS :  {'complex_type': 'alpha', 'precision': 'safe'}
# Test for the parameters: {'complex_type': 'alpha', 'precision': 'safe'} took 169.28 seconds
# ============================================================================================================================================
# ============================================================================================================================================
# ============================================================================================================================================
# TEST STARTED FOR :complex_alpha_parameters:  {'complex_type': 'alpha', 'precision': 'fast'}
# ST 1 computation time: 1.91 seconds
# ST 1 Memory used: 0.00 MB
# persistence computation time: :3.24 seconds
#
#
#
# ST 2 computation time: 2.24 seconds
# ST 2 Memory used: 0.00 MB
# persistence computation time: :7.68 seconds
#
#
#
# ST 3 computation time: 3.33 seconds
# ST 3 Memory used: 0.00 MB
# persistence computation time: :4.56 seconds
#
#
#
# ST 4 computation time: 1.68 seconds
# ST 4 Memory used: 0.00 MB
# persistence computation time: :3.64 seconds
#
#
#
# ST 5 computation time: 1.66 seconds
# ST 5 Memory used: 0.00 MB
# persistence computation time: :3.62 seconds
#
#
#
# ST 6 computation time: 1.67 seconds
# ST 6 Memory used: 0.00 MB
# persistence computation time: :3.58 seconds
#
#
#
# ST 7 computation time: 1.65 seconds
# ST 7 Memory used: 0.00 MB
# persistence computation time: :3.64 seconds
#
#
#
# ST 8 computation time: 1.68 seconds
# ST 8 Memory used: 0.00 MB
# persistence computation time: :3.69 seconds
#
#
#
# ST 9 computation time: 1.69 seconds
# ST 9 Memory used: 0.00 MB
# persistence computation time: :2.68 seconds
#
#
#
# ST 10 computation time: 1.66 seconds
# ST 10 Memory used: 0.00 MB
# persistence computation time: :3.65 seconds
#
#
#
# ST 11 computation time: 1.68 seconds
# ST 11 Memory used: 0.00 MB
# persistence computation time: :3.72 seconds
#
#
#
# ST 12 computation time: 1.64 seconds
# ST 12 Memory used: 0.00 MB
# persistence computation time: :3.59 seconds
#
#
#
# ST 13 computation time: 1.66 seconds
# ST 13 Memory used: 0.00 MB
# persistence computation time: :3.72 seconds
#
#
#
# ST 14 computation time: 1.63 seconds
# ST 14 Memory used: 0.00 MB
# persistence computation time: :2.63 seconds
#
#
#
# ST 15 computation time: 1.65 seconds
# ST 15 Memory used: 0.00 MB
# persistence computation time: :2.18 seconds
#
#
#
# ST 16 computation time: 1.70 seconds
# ST 16 Memory used: 0.00 MB
# persistence computation time: :3.71 seconds
#
#
#
# ST 17 computation time: 1.66 seconds
# ST 17 Memory used: 0.00 MB
# persistence computation time: :3.66 seconds
#
#
#
# ST 18 computation time: 1.65 seconds
# ST 18 Memory used: 0.00 MB
# persistence computation time: :3.62 seconds
#
#
#
# ST 19 computation time: 1.64 seconds
# ST 19 Memory used: 0.00 MB
# persistence computation time: :3.80 seconds
#
#
#
# ST 20 computation time: 1.63 seconds
# ST 20 Memory used: 0.00 MB
# persistence computation time: :3.64 seconds
#
#
#
# ST 21 computation time: 1.66 seconds
# ST 21 Memory used: 0.00 MB
# persistence computation time: :3.69 seconds
#
#
#
# ST 22 computation time: 1.71 seconds
# ST 22 Memory used: 0.00 MB
# persistence computation time: :3.23 seconds
#
#
#
# ST 23 computation time: 1.70 seconds
# ST 23 Memory used: 0.00 MB
# persistence computation time: :3.70 seconds
#
#
#
# ST 24 computation time: 2.17 seconds
# ST 24 Memory used: 0.00 MB
# persistence computation time: :3.61 seconds
#
#
#
# ST 25 computation time: 1.65 seconds
# ST 25 Memory used: 0.00 MB
# persistence computation time: :3.69 seconds
#
#
#
# ST 26 computation time: 1.65 seconds
# ST 26 Memory used: 0.00 MB
# persistence computation time: :3.62 seconds
#
#
#
# ST 27 computation time: 1.68 seconds
# ST 27 Memory used: 0.00 MB
# persistence computation time: :3.79 seconds
#
#
#
# ST 28 computation time: 1.65 seconds
# ST 28 Memory used: 0.00 MB
# persistence computation time: :3.71 seconds
#
#
#
# ST 29 computation time: 1.65 seconds
# ST 29 Memory used: 0.00 MB
# persistence computation time: :3.69 seconds
#
#
#
# ST 30 computation time: 1.68 seconds
# ST 30 Memory used: 0.00 MB
# persistence computation time: :3.62 seconds
#
#
#
# Time used for diagrams computation and persistence:  163.47570276260376 seconds
# Memory used for diagrams computation and persistence: 0.01 MB
# Time used for pipeline creation:  3.641104221343994 seconds
# Memory used for diagrams computation and persistence: 0.00 MB
# GridSearchCV(cv=4, error_score='raise',
#              estimator=Pipeline(steps=[('Separator', DiagramSelector()),
#                                        ('Scaler',
#                                         DiagramScaler(scalers=[([0, 1],
#                                                                 MinMaxScaler())])),
#                                        ('TDA', PersistenceImage()),
#                                        ('Estimator',
#                                         RandomForestClassifier())]),
#              param_grid=[{'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [Landscape()],
#                           'TDA__resolution': [100]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [PersistenceImage()],
#                           'TDA__bandwidth': [0.01, 0.1, 1.0, 10.0],
#                           'TDA__resolution': [[5, 5], [6, 6]]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [False], 'TDA': [BottleneckDistance()],
#                           'TDA__epsilon': [0.1]}])
# model best parameters {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# Train accuracy = 1.0
# Test accuracy  = 0.16666666666666666
# model best parameters {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# Train accuracy = 1.0
# Test accuracy  = 0.16666666666666666
# Launch_benchmark computation time: :8.46 seconds
#
#
#
# TEST RESULT FOR PARAMETERS :  {'complex_type': 'alpha', 'precision': 'fast'}
# Test for the parameters: {'complex_type': 'alpha', 'precision': 'fast'} took 183.80 seconds
# ============================================================================================================================================
# ============================================================================================================================================
# ============================================================================================================================================
# Time consumed after the whole script 353.075 seconds
# Memory consumed for the whole script 8.082 MB
# Best Complex  Parameters: {'complex_type': 'alpha', 'precision': 'fast'}
# Best Grid Search Parameters: {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[5, 5]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [5, 5]}
# Best Test Accuracy: 0.16666666666666666
#                                complex_parameters  elapsed_time
# 0  {'complex_type': 'alpha', 'precision': 'safe'}       169.278  \
# 1  {'complex_type': 'alpha', 'precision': 'fast'}       183.797
#
#    elapsed_memory  test_accuracy
# 0           8.055       0.166667  \
# 1           0.027       0.166667
#
#                      best parameters for the complex
# 0  {'Estimator': RandomForestClassifier(), 'Scale...
# 1  {'Estimator': RandomForestClassifier(), 'Scale...
