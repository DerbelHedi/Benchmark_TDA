# %% [markdown]
# ### This notebook is to explain how to use this
#  script_final is the function to run in the cluster, and get all the results from it , depending on the parameter of the complex

# %%
from ClusterFile import script_final
from DatasetGeneration import generate_data_clouds
import matplotlib.pyplot as plt
points_for_cloud=800
num_diag_per_class=15
#r_values=[3, 3.5, 4]
r_values=[3, 3.5, 4, 4.1, 4.3, 4.5,5]
points,labels,quantile=generate_data_clouds(points_for_cloud,num_diag_per_class,r_values)
from ClusterFile import script_final
from DatasetGeneration import generate_data_clouds
import matplotlib.pyplot as plt
points_for_cloud=800
num_diag_per_class=15
#r_values=[3, 3.5, 4]
r_values=[3, 3.5, 4, 4.1, 4.3, 4.5,5]
points,labels,quantile=generate_data_clouds(points_for_cloud,num_diag_per_class,r_values)
X=points[49]
from alpha_job_to_run import run_the_process
from build_complex import build_complex
from measure_time_memory import measure_time_memory
from compute_persistence import compute_persistence
complex_alpha_parameters={ "complex_type": 'rips', "max_dimension": 2, "sparse":None, "max_edge_length": 0.2}

alpha_result,build_complex_timing,build_complex_memory=measure_time_memory(build_complex,X,**complex_alpha_parameters)
print("ST {} computation time: {:.2f} seconds".format(50, build_complex_timing))
print("ST {} Memory used: {:.2f} MB".format(50,build_complex_memory))
print("ST number of simplices ", alpha_result.num_simplices())

dgm,compute_persistence_timing,compute_persistence_memory=measure_time_memory(compute_persistence,alpha_result,1)

print("persistence computation time: :{:.2f} seconds".format(compute_persistence_timing))
print(" \n\n")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 8
#       6 #r_values=[3, 3.5, 4]
#       7 r_values=[3, 3.5, 4, 4.1, 4.3, 4.5,5]
# ----> 8 points,labels,quantile=generate_data_clouds(points_for_cloud,num_diag_per_class,r_values)
#       9 X=points[49]
#      10 from alpha_job_to_run import run_the_process
#
# File ~/Desktop/Benchmark_TDA /DatasetGeneration.py:30, in generate_data_clouds(points_for_cloud, num_diag_per_class, r_values)
#      27         points.append(X)
#      28         labels.append([str(r)])
# ---> 30 thresh = [quantile(element) for element in points]
#      31 thresh_array = np.array(thresh)
#      32 quantiles= np.mean(thresh_array, axis=0)
#
# File ~/Desktop/Benchmark_TDA /DatasetGeneration.py:30, in <listcomp>(.0)
#      27         points.append(X)
#      28         labels.append([str(r)])
# ...

# %%
from ClusterFile import script_final
from DatasetGeneration import generate_data_clouds
import matplotlib.pyplot as plt
points_for_cloud=800
num_diag_per_class=15
#r_values=[3, 3.5, 4]
r_values=[3, 3.5, 4, 4.1, 4.3, 4.5,5]
points,labels,quantile=generate_data_clouds(points_for_cloud,num_diag_per_class,r_values)
X=points[49]
# Out:
# /Users/hediderbel/Desktop/Benchmark_TDA /DatasetGeneration.py:31: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   thresh_array = np.array(thresh)

# %%
import matplotlib.pyplot as plt
X=points[49]
plt.scatter(X[:,0], X[:,1], s=3)
plt.show()

# %%
from alpha_job_to_run import run_the_process
from build_complex import build_complex
from measure_time_memory import measure_time_memory
from compute_persistence import compute_persistence
complex_alpha_parameters={ "complex_type": 'rips', "max_dimension": 2, "sparse":None, "max_edge_length": 0.2}

alpha_result,build_complex_timing,build_complex_memory=measure_time_memory(build_complex,X,**complex_alpha_parameters)
print("ST {} computation time: {:.2f} seconds".format(50, build_complex_timing))
print("ST {} Memory used: {:.2f} MB".format(50,build_complex_memory))
print("ST number of simplices ", alpha_result.num_simplices())

dgm,compute_persistence_timing,compute_persistence_memory=measure_time_memory(compute_persistence,alpha_result,1)

print("persistence computation time: :{:.2f} seconds".format(compute_persistence_timing))
print(" \n\n")
# Out:
# ST 50 computation time: 1.06 seconds
# ST 50 Memory used: 294.84 MB
# ST number of simplices  44901463

# %%
points_for_cloud=800
num_diag_per_class=15
#r_values=[3, 3.5, 4]
r_values=[3, 3.5, 4, 4.1, 4.3, 4.5,5]
points,labels,quantile=generate_data_clouds(points_for_cloud,num_diag_per_class,r_values)

# %%
from alpha_job_to_run import run_the_process
from build_complex import build_complex
from measure_time_memory import measure_time_memory
from compute_persistence import compute_persistence
complex_alpha_parameters={ "complex_type": 'rips', "max_dimension": 2, "sparse":None, "max_edge_length": 0.2}

alpha_result=build_complex(X,**complex_alpha_parameters)

print("ST number of simplices ", alpha_result.num_simplices())

dgm=compute_persistence(alpha_result,1)

print(" \n\n")
# Out:
# ST number of simplices  44901463

# %%
complex_params = {
    'complex_type': ['rips'],
    'max_dimension': [2],
    'sparse': [None],
    'max_edge_length': quantile
}

# %%
# Out:
# 'edge'

# %%
import pandas as pd

# %%
script_final(complex_params)
# Out:
# TEST STARTED FOR :complex_alpha_parameters:  {'complex_type': 'edge', 'max_dimension': 2, 'sparse': None, 'max_edge_length': 0.5165838150439828, 'nb_iterations': 2}
# ST 1 computation time: 2.43 seconds
# ST 1 Memory used: 589.16 MB
# persistence computation time: :1.75 seconds
#
#
#
# ST 2 computation time: 2.24 seconds
# ST 2 Memory used: 501.81 MB
# persistence computation time: :1.74 seconds
#
#
#
# ST 3 computation time: 2.30 seconds
# ST 3 Memory used: 511.46 MB
# persistence computation time: :1.75 seconds
#
#
#
# ST 4 computation time: 2.33 seconds
# ST 4 Memory used: 533.28 MB
# persistence computation time: :1.71 seconds
#
#
#
# ST 5 computation time: 2.19 seconds
# ST 5 Memory used: 457.81 MB
# persistence computation time: :1.74 seconds
#
#
#
# ST 6 computation time: 2.14 seconds
# ST 6 Memory used: 466.40 MB
# persistence computation time: :1.73 seconds
#
#
#
# ST 7 computation time: 2.20 seconds
# ST 7 Memory used: 466.16 MB
# ...

# %%
df=script_final(points,labels,complex_params)
# Out:
# TEST STARTED FOR :complex_alpha_parameters:  {'complex_type': 'edge', 'max_dimension': 2, 'sparse': None, 'max_edge_length': array([0.19036207, 0.28275841, 0.36349825, 0.43895282, 0.51169332,
#        0.58473491, 0.65936844, 0.74518207, 0.85148833]), 'nb_iterations': 2}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=script_final(points,labels,complex_params)
#
# File ~/Desktop/Benchmark_TDA /ClusterFile.py:31, in script_final(points, labels, complex_alpha_params)
#      28 print("TEST STARTED FOR :complex_alpha_parameters: ",complex_alpha_parameters)
#      30 #step 1, compute the simplex tree and their corresponding diagram
# ---> 31 dgms = [run_the_process(X,i,complex_alpha_parameters,timing,memory,1) for i,X in enumerate(points)]
#      32 dgm_time,dgm_memory=np.sum(timing), np.sum(memory)
# ...

# %%
import pandas as pd

name = [2, 4]
surname = [33, 44]
axes = ["hedi", "nour"]

# Specify column names using the 'columns' parameter
df_results = pd.read_csv('results_alpha.csv')

df_results
# Out:
#                                 complex_parameters  elapsed_time
# 0   {'complex_type': 'alpha', 'precision': 'fast'}        24.089  \
# 1   {'complex_type': 'alpha', 'precision': 'safe'}        30.043
# 2  {'complex_type': 'alpha', 'precision': 'exact'}        39.283
#
#    time for diagram computation  time for pipeline creation
# 0                         3.178                         0.0  \
# 1                         2.895                         0.0
# 2                        11.054                         0.0
#
#    time for pipeline fitting and testing  elapsed_memory
# 0                                     21           5.309  \
# 1                                     27           9.238
# 2                                     28           0.766
#
#    memory for diagram computation  memory for pipeline creation
# 0                           1.547                           0.0  \
# 1                           7.402                           0.0
# ...

# %%
import dataframe_image as dfi
df_styled = df_results.style.background_gradient() #adding a gradient based on values in cell
dfi.export(df_styled,"mytable.png")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 3
#       1 import dataframe_image as dfi
#       2 df_styled = df_results.style.background_gradient() #adding a gradient based on values in cell
# ----> 3 dfi.export(df_styled,"mytable.png")
#
# File ~/Library/Python/3.9/lib/python/site-packages/dataframe_image/_pandas_accessor.py:48, in export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi)
#      38 def export(
#      39     obj,
#      40     filename,
#    (...)
#      46     dpi=None,
#      47 ):
# ---> 48     return _export(
#      49         obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi
#      50     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/dataframe_image/_pandas_accessor.py:70, in _export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi)
# ...

# %%
df_results
# Out:
#                                 complex_parameters  elapsed_time
# 0   {'complex_type': 'alpha', 'precision': 'fast'}        24.089  \
# 1   {'complex_type': 'alpha', 'precision': 'safe'}        30.043
# 2  {'complex_type': 'alpha', 'precision': 'exact'}        39.283
#
#    time for diagram computation  time for pipeline creation
# 0                         3.178                         0.0  \
# 1                         2.895                         0.0
# 2                        11.054                         0.0
#
#    time for pipeline fitting and testing  elapsed_memory
# 0                                     21           5.309  \
# 1                                     27           9.238
# 2                                     28           0.766
#
#    memory for diagram computation  memory for pipeline creation
# 0                           1.547                           0.0  \
# 1                           7.402                           0.0
# ...

# %%
# Save the DataFrame as an image
df_results.to_html("my_dataframe.html")

# Convert the HTML file to an image
from html2image import convert

image = convert("my_dataframe.html", output_format="png")

# Save the image
image.save("my_dataframe.png")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       2 df_results.to_html("my_dataframe.html")
#       4 # Convert the HTML file to an image
# ----> 5 from html2image import convert
#       7 image = convert("my_dataframe.html", output_format="png")
#       9 # Save the image
#
# ImportError: cannot import name 'convert' from 'html2image' (/Users/hediderbel/Library/Python/3.9/lib/python/site-packages/html2image/__init__.py)

# %%
pip install html2image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1=pd.read_csv("results_rips.csv")
df1['complex_parameters']
# Out:
# 0    {'complex_type': 'rips', 'max_dimension': 2, '...
# Name: complex_parameters, dtype: object

# %%
df1
# Out:
#                                   complex_parameters  elapsed_time
# 0  {'complex_type': 'rips', 'max_dimension': 2, '...         8.538  \
#
#    time for diagram computation  time for pipeline creation
# 0                         0.027                         0.0  \
#
#    time for pipeline fitting and testing  elapsed_memory
# 0                                      9           1.082  \
#
#    memory for diagram computation  memory for pipeline creation
# 0                             0.0                           0.0  \
#
#    memory for pipeline fitting and testing  test_accuracy
# 0                                        1       0.333333  \
#
#                      best parameters for the complex
# 0  {'Estimator': RandomForestClassifier(), 'Scale...

# %%
type(df1['complex_parameters'])
# Out:
# pandas.core.series.Series

# %%
tt=df1['best parameters for the complex']

# %%
type(tt)
# Out:
# pandas.core.series.Series

# %%
for element in tt :
    print(element)
# Out:
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(resolution=[5, 5]), 'TDA__bandwidth': 1.0, 'TDA__resolution': [5, 5]}
