# %%
from TestTest import test
test()
# Out:
# quantile  1   0.1941899658558497
# quantile  2   0.2894427371613919
# quantile  3   0.3708077792360198
# quantile  4   0.4465520706530718
# quantile  5   0.5202705131153148
# quantile  6   0.5946069123466036
# quantile  7   0.6723842494908339
# quantile  8   0.758389453059409
# quantile  9   0.8655854666974098
# TEST STARTED FOR :complex_alpha_parameters:  {'complex_type': 'rips', 'max_dimension': 2, 'sparse': None, 'max_edge_length': 0.1941899658558497}
# ST 1 computation time: 0.04 seconds
# ST 1 Memory used: 21.04 MB
# ST number of simplices  579983
# persistence computation time: :0.90 seconds
#
#
#
# ST 2 computation time: 0.04 seconds
# ST 2 Memory used: 16.32 MB
# ST number of simplices  570583
# persistence computation time: :0.74 seconds
#
#
#
# ST 3 computation time: 0.04 seconds
# ST 3 Memory used: 14.15 MB
# ST number of simplices  570314
# persistence computation time: :0.95 seconds
#
#
#
# ST 4 computation time: 0.04 seconds
# ST 4 Memory used: 14.39 MB
# ...
