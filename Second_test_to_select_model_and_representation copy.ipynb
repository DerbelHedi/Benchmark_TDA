# %%
from DatasetGeneration import generate_data_clouds
from ML_pipeline_final import ML_pipeline
from quantile_filtration import quantile
import itertools
import gudhi as gd
from build_complex import build_complex
from run_complex import run_complex
from compute_persistence import compute_persistence
from measure_time_memory import measure_time_memory
import matplotlib.pyplot as plt
import numpy as np
from compute_vectorisation import compute_vectorisation
from memory_profiler import profile
from sklearn.preprocessing   import MinMaxScaler
from sklearn.pipeline        import Pipeline
from sklearn.svm             import SVC
from sklearn.ensemble        import RandomForestClassifier
from sklearn.neighbors       import KNeighborsClassifier
from launch_benchmark import launch_benchmark
import random
import time

# %%
points_for_cloud=800
num_diag_per_class=15
#r_values=[3, 3.5, 4]
r_values=[3, 3.5, 4, 4.1, 4.3, 4.5,5]

points,labels=generate_data_clouds(points_for_cloud,num_diag_per_class,r_values)
thresh = [quantile(element) for element in points]
thresh_array = np.array(thresh)
quantile = np.mean(thresh_array, axis=0)
#np.append(quantile,None)

# %% [markdown]
# Now we will test which is the best combination of ml algo and tda representation for this dataset

# %%
complex_alpha_params = {
    'complex_type': ['alpha'],
    'precision': ['safe']}
        
        
best_accuracy=0
best_complex_parameters = {}
best_grid_search_parameters = {}
whole_time,whole_memory=[], []
for complex_alpha_values in itertools.product(*complex_alpha_params.values()):
    
    complex_alpha_parameters = dict(zip(complex_alpha_params.keys(), complex_alpha_values))
    dgms=[]  #diagrams list for all the points clouds
    
   
    
    for i,X in enumerate(points):
        alpha_result,timing,memory=measure_time_memory(build_complex,X,**complex_alpha_parameters)
        print("ST {} computation time: {:.2f} seconds".format(i, timing))
        print("ST Memory used: {:.2f} MB".format(memory))
        start_time = time.time()
        dgm=compute_persistence(alpha_result) #PD
        end_time = time.time()
        elapsed_time = end_time - start_time
        print("persistence computation time: :{:.2f} seconds".format(elapsed_time))
        print(" \n\n")
        dgms.append(dgm)
        whole_time.append(timing)
        whole_memory.append(memory)
    print("Time used for diagrams computation and persistence: ", np.sum(whole_time),"seconds")    
    print("Menory used for diagrams computation and persistence: {:.2f} MB".format(np.sum(whole_memory)))
    model,train_dgms,test_dgms,train_labs,test_labs=ML_pipeline(dgms,labels) 
    start_time2 = time.time()    
    test_accuracy,best_par=launch_benchmark(model,train_dgms,test_dgms,train_labs,test_labs)
    end_time2 = time.time()
    elapsed_time2 = end_time2 - start_time2
    print("Launch_benchmark computation time: :{:.2f} seconds".format(elapsed_time2))
    print(" \n\n")
    print("TEST RESULT FOR PARAMETERS : ", complex_alpha_parameters)
    print("============================================================================================================================================")
    print("============================================================================================================================================")
    print("============================================================================================================================================")
    
    if test_accuracy >best_accuracy :
        best_accuracy=test_accuracy
        best_grid_parameters=best_par.copy()
        best_complex_parameters=complex_alpha_parameters.copy()
# Out:
# ST 0 computation time: 2.41 seconds
# ST Memory used: 0.92 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 1 computation time: 2.92 seconds
# ST Memory used: 0.30 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 2 computation time: 1.41 seconds
# ST Memory used: 0.02 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 3 computation time: 1.46 seconds
# ST Memory used: 0.01 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 4 computation time: 2.01 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 5 computation time: 1.40 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 6 computation time: 1.37 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 7 computation time: 1.88 seconds
# ST Memory used: 0.19 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 8 computation time: 1.45 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.02 seconds
#
#
#
# ST 9 computation time: 3.20 seconds
# ST Memory used: 0.08 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 10 computation time: 3.22 seconds
# ST Memory used: 0.02 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 11 computation time: 1.29 seconds
# ST Memory used: 0.14 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 12 computation time: 1.20 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 13 computation time: 1.78 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 14 computation time: 1.78 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 15 computation time: 1.51 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 16 computation time: 2.56 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 17 computation time: 3.18 seconds
# ST Memory used: 0.33 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 18 computation time: 1.45 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 19 computation time: 1.76 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 20 computation time: 1.82 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 21 computation time: 1.76 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 22 computation time: 1.79 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 23 computation time: 1.75 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 24 computation time: 1.82 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 25 computation time: 1.76 seconds
# ST Memory used: 0.03 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 26 computation time: 2.04 seconds
# ST Memory used: 0.05 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 27 computation time: 1.68 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 28 computation time: 2.15 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 29 computation time: 1.50 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 30 computation time: 2.15 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 31 computation time: 1.98 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 32 computation time: 2.11 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 33 computation time: 1.36 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 34 computation time: 1.99 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 35 computation time: 1.29 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 36 computation time: 2.10 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 37 computation time: 1.37 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 38 computation time: 1.75 seconds
# ST Memory used: 0.03 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 39 computation time: 1.88 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 40 computation time: 1.70 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 41 computation time: 1.43 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 42 computation time: 1.89 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 43 computation time: 1.24 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 44 computation time: 2.24 seconds
# ST Memory used: 0.02 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 45 computation time: 1.95 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 46 computation time: 1.56 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 47 computation time: 2.13 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.02 seconds
#
#
#
# ST 48 computation time: 2.22 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 49 computation time: 1.83 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 50 computation time: 1.80 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 51 computation time: 1.61 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 52 computation time: 1.46 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 53 computation time: 1.31 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 54 computation time: 1.93 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 55 computation time: 2.04 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 56 computation time: 2.49 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 57 computation time: 1.73 seconds
# ST Memory used: 0.03 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 58 computation time: 1.23 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 59 computation time: 1.84 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 60 computation time: 1.63 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 61 computation time: 1.40 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 62 computation time: 1.95 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 63 computation time: 2.00 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 64 computation time: 2.24 seconds
# ST Memory used: 0.02 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 65 computation time: 1.55 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 66 computation time: 1.39 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 67 computation time: 2.80 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 68 computation time: 2.58 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 69 computation time: 2.90 seconds
# ST Memory used: 0.12 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 70 computation time: 4.08 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 71 computation time: 2.51 seconds
# ST Memory used: 0.06 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 72 computation time: 2.38 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 73 computation time: 2.48 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 74 computation time: 1.86 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 75 computation time: 1.83 seconds
# ST Memory used: 0.02 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 76 computation time: 1.73 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 77 computation time: 1.79 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 78 computation time: 1.72 seconds
# ST Memory used: 0.03 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 79 computation time: 1.75 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 80 computation time: 1.75 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 81 computation time: 1.74 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 82 computation time: 1.76 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 83 computation time: 1.70 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 84 computation time: 1.74 seconds
# ST Memory used: 0.02 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 85 computation time: 1.77 seconds
# ST Memory used: 0.11 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 86 computation time: 1.74 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 87 computation time: 1.69 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 88 computation time: 1.74 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 89 computation time: 1.88 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 90 computation time: 1.71 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 91 computation time: 1.70 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 92 computation time: 1.78 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 93 computation time: 1.70 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 94 computation time: 1.25 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 95 computation time: 1.71 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 96 computation time: 1.72 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 97 computation time: 1.76 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 98 computation time: 1.77 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 99 computation time: 1.81 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 100 computation time: 1.80 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 101 computation time: 1.75 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 102 computation time: 1.39 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 103 computation time: 1.68 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 104 computation time: 1.57 seconds
# ST Memory used: 0.00 MB
# persistence computation time: :0.00 seconds
#
#
#
# Time used for diagrams computation and persistence:  196.08065676689148 seconds
# Menory used for diagrams computation and persistence: 2.61 MB
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# Train accuracy = 1.0
# Test accuracy  = 0.38095238095238093
# Launch_benchmark computation time: :10.77 seconds
#
#
#
# TEST RESULT FOR PARAMETERS :  {'complex_type': 'alpha', 'precision': 'safe'}
# ============================================================================================================================================
# ============================================================================================================================================
# ============================================================================================================================================

# %%
print("Best Complex Alpha Parameters:", best_complex_parameters)
print("Best Grid Search Parameters:", best_grid_parameters)
print("Best Test Accuracy:", best_accuracy)
print()
# Out:
# Best Complex Alpha Parameters: {'complex_type': 'alpha', 'precision': 'safe'}
# Best Grid Search Parameters: {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': PersistenceImage(bandwidth=0.1, resolution=[6, 6]), 'TDA__bandwidth': 0.1, 'TDA__resolution': [6, 6]}
# Best Test Accuracy: 0.38095238095238093

# %%
complex_alpha_params = {
    'complex_type': ['rips'],
    'max_dimension': [2],
    'sparse': [None],
    'max_edge_length': [quantile[-1]]
}
        
best_accuracy=0
best_complex_parameters = {}
best_grid_search_parameters = {}
whole_time,whole_memory=[], []
for complex_alpha_values in itertools.product(*complex_alpha_params.values()):
    
    complex_alpha_parameters = dict(zip(complex_alpha_params.keys(), complex_alpha_values))
    dgms=[]  #diagrams list for all the points clouds
    
   
    
    for i,X in enumerate(points):
        alpha_result,timing,memory=measure_time_memory(build_complex,X,**complex_alpha_parameters)
        print("ST {} computation time: {:.2f} seconds".format(i, timing))
        print("ST Memory used: {:.2f} MB".format(memory))
        start_time = time.time()
        dgm=compute_persistence(alpha_result) #PD
        end_time = time.time()
        elapsed_time = end_time - start_time
        print("persistence computation time: :{:.2f} seconds".format(elapsed_time))
        print(" \n\n")
        dgms.append(dgm)
        whole_time.append(timing)
        whole_memory.append(memory)
    print("Time used for diagrams computation and persistence: ", np.sum(whole_time),"seconds")    
    print("Menory used for diagrams computation and persistence: {:.2f} MB".format(np.sum(whole_memory)))
    model,train_dgms,test_dgms,train_labs,test_labs=ML_pipeline(dgms,labels) 
    start_time2 = time.time()    
    test_accuracy,best_par=launch_benchmark(model,train_dgms,test_dgms,train_labs,test_labs)
    end_time2 = time.time()
    elapsed_time2 = end_time2 - start_time2
    print("Launch_benchmark computation time: :{:.2f} seconds".format(elapsed_time2))
    print(" \n\n")
    print("TEST RESULT FOR PARAMETERS : ", complex_alpha_parameters)
    print("============================================================================================================================================")
    print("============================================================================================================================================")
    print("============================================================================================================================================")
    
    if test_accuracy >best_accuracy :
        best_accuracy=test_accuracy
        best_grid_parameters=best_par.copy()
        best_complex_parameters=complex_alpha_parameters.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 complex_alpha_params = {
#       2     'complex_type': ['rips'],
#       3     'max_dimension': [2],
#       4     'sparse': [None],
# ----> 5     'max_edge_length': [quantile[-1]]
#       6 }
#       8 best_accuracy=0
#       9 best_complex_parameters = {}
#
# NameError: name 'quantile' is not defined

# %%
print("Best Complex Alpha Parameters:", best_complex_parameters)
print("Best Grid Search Parameters:", best_grid_parameters)
print("Best Test Accuracy:", best_accuracy)
print()
# Out:
# Best Complex Alpha Parameters: {'complex_type': 'rips', 'max_dimension': 2, 'sparse': None, 'max_edge_length': 0.8576947761290932}
# Best Grid Search Parameters: {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# Best Test Accuracy: 0.5714285714285714

# %%
complex_alpha_params = {
    'complex_type': ['edge'],
    'max_dimension': [2],
    'sparse': [None],
    'max_edge_length': [quantile[-1]],
    'nb_iterations': [1]
}
        
best_accuracy=0
best_complex_parameters = {}
best_grid_search_parameters = {}
whole_time,whole_memory=[], []
for complex_alpha_values in itertools.product(*complex_alpha_params.values()):
    
    complex_alpha_parameters = dict(zip(complex_alpha_params.keys(), complex_alpha_values))
    dgms=[]  #diagrams list for all the points clouds
    
   
    
    for i,X in enumerate(points):
        alpha_result,timing,memory=measure_time_memory(build_complex,X,**complex_alpha_parameters)
        print("ST {} computation time: {:.2f} seconds".format(i, timing))
        print("ST Memory used: {:.2f} MB".format(memory))
        start_time = time.time()
        dgm=compute_persistence(alpha_result) #PD
        end_time = time.time()
        elapsed_time = end_time - start_time
        print("persistence computation time: :{:.2f} seconds".format(elapsed_time))
        print(" \n\n")
        dgms.append(dgm)
        whole_time.append(timing)
        whole_memory.append(memory)
    print("Time used for diagrams computation and persistence: ", np.sum(whole_time),"seconds")    
    print("Menory used for diagrams computation and persistence: {:.2f} MB".format(np.sum(whole_memory)))
    model,train_dgms,test_dgms,train_labs,test_labs=ML_pipeline(dgms,labels) 
    start_time2 = time.time()    
    test_accuracy,best_par=launch_benchmark(model,train_dgms,test_dgms,train_labs,test_labs)
    end_time2 = time.time()
    elapsed_time2 = end_time2 - start_time2
    print("Launch_benchmark computation time: :{:.2f} seconds".format(elapsed_time2))
    print(" \n\n")
    print("TEST RESULT FOR PARAMETERS : ", complex_alpha_parameters)
    print("============================================================================================================================================")
    print("============================================================================================================================================")
    print("============================================================================================================================================")
    
    if test_accuracy >best_accuracy :
        best_accuracy=test_accuracy
        best_grid_parameters=best_par.copy()
        best_complex_parameters=complex_alpha_parameters.copy()
# Out:
# ST 0 computation time: 9.57 seconds
# ST Memory used: 792.02 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 1 computation time: 5.71 seconds
# ST Memory used: 1789.23 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 2 computation time: 4.94 seconds
# ST Memory used: 1801.57 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 3 computation time: 5.18 seconds
# ST Memory used: 1753.82 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 4 computation time: 4.91 seconds
# ST Memory used: 1726.91 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 5 computation time: 4.86 seconds
# ST Memory used: 1708.86 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 6 computation time: 4.97 seconds
# ST Memory used: 1714.11 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 7 computation time: 4.89 seconds
# ST Memory used: 1793.40 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 8 computation time: 4.80 seconds
# ST Memory used: 1743.51 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 9 computation time: 4.69 seconds
# ST Memory used: 1730.61 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 10 computation time: 4.61 seconds
# ST Memory used: 1675.14 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 11 computation time: 4.95 seconds
# ST Memory used: 1722.20 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 12 computation time: 4.75 seconds
# ST Memory used: 1641.35 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 13 computation time: 4.71 seconds
# ST Memory used: 1643.73 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 14 computation time: 4.73 seconds
# ST Memory used: 1658.92 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 15 computation time: 4.70 seconds
# ST Memory used: 1627.48 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 16 computation time: 4.67 seconds
# ST Memory used: 1584.97 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 17 computation time: 4.88 seconds
# ST Memory used: 1626.84 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 18 computation time: 4.65 seconds
# ST Memory used: 1596.84 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 19 computation time: 4.63 seconds
# ST Memory used: 1598.34 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 20 computation time: 4.53 seconds
# ST Memory used: 1520.06 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 21 computation time: 4.97 seconds
# ST Memory used: 1616.01 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 22 computation time: 5.31 seconds
# ST Memory used: 1622.23 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 23 computation time: 4.39 seconds
# ST Memory used: 1622.82 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 24 computation time: 4.23 seconds
# ST Memory used: 1504.86 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 25 computation time: 4.42 seconds
# ST Memory used: 1624.76 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 26 computation time: 4.30 seconds
# ST Memory used: 1498.98 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 27 computation time: 4.39 seconds
# ST Memory used: 1573.70 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 28 computation time: 4.40 seconds
# ST Memory used: 1587.18 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 29 computation time: 4.42 seconds
# ST Memory used: 1544.24 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 30 computation time: 4.32 seconds
# ST Memory used: 1460.99 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 31 computation time: 4.40 seconds
# ST Memory used: 1517.56 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 32 computation time: 4.18 seconds
# ST Memory used: 1432.90 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 33 computation time: 4.46 seconds
# ST Memory used: 1573.11 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 34 computation time: 5.19 seconds
# ST Memory used: 1339.61 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 35 computation time: 4.25 seconds
# ST Memory used: 1459.64 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 36 computation time: 4.14 seconds
# ST Memory used: 1399.69 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 37 computation time: 4.27 seconds
# ST Memory used: 1408.95 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 38 computation time: 4.10 seconds
# ST Memory used: 1309.31 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 39 computation time: 4.24 seconds
# ST Memory used: 1406.67 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 40 computation time: 4.07 seconds
# ST Memory used: 1277.96 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 41 computation time: 4.29 seconds
# ST Memory used: 1368.60 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 42 computation time: 4.24 seconds
# ST Memory used: 1398.07 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 43 computation time: 4.18 seconds
# ST Memory used: 1274.35 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 44 computation time: 4.17 seconds
# ST Memory used: 1350.56 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 45 computation time: 4.16 seconds
# ST Memory used: 1276.37 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 46 computation time: 4.21 seconds
# ST Memory used: 1348.52 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 47 computation time: 4.49 seconds
# ST Memory used: 1389.02 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 48 computation time: 4.18 seconds
# ST Memory used: 1292.77 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 49 computation time: 4.37 seconds
# ST Memory used: 1315.89 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 50 computation time: 4.27 seconds
# ST Memory used: 1281.23 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 51 computation time: 4.12 seconds
# ST Memory used: 1247.61 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 52 computation time: 4.18 seconds
# ST Memory used: 1258.26 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 53 computation time: 4.18 seconds
# ST Memory used: 1253.38 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 54 computation time: 4.21 seconds
# ST Memory used: 1209.10 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 55 computation time: 4.33 seconds
# ST Memory used: 1291.50 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 56 computation time: 13.20 seconds
# ST Memory used: 1557.95 MB
# persistence computation time: :9.14 seconds
#
#
#
# ST 57 computation time: 6.42 seconds
# ST Memory used: 1001.98 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 58 computation time: 4.09 seconds
# ST Memory used: 1166.77 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 59 computation time: 4.00 seconds
# ST Memory used: 1150.85 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 60 computation time: 4.03 seconds
# ST Memory used: 1135.21 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 61 computation time: 4.35 seconds
# ST Memory used: 1372.54 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 62 computation time: 4.02 seconds
# ST Memory used: 1136.82 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 63 computation time: 4.06 seconds
# ST Memory used: 1147.77 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 64 computation time: 4.13 seconds
# ST Memory used: 1213.86 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 65 computation time: 4.13 seconds
# ST Memory used: 1057.88 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 66 computation time: 4.15 seconds
# ST Memory used: 1178.20 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 67 computation time: 4.23 seconds
# ST Memory used: 1240.29 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 68 computation time: 4.15 seconds
# ST Memory used: 1237.79 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 69 computation time: 4.38 seconds
# ST Memory used: 1899.37 MB
# persistence computation time: :0.02 seconds
#
#
#
# ST 70 computation time: 4.12 seconds
# ST Memory used: 1152.86 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 71 computation time: 4.08 seconds
# ST Memory used: 1117.43 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 72 computation time: 4.17 seconds
# ST Memory used: 1161.55 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 73 computation time: 4.45 seconds
# ST Memory used: 935.09 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 74 computation time: 4.56 seconds
# ST Memory used: 1196.74 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 75 computation time: 4.34 seconds
# ST Memory used: 1225.76 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 76 computation time: 4.09 seconds
# ST Memory used: 1022.24 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 77 computation time: 4.24 seconds
# ST Memory used: 1143.83 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 78 computation time: 4.30 seconds
# ST Memory used: 1215.69 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 79 computation time: 4.26 seconds
# ST Memory used: 1108.41 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 80 computation time: 4.42 seconds
# ST Memory used: 1276.90 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 81 computation time: 4.29 seconds
# ST Memory used: 1157.61 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 82 computation time: 4.58 seconds
# ST Memory used: 1250.83 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 83 computation time: 4.17 seconds
# ST Memory used: 1051.87 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 84 computation time: 4.17 seconds
# ST Memory used: 1081.46 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 85 computation time: 4.26 seconds
# ST Memory used: 1185.77 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 86 computation time: 4.08 seconds
# ST Memory used: 983.45 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 87 computation time: 4.22 seconds
# ST Memory used: 1108.61 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 88 computation time: 4.55 seconds
# ST Memory used: 1196.09 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 89 computation time: 4.28 seconds
# ST Memory used: 1046.74 MB
# persistence computation time: :0.01 seconds
#
#
#
# ST 90 computation time: 4.26 seconds
# ST Memory used: 1026.25 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 91 computation time: 4.30 seconds
# ST Memory used: 1072.22 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 92 computation time: 4.22 seconds
# ST Memory used: 1010.32 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 93 computation time: 4.20 seconds
# ST Memory used: 941.97 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 94 computation time: 4.45 seconds
# ST Memory used: 1106.64 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 95 computation time: 4.47 seconds
# ST Memory used: 1010.81 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 96 computation time: 4.21 seconds
# ST Memory used: 956.91 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 97 computation time: 4.25 seconds
# ST Memory used: 983.58 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 98 computation time: 4.43 seconds
# ST Memory used: 1055.38 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 99 computation time: 4.34 seconds
# ST Memory used: 978.79 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 100 computation time: 4.42 seconds
# ST Memory used: 983.50 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 101 computation time: 4.34 seconds
# ST Memory used: 964.24 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 102 computation time: 4.23 seconds
# ST Memory used: 876.28 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 103 computation time: 4.64 seconds
# ST Memory used: 1059.60 MB
# persistence computation time: :0.00 seconds
#
#
#
# ST 104 computation time: 4.31 seconds
# ST Memory used: 943.21 MB
# persistence computation time: :0.00 seconds
#
#
#
# Time used for diagrams computation and persistence:  478.42084527015686 seconds
# Menory used for diagrams computation and persistence: 138872.20 MB
# GridSearchCV(cv=3, error_score='raise',
#              estimator=Pipeline(steps=[('Separator', DiagramSelector()),
#                                        ('Scaler',
#                                         DiagramScaler(scalers=[([0, 1],
#                                                                 MinMaxScaler())])),
#                                        ('TDA', PersistenceImage()),
#                                        ('Estimator', SVC())]),
#              param_grid=[{'Estimator': [SVC(gamma='auto',
#                                             kernel='precomputed')],
#                           'Scaler__use': [False],
#                           'TDA': [SlicedWassersteinKernel()],
#                           'TDA__bandwidth': [0.1, 1....
#                          {'Estimator': [SVC()], 'Scaler__use': [True],
#                           'TDA': [PersistenceImage()],
#                           'TDA__bandwidth': [0.01, 0.1, 1.0, 10.0],
#                           'TDA__resolution': [[5, 5], [6, 6]]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [Landscape()],
#                           'TDA__resolution': [100]},
#                          {'Estimator': [KNeighborsClassifier(metric='precomputed')],
#                           'Scaler__use': [False], 'TDA': [BottleneckDistance()],
#                           'TDA__epsilon': [0.1]}])
# GridSearchCV(cv=3, error_score='raise',
#              estimator=Pipeline(steps=[('Separator', DiagramSelector()),
#                                        ('Scaler',
#                                         DiagramScaler(scalers=[([0, 1],
#                                                                 MinMaxScaler())])),
#                                        ('TDA', PersistenceImage()),
#                                        ('Estimator', SVC())]),
#              param_grid=[{'Estimator': [SVC(gamma='auto',
#                                             kernel='precomputed')],
#                           'Scaler__use': [False],
#                           'TDA': [SlicedWassersteinKernel()],
#                           'TDA__bandwidth': [0.1, 1....
#                          {'Estimator': [SVC()], 'Scaler__use': [True],
#                           'TDA': [PersistenceImage()],
#                           'TDA__bandwidth': [0.01, 0.1, 1.0, 10.0],
#                           'TDA__resolution': [[5, 5], [6, 6]]},
#                          {'Estimator': [RandomForestClassifier()],
#                           'Scaler__use': [True], 'TDA': [Landscape()],
#                           'TDA__resolution': [100]},
#                          {'Estimator': [KNeighborsClassifier(metric='precomputed')],
#                           'Scaler__use': [False], 'TDA': [BottleneckDistance()],
#                           'TDA__epsilon': [0.1]}])
# {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# Train accuracy = 1.0
# Test accuracy  = 0.6666666666666666
# Launch_benchmark computation time: :43.23 seconds
#
#
#
# TEST RESULT FOR PARAMETERS :  {'complex_type': 'edge', 'max_dimension': 2, 'sparse': None, 'max_edge_length': 0.8492661703175679, 'nb_iterations': 1}
# ============================================================================================================================================
# ============================================================================================================================================
# ============================================================================================================================================

# %%
print("Best Complex Alpha Parameters:", best_complex_parameters)
print("Best Grid Search Parameters:", best_grid_parameters)
print("Best Test Accuracy:", best_accuracy)
print()
# Out:
# Best Complex Alpha Parameters: {'complex_type': 'edge', 'max_dimension': 2, 'sparse': None, 'max_edge_length': 0.8492661703175679, 'nb_iterations': 1}
# Best Grid Search Parameters: {'Estimator': RandomForestClassifier(), 'Scaler__use': True, 'TDA': Landscape(), 'TDA__resolution': 100}
# Best Test Accuracy: 0.6666666666666666
